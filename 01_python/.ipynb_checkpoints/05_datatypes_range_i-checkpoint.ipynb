# %% [markdown]
# ## **This notebook aims to compare some models and store them in a reasonable fashion**

# %%
import pandas as pd
import numpy as np
import os
import time
from imblearn.over_sampling import SMOTE
from sklearn.metrics import accuracy_score
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "0"  # Use GPU 0 in first notebook

# %%
project_dir = "/home/jupyter-tfg2425paula/prediction_project_v3"
os.chdir(project_dir)

clean_data_dir = os.path.join(project_dir, "00_data/clean")
horizontal_data_dir = os.path.join(project_dir, "00_data/horizontal_structure")
results_dir = os.path.join(project_dir, "02_results")
plots_dir = os.path.join(project_dir, "03_plots")
pca_data_dir = os.path.join(project_dir, "00_data/pca")

# %% [markdown]
# ### **GRU Model**

# %%
class GRU3DClassifier(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers, dropout):
        super(GRU3DClassifier, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.gru = nn.GRU(input_size, hidden_size, num_layers, batch_first=True, dropout=dropout)
        self.fc = nn.Linear(hidden_size, output_size)
        self.sigmoid = nn.Sigmoid()
    
    def forward(self, x):

        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)

        out, _ = self.gru(x, h0)
        out = self.fc(out[:, -1, :]) 
        # return self.sigmoid(out)
        return out

# %% [markdown]
# ### **LSTM Model**

# %%
class StockPriceLSTM(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, num_layers=1, dropout=0.0):
        super(StockPriceLSTM, self).__init__()
        self.hidden_dim = hidden_dim
        self.num_layers = num_layers
        self.lstm = nn.LSTM(input_dim, hidden_dim, num_layers=num_layers, 
                            batch_first=True, dropout=dropout)
    
        self.fc = nn.Linear(hidden_dim, output_dim)
        self.sigmoid = nn.Sigmoid()
    
    def forward(self, x):
        batch_size = x.size(0)  # Get the batch size dynamically

        h0 = torch.zeros(self.num_layers, batch_size, self.hidden_dim).to(x.device)  # (num_layers, batch_size, hidden_dim)
        c0 = torch.zeros(self.num_layers, batch_size, self.hidden_dim).to(x.device)  # (num_layers, batch_size, hidden_dim)
        
        out, _ = self.lstm(x, (h0, c0))

        out = self.fc(out[:, -1, :]) 
        # out = self.sigmoid(out)
        return out

# %% [markdown]
# ### **Set folders**

# %% [markdown]
# Processing

# %%
processing_types = ["clean", "pca"]
processing_types= ["clean"]

# %% [markdown]
# Folders

# %%
# stocks = ['AAPL', 'MSFT', 'AMZN', 'NVDA', 'SPX']
stocks = ['AAPL']
# types_securities = ["single_name", "options", "technical"]
types_securities = ["options"]

# %% [markdown]
# Different files

# %%
# years = ["15y", "10y", "5y", "2y"]
years = ["10y"]
# window_sizes = [5, 10, 50, 100]
window_sizes = [5]
# train_sizes = [80, 90, 95]
train_sizes = [95]

# %% [markdown]
# Same file

# %%
thresholds = [0.3, 0.35, 0.4, 0.45, 0.5]
thresholds = [0.5]
learning_rates = [0.005, 0.008, 0.009, 0.01]
learning_rates = [0.01]
num_epochs_list = [100, 200]
num_epochs_list = [100]
batch_sizes = [16, 32]
batch_sizes = [16]
prediction_thresholds = [0.35, 0.4, 0.45, 0.5]
prediction_thresholds = [0.5]

# %% [markdown]
# #### **Model and Hyperparameters**

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

hidden_size = 64  
output_size = 2  
num_layers = 2
dropout = 0.2

criterion = nn.CrossEntropyLoss()

# %%
model_types = ["lstm", "gru"]

# %% [markdown]
# #### **Last data modifications**

# %%
def reshape_remove_characters(df):

    X = np.array([np.stack(row) for row in df.drop(columns=['Target']).values])
    y = df['Target'].values

    smote = SMOTE(random_state=42)
    n_samples, timesteps, n_features = X.shape
    X_flat = X.reshape((n_samples, timesteps * n_features))
    X_flat = np.where(X_flat == 'ç', 0, X_flat)

    X_resampled = X_flat.reshape((-1, timesteps, n_features))
    
    return X_resampled, y

# %% [markdown]
# ### **Evaluation function**

# %%
def evaluate_rolling_unchanged_model_threshold(
    model, 
    X, 
    y, 
    criterion, 
    optimizer, 
    device, 
    train_size, 
    batch_size, 
    num_epochs, 
    lower_threshold
):
    """
    Evaluate a PyTorch model using a rolling prediction approach for time series,
    training the model only once on the initial training set. For each time step
    after train_size, the model makes a prediction without further parameter updates.
    Only predicts +1 or -1 if the probability of class 1 is above/below given thresholds;
    otherwise, predicts 0. Accuracy is computed only on nonzero predictions.

    Args:
        model:          PyTorch model to evaluate.
        X:              Feature data (numpy array).
        y:              Target data (numpy array).
        criterion:      Loss function (e.g., CrossEntropyLoss).
        optimizer:      Optimizer (e.g., Adam).
        device:         Device for computation (CPU or GPU).
        train_size:     Initial size of the training data (int or float).
                        If < 1, treated as fraction of total length.
        batch_size:     Batch size for training.
        num_epochs:     Number of epochs for initial training only.
        lower_threshold: Probability threshold below which model predicts -1.
        upper_threshold: Probability threshold above which model predicts +1.

    Returns:
        dict: Dictionary with the following keys:
            - "rolling_predictions": All predictions (-1, 0, +1) across the test period.
            - "rolling_targets": Corresponding true targets in [-1, +1].
            - "filtered_predictions": Nonzero predictions only.
            - "filtered_targets": Targets corresponding to nonzero predictions.
            - "accuracy_nonzero": Accuracy computed only on nonzero predictions.
    """

    # Convert X, y to tensors
    X = torch.tensor(X, dtype=torch.float32)
    y = torch.tensor(y, dtype=torch.long)

    # Determine initial training set size
    if train_size < 1.0:
        lower_bound = int(train_size * len(X))
    else:
        lower_bound = train_size

    # -------------------------
    # 1) SINGLE TRAINING PHASE
    # -------------------------
    model.to(device)
    model.train()
    
    X_train = X[:lower_bound].to(device)
    y_train = y[:lower_bound].to(device)

    train_dataset = TensorDataset(X_train, y_train)
    trainloader = DataLoader(
        train_dataset, 
        batch_size=batch_size, 
        shuffle=False,         # Keep False if order matters; True for better generalization
        # num_workers=4,         # Adjust based on your CPU cores
        # pin_memory=True,       # Speeds up transfer if using GPUs
        drop_last=False        # Ensure the last batch is included
    )

    epoch_train_losses = []
    for epoch in range(num_epochs):
        # torch.cuda.empty_cache()
        epoch_loss = 0.0
        for X_batch, y_batch in trainloader:
            X_batch = X_batch.to(device)
            y_batch = y_batch.to(device)

            optimizer.zero_grad()
            pred_y = model(X_batch)   # [batch_size, num_classes]
            loss = criterion(pred_y, y_batch)
            loss.backward()

            # Gradient clipping (optional)
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()

            epoch_loss += loss.item()
               
        if (epoch + 1) % 5 == 0 or epoch == num_epochs - 1:
            print(f"[Train] Epoch {epoch+1}/{num_epochs}, Loss={epoch_loss/len(trainloader):.4f}")

        epoch_train_losses.append(epoch_loss/len(trainloader))
        
    loss_decrease_percentage = ((epoch_train_losses[-1] - epoch_train_losses[0]) / epoch_train_losses[0]) * 100
    # ---------------------------------
    # 2) ROLLING PREDICTIONS, NO UPDATE
    # ---------------------------------
    model.eval()

    rolling_predictions = []
    rolling_targets     = []

    for i in range(lower_bound, len(X)):
        # Single-step "test" sample
        X_test = X[i:i+1].to(device)  # shape: (1, num_features)
        y_test = y[i:i+1].to(device)  # shape: (1, )

        with torch.no_grad():
            # Forward pass
            pred_y = model(X_test)  # [1, num_classes]
            probabilities = torch.softmax(pred_y, dim=1).cpu().numpy()  # shape: (1, 2)
            prob_class_1  = probabilities[:, 1]  # shape: (1,)

            # Threshold-based logic
            # Initialize all predictions to 0
            pred_classes = np.zeros_like(prob_class_1)
            # Predict -1 if prob < lower_threshold
            pred_classes[prob_class_1 < lower_threshold] = -1
            # Predict +1 if prob > upper_threshold
            pred_classes[prob_class_1 > 1-lower_threshold] = 1

        rolling_predictions.append(pred_classes[0])  # scalar
        rolling_targets.append(y_test.item())

    rolling_predictions = np.array(rolling_predictions)
    rolling_targets = np.array(rolling_targets).astype(int)

    # Convert any 0-labeled targets to -1 if your original data is in [-1, +1]
    # (Sometimes y might be {0,1} or {-1, +1}; adapt as needed.)
    rolling_targets[rolling_targets == 0] = -1

    # Filter out zero predictions
    nonzero_mask = rolling_predictions != 0
    filtered_preds = rolling_predictions[nonzero_mask]
    filtered_targets = rolling_targets[nonzero_mask]

    if len(filtered_preds) == 0:
        accuracy_nonzero = None
        print("No nonzero predictions, cannot compute thresholded accuracy.")
    else:
        accuracy_nonzero = accuracy_score(filtered_targets, filtered_preds)
        print(f"Accuracy on Nonzero Predictions: {accuracy_nonzero:.4f}")

    return {
        "rolling_predictions": rolling_predictions,
        "rolling_targets": rolling_targets,
        "filtered_predictions": filtered_preds,
        "filtered_targets": filtered_targets,
        "accuracy_nonzero": accuracy_nonzero,
        "loss_decrease_percentage": loss_decrease_percentage,
        "final_train_loss": epoch_train_losses[-1] 
    }

# %% [markdown]
# ### **3nd Type of comparison:**
#
# Learning rates, for AAPL 10y

# %% [markdown]
# ### **Plot curves**

# %%
import os
import numpy as np
import torch
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import accuracy_score

def evaluate_rolling_unchanged_model_threshold(
    model, 
    X, 
    y, 
    criterion, 
    optimizer, 
    device, 
    train_size, 
    batch_size, 
    num_epochs, 
    lower_threshold,
    plots_dir=None,
    plot_filename=None
):

    # -------------------------------
    # 0) Prepare Tensors & Splits
    # -------------------------------
    X = torch.tensor(X, dtype=torch.float32)
    y = torch.tensor(y, dtype=torch.long)

    total_size = len(X)
    # Determine actual train_size index
    if train_size < 1.0:
        lower_bound = int(train_size * total_size)
    else:
        lower_bound = train_size

    # Training portion
    X_train = X[:lower_bound].to(device)
    y_train = y[:lower_bound].to(device)

    train_dataset = TensorDataset(X_train, y_train)
    trainloader = DataLoader(
        train_dataset,
        batch_size=batch_size,
        shuffle=False,   # Set True if you prefer shuffling
        drop_last=False
    )

    if lower_bound < total_size:
        X_val = X[lower_bound:].to(device)
        y_val = y[lower_bound:].to(device)
        val_dataset = TensorDataset(X_val, y_val)
        valloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
    else:
        # If there's no leftover data for "test", handle gracefully
        X_val = None
        y_val = None
        valloader = None

    # ---------------------------------------------
    # 1) SINGLE TRAINING PHASE + Track Loss Curves
    # ---------------------------------------------
    model.to(device)
    model.train()

    epoch_train_losses = []
    epoch_test_losses = []

    for epoch in range(num_epochs):
        # TRAINING PASS
        epoch_loss = 0.0
        for X_batch, y_batch in trainloader:
            optimizer.zero_grad()

            # Forward
            pred_y = model(X_batch)
            loss = criterion(pred_y, y_batch)

            # Backprop & update
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)  # optional
            optimizer.step()

            epoch_loss += loss.item()

        avg_train_loss = epoch_loss / len(trainloader)
        epoch_train_losses.append(avg_train_loss)

        # VALIDATION PASS (Optional but needed to get test_loss_curve)
        if valloader is not None:
            model.eval()
            val_loss = 0.0
            with torch.no_grad():
                for Xb, yb in valloader:
                    pred_yb = model(Xb)
                    loss_b = criterion(pred_yb, yb)
                    val_loss += loss_b.item()
            avg_val_loss = val_loss / len(valloader)
            epoch_test_losses.append(avg_val_loss)

            model.train()  # Switch back to train mode

        else:
            # If no validation set, just store None or 0
            epoch_test_losses.append(None)

        # Print progress every 5 epochs or last epoch
        if (epoch + 1) % 5 == 0 or (epoch == num_epochs - 1):
            if epoch_test_losses[-1] is not None:
                print(f"[Epoch {epoch+1}/{num_epochs}] "
                      f"Train Loss: {avg_train_loss:.4f}, "
                      f"Val Loss: {avg_val_loss:.4f}")
            else:
                print(f"[Epoch {epoch+1}/{num_epochs}] "
                      f"Train Loss: {avg_train_loss:.4f}")

    # % decrease from first to last train loss
    if len(epoch_train_losses) > 1:
        loss_decrease_percentage = ((epoch_train_losses[-1] - epoch_train_losses[0])
                                    / epoch_train_losses[0]) * 100
    else:
        loss_decrease_percentage = 0.0

    final_train_loss = epoch_train_losses[-1]

    # -------------------------------
    # 2) ROLLING PREDICTIONS, NO UPDATE
    # -------------------------------
    model.eval()
    rolling_predictions = []
    rolling_targets = []

    for i in range(lower_bound, total_size):
        X_test = X[i:i+1].to(device)
        y_test = y[i:i+1].to(device)

        with torch.no_grad():
            pred_y = model(X_test)
            probabilities = torch.softmax(pred_y, dim=1).cpu().numpy()
            prob_class_1 = probabilities[:, 1]  # shape: (1,)

            # Threshold-based logic
            pred_classes = np.zeros_like(prob_class_1)
            # Predict -1 if prob < lower_threshold
            pred_classes[prob_class_1 < lower_threshold] = -1
            # Predict +1 if prob > (1 - lower_threshold)
            pred_classes[prob_class_1 > (1 - lower_threshold)] = 1

        rolling_predictions.append(pred_classes[0])
        rolling_targets.append(y_test.item())

    rolling_predictions = np.array(rolling_predictions)
    rolling_targets = np.array(rolling_targets).astype(int)

    # If original labels might be {0,1}, adapt as needed
    rolling_targets[rolling_targets == 0] = -1

    # Filter out zero predictions
    nonzero_mask = (rolling_predictions != 0)
    filtered_preds = rolling_predictions[nonzero_mask]
    filtered_targets = rolling_targets[nonzero_mask]

    if len(filtered_preds) == 0:
        accuracy_nonzero = None
        print("No nonzero predictions, cannot compute thresholded accuracy.")
    else:
        accuracy_nonzero = accuracy_score(filtered_targets, filtered_preds)
        print(f"Accuracy on Nonzero Predictions: {accuracy_nonzero:.4f}")

    # -------------------------------------------------
    # 3) PLOT (if plots_dir is set and there's test data)
    # -------------------------------------------------
    if plots_dir is not None:
        os.makedirs(plots_dir, exist_ok=True)

        # If user didn't provide a filename, create a default
        if plot_filename is None:
            plot_filename = "train_test_loss_curve.png"
        plot_path = os.path.join(plots_dir, plot_filename)

        # Plot the training and validation (test) loss curves
        plt.figure(figsize=(8, 5))
        plt.plot(epoch_train_losses, label="Train Loss")
        # Only plot test loss if it isn't None
        if any(x is not None for x in epoch_test_losses):
            plt.plot(epoch_test_losses, label="Test Loss")
        plt.xlabel("Epoch")
        plt.ylabel("Loss")
        plt.title("Train vs. Test Loss per Epoch")
        plt.legend()
        plt.tight_layout()

        plt.savefig(plot_path)
        plt.close()
        print(f"Loss curves saved to: {plot_path}")

    # ----------------
    # 4) Return results
    # ----------------
    return {
        "rolling_predictions": rolling_predictions,
        "rolling_targets": rolling_targets,
        "filtered_predictions": filtered_preds,
        "filtered_targets": filtered_targets,
        "accuracy_nonzero": accuracy_nonzero,
        "loss_decrease_percentage": loss_decrease_percentage,
        "final_train_loss": final_train_loss,
        "train_loss_curve": epoch_train_losses,
        "test_loss_curve": epoch_test_losses
    }

# %%
results_list = []
stock = "AAPL"
period = "10y"
possible_train_size = 95
window_size = 5
batch_size = 32
num_epochs = 100
window_size = 3

prediction_threshold = 0.5

output_folder = os.path.join(results_dir, f"inidividual_trials") 
os.makedirs(output_folder, exist_ok=True)

processing = "clean"
security_types = ["single_name", "options", "technical"]
learning_rate = 0.01
model_type == "lstm"

results_list = []
for security_type in security_types:
    initial_data_dir = os.path.join(project_dir, f"00_data/{processing}") 
    
    # 1) Load original data (info only)
    filename = f"{security_type}/{stock}/{period}_data.csv"
    original_input_filepath = os.path.join(initial_data_dir, filename)
    original_data = pd.read_csv(original_input_filepath)

    print(f"\n----- LEARNING_RATE: {learning_rate}, SECURITY_TYPE: {security_type}, MODEL_TYPE: {model_type} -----")

    # 2) Load the preprocessed data
    pkl_filename = f"{processing}/{security_type}/{stock}/{period}_{window_size}_data.pkl"
    input_filepath = os.path.join(horizontal_data_dir, pkl_filename)
    input_df = pd.read_pickle(input_filepath)
    
    # 3) Reshape
    X_resampled, y_resampled = reshape_remove_characters(input_df)

    input_size = X_resampled.shape[2]
    train_size = int(X_resampled.shape[0] * possible_train_size / 100)
    test_size = X_resampled.shape[0] - train_size

    for i in range(50):
        print(i)
        
        # for model_type in model_types:
            # 4) Initialize the model
            # if model_type == "gru":
            #     model = GRU3DClassifier(input_size, hidden_size, output_size, num_layers, dropout)
            # elif model_type == "lstm":
        model = GRU3DClassifier(input_size, hidden_size, output_size, num_layers, dropout)
        model = model.to(device)

        # 5) Set up optimizer
        optimizer = optim.Adam(model.parameters(), lr=learning_rate)
        print(f"Training {stock} | LR: {learning_rate} | Epochs: {num_epochs} "
              f"| Batch: {batch_size} | Security type: {security_type}")

        result = evaluate_rolling_unchanged_model_threshold(
            model=model,
            X=X_resampled,
            y=y_resampled,
            criterion=criterion,
            optimizer=optimizer,
            device=device,
            train_size=train_size,
            batch_size=batch_size,
            num_epochs=num_epochs,
            lower_threshold=0.5,
            plots_dir=None,                # folder where plots are saved
            plot_filename=f"learning_rates/AAPL_{model_type}_lr{learning_rate}_{security_type}.png" # optional custom filename
        )

        # 7) Extract results
        rolling_predictions = result["rolling_predictions"]
        rolling_targets = result["rolling_targets"]
        test_accuracy = result["accuracy_nonzero"]
        loss_decrease_percentage = result["loss_decrease_percentage"]
        nonzero_preds = np.count_nonzero(rolling_predictions)
        final_train_loss = result["final_train_loss"]

        # 9) Create a record (dictionary) for this run
        run_record = {
            "STOCK": stock,
            "DATA_TYPE": security_type,
            "MODEL": model_type.upper(),
            "PROCESSING": processing,
            "ACCURACY": test_accuracy,
            "TRAIN_PCT_DECREASE": loss_decrease_percentage,
            "FINAL_TRAIN_LOSS": final_train_loss
        }

        # 10) Append to the results_list
        results_list.append(run_record)
# Out:
# ----- LEARNING_RATE: 0.01, SECURITY_TYPE: single_name, MODEL_TYPE: gru -----
# 0
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Security type: single_name
# [Epoch 5/100] Train Loss: 0.6939, Val Loss: 0.6933
# [Epoch 10/100] Train Loss: 0.6937, Val Loss: 0.6924
# [Epoch 15/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 20/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 25/100] Train Loss: 0.6930, Val Loss: 0.6934
# [Epoch 30/100] Train Loss: 0.6922, Val Loss: 0.6913
# [Epoch 35/100] Train Loss: 0.6922, Val Loss: 0.6907
# [Epoch 40/100] Train Loss: 0.6912, Val Loss: 0.6891
# [Epoch 45/100] Train Loss: 0.6917, Val Loss: 0.6897
# [Epoch 50/100] Train Loss: 0.6902, Val Loss: 0.6861
# [Epoch 55/100] Train Loss: 0.6899, Val Loss: 0.6881
# [Epoch 60/100] Train Loss: 0.6891, Val Loss: 0.6871
# [Epoch 65/100] Train Loss: 0.6887, Val Loss: 0.6854
# [Epoch 70/100] Train Loss: 0.6882, Val Loss: 0.6847
# [Epoch 75/100] Train Loss: 0.6875, Val Loss: 0.6839
# [Epoch 80/100] Train Loss: 0.6863, Val Loss: 0.6875
# [Epoch 85/100] Train Loss: 0.6851, Val Loss: 0.6922
# [Epoch 90/100] Train Loss: 0.6856, Val Loss: 0.6939
# [Epoch 95/100] Train Loss: 0.6835, Val Loss: 0.6940
# [Epoch 100/100] Train Loss: 0.6772, Val Loss: 0.7089
# Accuracy on Nonzero Predictions: 0.4733
# 1
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Security type: single_name
# [Epoch 5/100] Train Loss: 0.6940, Val Loss: 0.6938
# [Epoch 10/100] Train Loss: 0.6936, Val Loss: 0.6924
# [Epoch 15/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 20/100] Train Loss: 0.6939, Val Loss: 0.6922
# [Epoch 25/100] Train Loss: 0.6934, Val Loss: 0.6928
# [Epoch 30/100] Train Loss: 0.6926, Val Loss: 0.6931
# [Epoch 35/100] Train Loss: 0.6924, Val Loss: 0.6926
# [Epoch 40/100] Train Loss: 0.6918, Val Loss: 0.6915
# [Epoch 45/100] Train Loss: 0.6907, Val Loss: 0.6948
# [Epoch 50/100] Train Loss: 0.6909, Val Loss: 0.6921
# [Epoch 55/100] Train Loss: 0.6890, Val Loss: 0.6883
# [Epoch 60/100] Train Loss: 0.6879, Val Loss: 0.6876
# [Epoch 65/100] Train Loss: 0.6875, Val Loss: 0.6852
# [Epoch 70/100] Train Loss: 0.6869, Val Loss: 0.6860
# [Epoch 75/100] Train Loss: 0.6868, Val Loss: 0.6916
# [Epoch 80/100] Train Loss: 0.6854, Val Loss: 0.6894
# [Epoch 85/100] Train Loss: 0.6813, Val Loss: 0.6888
# [Epoch 90/100] Train Loss: 0.6825, Val Loss: 0.6885
# [Epoch 95/100] Train Loss: 0.6824, Val Loss: 0.6892
# [Epoch 100/100] Train Loss: 0.6785, Val Loss: 0.6910
# Accuracy on Nonzero Predictions: 0.5649
# 2
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Security type: single_name
# [Epoch 5/100] Train Loss: 0.6938, Val Loss: 0.6936
# [Epoch 10/100] Train Loss: 0.6936, Val Loss: 0.6925
# [Epoch 15/100] Train Loss: 0.6936, Val Loss: 0.6924
# [Epoch 20/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 25/100] Train Loss: 0.6936, Val Loss: 0.6920
# [Epoch 30/100] Train Loss: 0.6936, Val Loss: 0.6925
# [Epoch 35/100] Train Loss: 0.6936, Val Loss: 0.6924
# [Epoch 40/100] Train Loss: 0.6935, Val Loss: 0.6927
# [Epoch 45/100] Train Loss: 0.6924, Val Loss: 0.6880
# [Epoch 50/100] Train Loss: 0.6917, Val Loss: 0.6886
# [Epoch 55/100] Train Loss: 0.6912, Val Loss: 0.6888
# [Epoch 60/100] Train Loss: 0.6906, Val Loss: 0.6837
# [Epoch 65/100] Train Loss: 0.6900, Val Loss: 0.6806
# [Epoch 70/100] Train Loss: 0.6881, Val Loss: 0.6813
# [Epoch 75/100] Train Loss: 0.6877, Val Loss: 0.6807
# [Epoch 80/100] Train Loss: 0.6879, Val Loss: 0.6802
# [Epoch 85/100] Train Loss: 0.6861, Val Loss: 0.6790
# [Epoch 90/100] Train Loss: 0.6844, Val Loss: 0.6792
# [Epoch 95/100] Train Loss: 0.6836, Val Loss: 0.6788
# [Epoch 100/100] Train Loss: 0.6841, Val Loss: 0.6832
# Accuracy on Nonzero Predictions: 0.5267
# 3
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Security type: single_name
# [Epoch 5/100] Train Loss: 0.6939, Val Loss: 0.6930
# [Epoch 10/100] Train Loss: 0.6936, Val Loss: 0.6924
# [Epoch 15/100] Train Loss: 0.6936, Val Loss: 0.6914
# [Epoch 20/100] Train Loss: 0.6933, Val Loss: 0.6870
# [Epoch 25/100] Train Loss: 0.6920, Val Loss: 0.6915
# [Epoch 30/100] Train Loss: 0.6913, Val Loss: 0.6802
# [Epoch 35/100] Train Loss: 0.6904, Val Loss: 0.6786
# [Epoch 40/100] Train Loss: 0.6903, Val Loss: 0.6815
# [Epoch 45/100] Train Loss: 0.6894, Val Loss: 0.6759
# [Epoch 50/100] Train Loss: 0.6879, Val Loss: 0.6731
# [Epoch 55/100] Train Loss: 0.6864, Val Loss: 0.6751
# [Epoch 60/100] Train Loss: 0.6863, Val Loss: 0.6722
# [Epoch 65/100] Train Loss: 0.6847, Val Loss: 0.6679
# [Epoch 70/100] Train Loss: 0.6849, Val Loss: 0.6702
# [Epoch 75/100] Train Loss: 0.6805, Val Loss: 0.6722
# [Epoch 80/100] Train Loss: 0.6814, Val Loss: 0.6703
# [Epoch 85/100] Train Loss: 0.6765, Val Loss: 0.6714
# [Epoch 90/100] Train Loss: 0.6792, Val Loss: 0.6687
# [Epoch 95/100] Train Loss: 0.6775, Val Loss: 0.6735
# [Epoch 100/100] Train Loss: 0.6733, Val Loss: 0.6684
# Accuracy on Nonzero Predictions: 0.5954
# 4
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Security type: single_name
# [Epoch 5/100] Train Loss: 0.6938, Val Loss: 0.6931
# [Epoch 10/100] Train Loss: 0.6937, Val Loss: 0.6926
# [Epoch 15/100] Train Loss: 0.6936, Val Loss: 0.6924
# [Epoch 20/100] Train Loss: 0.6937, Val Loss: 0.6927
# [Epoch 25/100] Train Loss: 0.6934, Val Loss: 0.6923
# [Epoch 30/100] Train Loss: 0.6929, Val Loss: 0.6905
# [Epoch 35/100] Train Loss: 0.6908, Val Loss: 0.6916
# [Epoch 40/100] Train Loss: 0.6911, Val Loss: 0.6915
# [Epoch 45/100] Train Loss: 0.6908, Val Loss: 0.6856
# [Epoch 50/100] Train Loss: 0.6893, Val Loss: 0.6824
# [Epoch 55/100] Train Loss: 0.6875, Val Loss: 0.6849
# [Epoch 60/100] Train Loss: 0.6889, Val Loss: 0.6852
# [Epoch 65/100] Train Loss: 0.6852, Val Loss: 0.6897
# [Epoch 70/100] Train Loss: 0.6843, Val Loss: 0.6873
# [Epoch 75/100] Train Loss: 0.6851, Val Loss: 0.6816
# [Epoch 80/100] Train Loss: 0.6817, Val Loss: 0.6886
# [Epoch 85/100] Train Loss: 0.6786, Val Loss: 0.6885
# [Epoch 90/100] Train Loss: 0.6758, Val Loss: 0.6876
# [Epoch 95/100] Train Loss: 0.6749, Val Loss: 0.6923
# [Epoch 100/100] Train Loss: 0.6715, Val Loss: 0.6900
# Accuracy on Nonzero Predictions: 0.6183
# 5
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Security type: single_name
# [Epoch 5/100] Train Loss: 0.6940, Val Loss: 0.6938
# [Epoch 10/100] Train Loss: 0.6936, Val Loss: 0.6925
# [Epoch 15/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 20/100] Train Loss: 0.6936, Val Loss: 0.6924
# [Epoch 25/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 30/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 35/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 40/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 45/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 50/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 55/100] Train Loss: 0.6936, Val Loss: 0.6925
# [Epoch 60/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 65/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 70/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 75/100] Train Loss: 0.6960, Val Loss: 0.6926
# [Epoch 80/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 85/100] Train Loss: 0.6937, Val Loss: 0.6922
# [Epoch 90/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 95/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 100/100] Train Loss: 0.6936, Val Loss: 0.6923
# Accuracy on Nonzero Predictions: 0.5878
# 6
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Security type: single_name
# [Epoch 5/100] Train Loss: 0.6940, Val Loss: 0.6936
# [Epoch 10/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 15/100] Train Loss: 0.6937, Val Loss: 0.6924
# [Epoch 20/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 25/100] Train Loss: 0.6939, Val Loss: 0.6918
# [Epoch 30/100] Train Loss: 0.6932, Val Loss: 0.6937
# [Epoch 35/100] Train Loss: 0.6921, Val Loss: 0.6909
# [Epoch 40/100] Train Loss: 0.6914, Val Loss: 0.6937
# [Epoch 45/100] Train Loss: 0.6905, Val Loss: 0.6954
# [Epoch 50/100] Train Loss: 0.6906, Val Loss: 0.6933
# [Epoch 55/100] Train Loss: 0.6896, Val Loss: 0.6943
# [Epoch 60/100] Train Loss: 0.6901, Val Loss: 0.6898
# [Epoch 65/100] Train Loss: 0.6886, Val Loss: 0.6903
# [Epoch 70/100] Train Loss: 0.6880, Val Loss: 0.6884
# [Epoch 75/100] Train Loss: 0.6887, Val Loss: 0.6925
# [Epoch 80/100] Train Loss: 0.6864, Val Loss: 0.6947
# [Epoch 85/100] Train Loss: 0.6841, Val Loss: 0.6953
# [Epoch 90/100] Train Loss: 0.6833, Val Loss: 0.6930
# [Epoch 95/100] Train Loss: 0.6838, Val Loss: 0.6941
# [Epoch 100/100] Train Loss: 0.6813, Val Loss: 0.6972
# Accuracy on Nonzero Predictions: 0.4351
# 7
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Security type: single_name
# [Epoch 5/100] Train Loss: 0.6939, Val Loss: 0.6929
# [Epoch 10/100] Train Loss: 0.6936, Val Loss: 0.6925
# [Epoch 15/100] Train Loss: 0.6936, Val Loss: 0.6925
# [Epoch 20/100] Train Loss: 0.6936, Val Loss: 0.6924
# [Epoch 25/100] Train Loss: 0.6936, Val Loss: 0.6925
# [Epoch 30/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 35/100] Train Loss: 0.6935, Val Loss: 0.6923
# [Epoch 40/100] Train Loss: 0.6932, Val Loss: 0.6921
# [Epoch 45/100] Train Loss: 0.6915, Val Loss: 0.6890
# [Epoch 50/100] Train Loss: 0.6910, Val Loss: 0.6842
# [Epoch 55/100] Train Loss: 0.6903, Val Loss: 0.6835
# [Epoch 60/100] Train Loss: 0.6880, Val Loss: 0.6794
# [Epoch 65/100] Train Loss: 0.6882, Val Loss: 0.6849
# [Epoch 70/100] Train Loss: 0.6865, Val Loss: 0.6791
# [Epoch 75/100] Train Loss: 0.6855, Val Loss: 0.6817
# [Epoch 80/100] Train Loss: 0.6837, Val Loss: 0.6776
# [Epoch 85/100] Train Loss: 0.6840, Val Loss: 0.6787
# [Epoch 90/100] Train Loss: 0.6786, Val Loss: 0.6864
# [Epoch 95/100] Train Loss: 0.6812, Val Loss: 0.6814
# [Epoch 100/100] Train Loss: 0.6817, Val Loss: 0.6850
# Accuracy on Nonzero Predictions: 0.5954
# 8
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Security type: single_name
# [Epoch 5/100] Train Loss: 0.6939, Val Loss: 0.6931
# [Epoch 10/100] Train Loss: 0.6937, Val Loss: 0.6926
# [Epoch 15/100] Train Loss: 0.6936, Val Loss: 0.6924
# [Epoch 20/100] Train Loss: 0.6936, Val Loss: 0.6924
# [Epoch 25/100] Train Loss: 0.6936, Val Loss: 0.6926
# [Epoch 30/100] Train Loss: 0.6933, Val Loss: 0.6924
# [Epoch 35/100] Train Loss: 0.6930, Val Loss: 0.6911
# [Epoch 40/100] Train Loss: 0.6922, Val Loss: 0.6893
# [Epoch 45/100] Train Loss: 0.6912, Val Loss: 0.6888
# [Epoch 50/100] Train Loss: 0.6908, Val Loss: 0.6826
# [Epoch 55/100] Train Loss: 0.6885, Val Loss: 0.6828
# [Epoch 60/100] Train Loss: 0.6882, Val Loss: 0.6810
# [Epoch 65/100] Train Loss: 0.6861, Val Loss: 0.6836
# [Epoch 70/100] Train Loss: 0.6832, Val Loss: 0.6813
# [Epoch 75/100] Train Loss: 0.6838, Val Loss: 0.6879
# [Epoch 80/100] Train Loss: 0.6823, Val Loss: 0.6919
# [Epoch 85/100] Train Loss: 0.6809, Val Loss: 0.6904
# [Epoch 90/100] Train Loss: 0.6821, Val Loss: 0.6865
# [Epoch 95/100] Train Loss: 0.6796, Val Loss: 0.6843
# [Epoch 100/100] Train Loss: 0.6768, Val Loss: 0.6822
# Accuracy on Nonzero Predictions: 0.6107
# 9
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Security type: single_name
# [Epoch 5/100] Train Loss: 0.6940, Val Loss: 0.6934
# [Epoch 10/100] Train Loss: 0.6936, Val Loss: 0.6924
# [Epoch 15/100] Train Loss: 0.6936, Val Loss: 0.6924
# [Epoch 20/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 25/100] Train Loss: 0.6936, Val Loss: 0.6922
# [Epoch 30/100] Train Loss: 0.6936, Val Loss: 0.6921
# [Epoch 35/100] Train Loss: 0.6936, Val Loss: 0.6924
# [Epoch 40/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 45/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 50/100] Train Loss: 0.6937, Val Loss: 0.6922
# [Epoch 55/100] Train Loss: 0.6937, Val Loss: 0.6923
# [Epoch 60/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 65/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 70/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 75/100] Train Loss: 0.6936, Val Loss: 0.6924
# [Epoch 80/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 85/100] Train Loss: 0.6944, Val Loss: 0.6930
# [Epoch 90/100] Train Loss: 0.6937, Val Loss: 0.6922
# [Epoch 95/100] Train Loss: 0.6937, Val Loss: 0.6926
# [Epoch 100/100] Train Loss: 0.6926, Val Loss: 0.6971
# Accuracy on Nonzero Predictions: 0.5496
# 10
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Security type: single_name
# [Epoch 5/100] Train Loss: 0.6940, Val Loss: 0.6934
# [Epoch 10/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 15/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 20/100] Train Loss: 0.6935, Val Loss: 0.6923
# [Epoch 25/100] Train Loss: 0.6927, Val Loss: 0.6921
# [Epoch 30/100] Train Loss: 0.6919, Val Loss: 0.6912
# [Epoch 35/100] Train Loss: 0.6912, Val Loss: 0.6900
# [Epoch 40/100] Train Loss: 0.6907, Val Loss: 0.6896
# [Epoch 45/100] Train Loss: 0.6916, Val Loss: 0.6898
# [Epoch 50/100] Train Loss: 0.6910, Val Loss: 0.6911
# [Epoch 55/100] Train Loss: 0.6898, Val Loss: 0.6893
# [Epoch 60/100] Train Loss: 0.6891, Val Loss: 0.6880
# [Epoch 65/100] Train Loss: 0.6887, Val Loss: 0.6868
# [Epoch 70/100] Train Loss: 0.6873, Val Loss: 0.6862
# [Epoch 75/100] Train Loss: 0.6840, Val Loss: 0.6866
# [Epoch 80/100] Train Loss: 0.6841, Val Loss: 0.6829
# [Epoch 85/100] Train Loss: 0.6792, Val Loss: 0.6915
# [Epoch 90/100] Train Loss: 0.6825, Val Loss: 0.6872
# [Epoch 95/100] Train Loss: 0.6793, Val Loss: 0.6827
# [Epoch 100/100] Train Loss: 0.6767, Val Loss: 0.6797
# Accuracy on Nonzero Predictions: 0.5954
# 11
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Security type: single_name
# [Epoch 5/100] Train Loss: 0.6940, Val Loss: 0.6935
# [Epoch 10/100] Train Loss: 0.6937, Val Loss: 0.6925
# [Epoch 15/100] Train Loss: 0.6936, Val Loss: 0.6922
# [Epoch 20/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 25/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 30/100] Train Loss: 0.6936, Val Loss: 0.6920
# [Epoch 35/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 40/100] Train Loss: 0.6936, Val Loss: 0.6922
# [Epoch 45/100] Train Loss: 0.6938, Val Loss: 0.6921
# [Epoch 50/100] Train Loss: 0.6936, Val Loss: 0.6927
# [Epoch 55/100] Train Loss: 0.6937, Val Loss: 0.6923
# [Epoch 60/100] Train Loss: 0.6938, Val Loss: 0.6935
# [Epoch 65/100] Train Loss: 0.6934, Val Loss: 0.6942
# [Epoch 70/100] Train Loss: 0.6917, Val Loss: 0.6889
# [Epoch 75/100] Train Loss: 0.6912, Val Loss: 0.6942
# [Epoch 80/100] Train Loss: 0.6900, Val Loss: 0.6901
# [Epoch 85/100] Train Loss: 0.6880, Val Loss: 0.6955
# [Epoch 90/100] Train Loss: 0.6891, Val Loss: 0.6953
# [Epoch 95/100] Train Loss: 0.6868, Val Loss: 0.6924
# [Epoch 100/100] Train Loss: 0.6880, Val Loss: 0.6949
# Accuracy on Nonzero Predictions: 0.5878
# 12
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Security type: single_name
# [Epoch 5/100] Train Loss: 0.6939, Val Loss: 0.6938
# [Epoch 10/100] Train Loss: 0.6936, Val Loss: 0.6925
# [Epoch 15/100] Train Loss: 0.6936, Val Loss: 0.6925
# [Epoch 20/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 25/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 30/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 35/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 40/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 45/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 50/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 55/100] Train Loss: 0.6935, Val Loss: 0.6923
# [Epoch 60/100] Train Loss: 0.6931, Val Loss: 0.6920
# [Epoch 65/100] Train Loss: 0.6936, Val Loss: 0.6929
# [Epoch 70/100] Train Loss: 0.6928, Val Loss: 0.6915
# [Epoch 75/100] Train Loss: 0.6935, Val Loss: 0.6919
# [Epoch 80/100] Train Loss: 0.6924, Val Loss: 0.6927
# [Epoch 85/100] Train Loss: 0.6919, Val Loss: 0.6857
# [Epoch 90/100] Train Loss: 0.6906, Val Loss: 0.6896
# [Epoch 95/100] Train Loss: 0.6906, Val Loss: 0.6883
# [Epoch 100/100] Train Loss: 0.6893, Val Loss: 0.6933
# Accuracy on Nonzero Predictions: 0.5344
# 13
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Security type: single_name
# [Epoch 5/100] Train Loss: 0.6941, Val Loss: 0.6924
# [Epoch 10/100] Train Loss: 0.6937, Val Loss: 0.6925
# [Epoch 15/100] Train Loss: 0.6936, Val Loss: 0.6925
# [Epoch 20/100] Train Loss: 0.6935, Val Loss: 0.6933
# [Epoch 25/100] Train Loss: 0.6930, Val Loss: 0.6941
# [Epoch 30/100] Train Loss: 0.6918, Val Loss: 0.6966
# [Epoch 35/100] Train Loss: 0.6911, Val Loss: 0.6949
# [Epoch 40/100] Train Loss: 0.6894, Val Loss: 0.6936
# [Epoch 45/100] Train Loss: 0.6895, Val Loss: 0.6944
# [Epoch 50/100] Train Loss: 0.6889, Val Loss: 0.6962
# [Epoch 55/100] Train Loss: 0.6874, Val Loss: 0.6959
# [Epoch 60/100] Train Loss: 0.6870, Val Loss: 0.6940
# [Epoch 65/100] Train Loss: 0.6859, Val Loss: 0.6956
# [Epoch 70/100] Train Loss: 0.6843, Val Loss: 0.6971
# [Epoch 75/100] Train Loss: 0.6844, Val Loss: 0.6986
# [Epoch 80/100] Train Loss: 0.6829, Val Loss: 0.6984
# [Epoch 85/100] Train Loss: 0.6822, Val Loss: 0.7031
# [Epoch 90/100] Train Loss: 0.6802, Val Loss: 0.7020
# [Epoch 95/100] Train Loss: 0.6774, Val Loss: 0.7025
# [Epoch 100/100] Train Loss: 0.6779, Val Loss: 0.7021
# Accuracy on Nonzero Predictions: 0.5038
# 14
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Security type: single_name
# [Epoch 5/100] Train Loss: 0.6940, Val Loss: 0.6932
# [Epoch 10/100] Train Loss: 0.6937, Val Loss: 0.6926
# [Epoch 15/100] Train Loss: 0.6935, Val Loss: 0.6929
# [Epoch 20/100] Train Loss: 0.6930, Val Loss: 0.6933
# [Epoch 25/100] Train Loss: 0.6922, Val Loss: 0.6935
# [Epoch 30/100] Train Loss: 0.6922, Val Loss: 0.6953
# [Epoch 35/100] Train Loss: 0.6915, Val Loss: 0.6954
# [Epoch 40/100] Train Loss: 0.6911, Val Loss: 0.6939
# [Epoch 45/100] Train Loss: 0.6896, Val Loss: 0.6931
# [Epoch 50/100] Train Loss: 0.6901, Val Loss: 0.6945
# [Epoch 55/100] Train Loss: 0.6868, Val Loss: 0.6904
# [Epoch 60/100] Train Loss: 0.6868, Val Loss: 0.6928
# [Epoch 65/100] Train Loss: 0.6849, Val Loss: 0.6893
# [Epoch 70/100] Train Loss: 0.6812, Val Loss: 0.6913
# [Epoch 75/100] Train Loss: 0.6840, Val Loss: 0.6920
# [Epoch 80/100] Train Loss: 0.6813, Val Loss: 0.6934
# [Epoch 85/100] Train Loss: 0.6800, Val Loss: 0.6920
# [Epoch 90/100] Train Loss: 0.6788, Val Loss: 0.6955
# [Epoch 95/100] Train Loss: 0.6790, Val Loss: 0.6903
# [Epoch 100/100] Train Loss: 0.6761, Val Loss: 0.6968
# Accuracy on Nonzero Predictions: 0.5496
# 15
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Security type: single_name
# [Epoch 5/100] Train Loss: 0.6940, Val Loss: 0.6929
# [Epoch 10/100] Train Loss: 0.6936, Val Loss: 0.6926
# [Epoch 15/100] Train Loss: 0.6935, Val Loss: 0.6910
# [Epoch 20/100] Train Loss: 0.6929, Val Loss: 0.6935
# [Epoch 25/100] Train Loss: 0.6920, Val Loss: 0.6935
# [Epoch 30/100] Train Loss: 0.6909, Val Loss: 0.6961
# [Epoch 35/100] Train Loss: 0.6903, Val Loss: 0.6966
# [Epoch 40/100] Train Loss: 0.6904, Val Loss: 0.6949
# [Epoch 45/100] Train Loss: 0.6896, Val Loss: 0.6922
# [Epoch 50/100] Train Loss: 0.6872, Val Loss: 0.6947
# [Epoch 55/100] Train Loss: 0.6866, Val Loss: 0.6990
# [Epoch 60/100] Train Loss: 0.6862, Val Loss: 0.6954
# [Epoch 65/100] Train Loss: 0.6837, Val Loss: 0.6978
# [Epoch 70/100] Train Loss: 0.6849, Val Loss: 0.6968
# [Epoch 75/100] Train Loss: 0.6795, Val Loss: 0.6998
# [Epoch 80/100] Train Loss: 0.6802, Val Loss: 0.7053
# [Epoch 85/100] Train Loss: 0.6812, Val Loss: 0.7089
# [Epoch 90/100] Train Loss: 0.6784, Val Loss: 0.7018
# [Epoch 95/100] Train Loss: 0.6768, Val Loss: 0.7027
# [Epoch 100/100] Train Loss: 0.6748, Val Loss: 0.7102
# Accuracy on Nonzero Predictions: 0.5420
# 16
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Security type: single_name
# [Epoch 5/100] Train Loss: 0.6941, Val Loss: 0.6933
# [Epoch 10/100] Train Loss: 0.6937, Val Loss: 0.6925
# [Epoch 15/100] Train Loss: 0.6934, Val Loss: 0.6923
# [Epoch 20/100] Train Loss: 0.6925, Val Loss: 0.6908
# [Epoch 25/100] Train Loss: 0.6912, Val Loss: 0.6876
# [Epoch 30/100] Train Loss: 0.6902, Val Loss: 0.6876
# [Epoch 35/100] Train Loss: 0.6877, Val Loss: 0.6826
# [Epoch 40/100] Train Loss: 0.6879, Val Loss: 0.6829
# [Epoch 45/100] Train Loss: 0.6865, Val Loss: 0.6863
# [Epoch 50/100] Train Loss: 0.6873, Val Loss: 0.6871
# [Epoch 55/100] Train Loss: 0.6827, Val Loss: 0.6910
# [Epoch 60/100] Train Loss: 0.6795, Val Loss: 0.6840
# [Epoch 65/100] Train Loss: 0.6815, Val Loss: 0.6863
# [Epoch 70/100] Train Loss: 0.6786, Val Loss: 0.6831
# [Epoch 75/100] Train Loss: 0.6782, Val Loss: 0.6831
# [Epoch 80/100] Train Loss: 0.6788, Val Loss: 0.6861
# [Epoch 85/100] Train Loss: 0.6791, Val Loss: 0.6848
# [Epoch 90/100] Train Loss: 0.6767, Val Loss: 0.6813
# [Epoch 95/100] Train Loss: 0.6777, Val Loss: 0.6822
# [Epoch 100/100] Train Loss: 0.6751, Val Loss: 0.6838
# Accuracy on Nonzero Predictions: 0.6183
# 17
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Security type: single_name
# [Epoch 5/100] Train Loss: 0.6938, Val Loss: 0.6929
# [Epoch 10/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 15/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 20/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 25/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 30/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 35/100] Train Loss: 0.6936, Val Loss: 0.6922
# [Epoch 40/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 45/100] Train Loss: 0.6936, Val Loss: 0.6921
# [Epoch 50/100] Train Loss: 0.6936, Val Loss: 0.6922
# [Epoch 55/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 60/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 65/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 70/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 75/100] Train Loss: 0.6937, Val Loss: 0.6923
# [Epoch 80/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 85/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 90/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 95/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 100/100] Train Loss: 0.6936, Val Loss: 0.6923
# Accuracy on Nonzero Predictions: 0.5878
# 18
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Security type: single_name
# [Epoch 5/100] Train Loss: 0.6941, Val Loss: 0.6933
# [Epoch 10/100] Train Loss: 0.6936, Val Loss: 0.6925
# [Epoch 15/100] Train Loss: 0.6936, Val Loss: 0.6925
# [Epoch 20/100] Train Loss: 0.6936, Val Loss: 0.6929
# [Epoch 25/100] Train Loss: 0.6926, Val Loss: 0.6950
# [Epoch 30/100] Train Loss: 0.6918, Val Loss: 0.6953
# [Epoch 35/100] Train Loss: 0.6911, Val Loss: 0.6935
# [Epoch 40/100] Train Loss: 0.6903, Val Loss: 0.6934
# [Epoch 45/100] Train Loss: 0.6896, Val Loss: 0.6944
# [Epoch 50/100] Train Loss: 0.6884, Val Loss: 0.6945
# [Epoch 55/100] Train Loss: 0.6879, Val Loss: 0.6867
# [Epoch 60/100] Train Loss: 0.6880, Val Loss: 0.6833
# [Epoch 65/100] Train Loss: 0.6860, Val Loss: 0.6840
# [Epoch 70/100] Train Loss: 0.6860, Val Loss: 0.6889
# [Epoch 75/100] Train Loss: 0.6840, Val Loss: 0.6775
# [Epoch 80/100] Train Loss: 0.6831, Val Loss: 0.6833
# [Epoch 85/100] Train Loss: 0.6816, Val Loss: 0.6815
# [Epoch 90/100] Train Loss: 0.6822, Val Loss: 0.6881
# [Epoch 95/100] Train Loss: 0.6831, Val Loss: 0.6871
# [Epoch 100/100] Train Loss: 0.6792, Val Loss: 0.6814
# Accuracy on Nonzero Predictions: 0.5267
# 19
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Security type: single_name
# [Epoch 5/100] Train Loss: 0.6940, Val Loss: 0.6927
# [Epoch 10/100] Train Loss: 0.6936, Val Loss: 0.6924
# [Epoch 15/100] Train Loss: 0.6936, Val Loss: 0.6924
# [Epoch 20/100] Train Loss: 0.6937, Val Loss: 0.6916
# [Epoch 25/100] Train Loss: 0.6936, Val Loss: 0.6921
# [Epoch 30/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 35/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 40/100] Train Loss: 0.6935, Val Loss: 0.6923
# [Epoch 45/100] Train Loss: 0.6940, Val Loss: 0.6927
# [Epoch 50/100] Train Loss: 0.6924, Val Loss: 0.6937
# [Epoch 55/100] Train Loss: 0.6918, Val Loss: 0.6903
# [Epoch 60/100] Train Loss: 0.6907, Val Loss: 0.6860
# [Epoch 65/100] Train Loss: 0.6898, Val Loss: 0.6879
# [Epoch 70/100] Train Loss: 0.6893, Val Loss: 0.6883
# [Epoch 75/100] Train Loss: 0.6865, Val Loss: 0.6829
# [Epoch 80/100] Train Loss: 0.6855, Val Loss: 0.6831
# [Epoch 85/100] Train Loss: 0.6866, Val Loss: 0.6823
# [Epoch 90/100] Train Loss: 0.6860, Val Loss: 0.6820
# [Epoch 95/100] Train Loss: 0.6850, Val Loss: 0.6796
# [Epoch 100/100] Train Loss: 0.6824, Val Loss: 0.6805
# Accuracy on Nonzero Predictions: 0.6183
# 20
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Security type: single_name
# [Epoch 5/100] Train Loss: 0.6939, Val Loss: 0.6943
# [Epoch 10/100] Train Loss: 0.6936, Val Loss: 0.6925
# [Epoch 15/100] Train Loss: 0.6936, Val Loss: 0.6924
# [Epoch 20/100] Train Loss: 0.6937, Val Loss: 0.6931
# [Epoch 25/100] Train Loss: 0.6931, Val Loss: 0.6935
# [Epoch 30/100] Train Loss: 0.6926, Val Loss: 0.6905
# [Epoch 35/100] Train Loss: 0.6908, Val Loss: 0.6892
# [Epoch 40/100] Train Loss: 0.6898, Val Loss: 0.6906
# [Epoch 45/100] Train Loss: 0.6896, Val Loss: 0.6875
# [Epoch 50/100] Train Loss: 0.6871, Val Loss: 0.6881
# [Epoch 55/100] Train Loss: 0.6869, Val Loss: 0.6833
# [Epoch 60/100] Train Loss: 0.6877, Val Loss: 0.6851
# [Epoch 65/100] Train Loss: 0.6859, Val Loss: 0.6827
# [Epoch 70/100] Train Loss: 0.6847, Val Loss: 0.6884
# [Epoch 75/100] Train Loss: 0.6860, Val Loss: 0.6823
# [Epoch 80/100] Train Loss: 0.6820, Val Loss: 0.6773
# [Epoch 85/100] Train Loss: 0.6812, Val Loss: 0.6854
# [Epoch 90/100] Train Loss: 0.6801, Val Loss: 0.6746
# [Epoch 95/100] Train Loss: 0.6751, Val Loss: 0.6840
# [Epoch 100/100] Train Loss: 0.6771, Val Loss: 0.6752
# Accuracy on Nonzero Predictions: 0.5725
# 21
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Security type: single_name
# [Epoch 5/100] Train Loss: 0.6940, Val Loss: 0.6935
# [Epoch 10/100] Train Loss: 0.6936, Val Loss: 0.6926
# [Epoch 15/100] Train Loss: 0.6936, Val Loss: 0.6925
# [Epoch 20/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 25/100] Train Loss: 0.6936, Val Loss: 0.6922
# [Epoch 30/100] Train Loss: 0.6937, Val Loss: 0.6923
# [Epoch 35/100] Train Loss: 0.6936, Val Loss: 0.6927
# [Epoch 40/100] Train Loss: 0.6933, Val Loss: 0.6908
# [Epoch 45/100] Train Loss: 0.6910, Val Loss: 0.6914
# [Epoch 50/100] Train Loss: 0.6911, Val Loss: 0.6927
# [Epoch 55/100] Train Loss: 0.6906, Val Loss: 0.6951
# [Epoch 60/100] Train Loss: 0.6891, Val Loss: 0.6966
# [Epoch 65/100] Train Loss: 0.6900, Val Loss: 0.6922
# [Epoch 70/100] Train Loss: 0.6872, Val Loss: 0.6953
# [Epoch 75/100] Train Loss: 0.6875, Val Loss: 0.6911
# [Epoch 80/100] Train Loss: 0.6853, Val Loss: 0.6937
# [Epoch 85/100] Train Loss: 0.6841, Val Loss: 0.6972
# [Epoch 90/100] Train Loss: 0.6850, Val Loss: 0.6935
# [Epoch 95/100] Train Loss: 0.6814, Val Loss: 0.7003
# [Epoch 100/100] Train Loss: 0.6801, Val Loss: 0.6955
# Accuracy on Nonzero Predictions: 0.5496
# 22
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Security type: single_name
# [Epoch 5/100] Train Loss: 0.6938, Val Loss: 0.6933
# [Epoch 10/100] Train Loss: 0.6936, Val Loss: 0.6926
# [Epoch 15/100] Train Loss: 0.6936, Val Loss: 0.6924
# [Epoch 20/100] Train Loss: 0.6937, Val Loss: 0.6923
# [Epoch 25/100] Train Loss: 0.6936, Val Loss: 0.6920
# [Epoch 30/100] Train Loss: 0.6936, Val Loss: 0.6915
# [Epoch 35/100] Train Loss: 0.6932, Val Loss: 0.6910
# [Epoch 40/100] Train Loss: 0.6924, Val Loss: 0.6925
# [Epoch 45/100] Train Loss: 0.6927, Val Loss: 0.6988
# [Epoch 50/100] Train Loss: 0.6913, Val Loss: 0.7001
# [Epoch 55/100] Train Loss: 0.6902, Val Loss: 0.7020
# [Epoch 60/100] Train Loss: 0.6912, Val Loss: 0.6946
# [Epoch 65/100] Train Loss: 0.6891, Val Loss: 0.6957
# [Epoch 70/100] Train Loss: 0.6890, Val Loss: 0.6964
# [Epoch 75/100] Train Loss: 0.6872, Val Loss: 0.6946
# [Epoch 80/100] Train Loss: 0.6889, Val Loss: 0.6982
# [Epoch 85/100] Train Loss: 0.6861, Val Loss: 0.6948
# [Epoch 90/100] Train Loss: 0.6856, Val Loss: 0.6992
# [Epoch 95/100] Train Loss: 0.6851, Val Loss: 0.6949
# [Epoch 100/100] Train Loss: 0.6864, Val Loss: 0.6921
# Accuracy on Nonzero Predictions: 0.5344
# 23
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Security type: single_name
# [Epoch 5/100] Train Loss: 0.6940, Val Loss: 0.6937
# [Epoch 10/100] Train Loss: 0.6936, Val Loss: 0.6924
# [Epoch 15/100] Train Loss: 0.6936, Val Loss: 0.6924
# [Epoch 20/100] Train Loss: 0.6935, Val Loss: 0.6922
# [Epoch 25/100] Train Loss: 0.6931, Val Loss: 0.6930
# [Epoch 30/100] Train Loss: 0.6922, Val Loss: 0.6908
# [Epoch 35/100] Train Loss: 0.6922, Val Loss: 0.6907
# [Epoch 40/100] Train Loss: 0.6915, Val Loss: 0.6899
# [Epoch 45/100] Train Loss: 0.6905, Val Loss: 0.6860
# [Epoch 50/100] Train Loss: 0.6906, Val Loss: 0.6890
# [Epoch 55/100] Train Loss: 0.6891, Val Loss: 0.6864
# [Epoch 60/100] Train Loss: 0.6882, Val Loss: 0.6892
# [Epoch 65/100] Train Loss: 0.6877, Val Loss: 0.6877
# [Epoch 70/100] Train Loss: 0.6835, Val Loss: 0.6869
# [Epoch 75/100] Train Loss: 0.6880, Val Loss: 0.6929
# [Epoch 80/100] Train Loss: 0.6835, Val Loss: 0.6920
# [Epoch 85/100] Train Loss: 0.6856, Val Loss: 0.6865
# [Epoch 90/100] Train Loss: 0.6830, Val Loss: 0.6917
# [Epoch 95/100] Train Loss: 0.6825, Val Loss: 0.6886
# [Epoch 100/100] Train Loss: 0.6841, Val Loss: 0.6816
# Accuracy on Nonzero Predictions: 0.5649
# 24
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Security type: single_name
# [Epoch 5/100] Train Loss: 0.6938, Val Loss: 0.6942
# [Epoch 10/100] Train Loss: 0.6937, Val Loss: 0.6925
# [Epoch 15/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 20/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 25/100] Train Loss: 0.6937, Val Loss: 0.6923
# [Epoch 30/100] Train Loss: 0.6932, Val Loss: 0.6920
# [Epoch 35/100] Train Loss: 0.6934, Val Loss: 0.6906
# [Epoch 40/100] Train Loss: 0.6926, Val Loss: 0.6898
# [Epoch 45/100] Train Loss: 0.6924, Val Loss: 0.6880
# [Epoch 50/100] Train Loss: 0.6904, Val Loss: 0.6860
# [Epoch 55/100] Train Loss: 0.6894, Val Loss: 0.6829
# [Epoch 60/100] Train Loss: 0.6904, Val Loss: 0.6832
# [Epoch 65/100] Train Loss: 0.6897, Val Loss: 0.6830
# [Epoch 70/100] Train Loss: 0.6891, Val Loss: 0.6871
# [Epoch 75/100] Train Loss: 0.6875, Val Loss: 0.6853
# [Epoch 80/100] Train Loss: 0.6849, Val Loss: 0.6860
# [Epoch 85/100] Train Loss: 0.6840, Val Loss: 0.6869
# [Epoch 90/100] Train Loss: 0.6817, Val Loss: 0.6884
# [Epoch 95/100] Train Loss: 0.6840, Val Loss: 0.6894
# [Epoch 100/100] Train Loss: 0.6810, Val Loss: 0.6965
# Accuracy on Nonzero Predictions: 0.4504
# 25
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Security type: single_name
# [Epoch 5/100] Train Loss: 0.6941, Val Loss: 0.6934
# [Epoch 10/100] Train Loss: 0.6936, Val Loss: 0.6922
# [Epoch 15/100] Train Loss: 0.6936, Val Loss: 0.6927
# [Epoch 20/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 25/100] Train Loss: 0.6931, Val Loss: 0.6923
# [Epoch 30/100] Train Loss: 0.6919, Val Loss: 0.6885
# [Epoch 35/100] Train Loss: 0.6914, Val Loss: 0.6884
# [Epoch 40/100] Train Loss: 0.6917, Val Loss: 0.6896
# [Epoch 45/100] Train Loss: 0.6911, Val Loss: 0.6855
# [Epoch 50/100] Train Loss: 0.6890, Val Loss: 0.6846
# [Epoch 55/100] Train Loss: 0.6890, Val Loss: 0.6898
# [Epoch 60/100] Train Loss: 0.6884, Val Loss: 0.6877
# [Epoch 65/100] Train Loss: 0.6887, Val Loss: 0.6880
# [Epoch 70/100] Train Loss: 0.6837, Val Loss: 0.6848
# [Epoch 75/100] Train Loss: 0.6850, Val Loss: 0.6837
# [Epoch 80/100] Train Loss: 0.6840, Val Loss: 0.6837
# [Epoch 85/100] Train Loss: 0.6815, Val Loss: 0.6764
# [Epoch 90/100] Train Loss: 0.6795, Val Loss: 0.6747
# [Epoch 95/100] Train Loss: 0.6780, Val Loss: 0.6782
# [Epoch 100/100] Train Loss: 0.6771, Val Loss: 0.6800
# Accuracy on Nonzero Predictions: 0.4962
# 26
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Security type: single_name
# [Epoch 5/100] Train Loss: 0.6938, Val Loss: 0.6934
# [Epoch 10/100] Train Loss: 0.6936, Val Loss: 0.6926
# [Epoch 15/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 20/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 25/100] Train Loss: 0.6929, Val Loss: 0.6902
# [Epoch 30/100] Train Loss: 0.6912, Val Loss: 0.6922
# [Epoch 35/100] Train Loss: 0.6922, Val Loss: 0.6936
# [Epoch 40/100] Train Loss: 0.6892, Val Loss: 0.6881
# [Epoch 45/100] Train Loss: 0.6894, Val Loss: 0.6895
# [Epoch 50/100] Train Loss: 0.6880, Val Loss: 0.6893
# [Epoch 55/100] Train Loss: 0.6847, Val Loss: 0.6933
# [Epoch 60/100] Train Loss: 0.6882, Val Loss: 0.6934
# [Epoch 65/100] Train Loss: 0.6868, Val Loss: 0.6966
# [Epoch 70/100] Train Loss: 0.6848, Val Loss: 0.7030
# [Epoch 75/100] Train Loss: 0.6845, Val Loss: 0.6955
# [Epoch 80/100] Train Loss: 0.6816, Val Loss: 0.7064
# [Epoch 85/100] Train Loss: 0.6800, Val Loss: 0.7057
# [Epoch 90/100] Train Loss: 0.6793, Val Loss: 0.7048
# [Epoch 95/100] Train Loss: 0.6805, Val Loss: 0.7116
# [Epoch 100/100] Train Loss: 0.6782, Val Loss: 0.6989
# Accuracy on Nonzero Predictions: 0.4733
# 27
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Security type: single_name
# [Epoch 5/100] Train Loss: 0.6939, Val Loss: 0.6928
# [Epoch 10/100] Train Loss: 0.6936, Val Loss: 0.6924
# [Epoch 15/100] Train Loss: 0.6936, Val Loss: 0.6922
# [Epoch 20/100] Train Loss: 0.6933, Val Loss: 0.6923
# [Epoch 25/100] Train Loss: 0.6921, Val Loss: 0.6917
# [Epoch 30/100] Train Loss: 0.6924, Val Loss: 0.6917
# [Epoch 35/100] Train Loss: 0.6917, Val Loss: 0.6890
# [Epoch 40/100] Train Loss: 0.6910, Val Loss: 0.6887
# [Epoch 45/100] Train Loss: 0.6894, Val Loss: 0.6902
# [Epoch 50/100] Train Loss: 0.6892, Val Loss: 0.6860
# [Epoch 55/100] Train Loss: 0.6888, Val Loss: 0.6876
# [Epoch 60/100] Train Loss: 0.6859, Val Loss: 0.6860
# [Epoch 65/100] Train Loss: 0.6851, Val Loss: 0.6869
# [Epoch 70/100] Train Loss: 0.6848, Val Loss: 0.6850
# [Epoch 75/100] Train Loss: 0.6839, Val Loss: 0.6848
# [Epoch 80/100] Train Loss: 0.6826, Val Loss: 0.6848
# [Epoch 85/100] Train Loss: 0.6808, Val Loss: 0.6878
# [Epoch 90/100] Train Loss: 0.6807, Val Loss: 0.6864
# [Epoch 95/100] Train Loss: 0.6781, Val Loss: 0.6946
# [Epoch 100/100] Train Loss: 0.6753, Val Loss: 0.6907
# Accuracy on Nonzero Predictions: 0.5267
# 28
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Security type: single_name
# [Epoch 5/100] Train Loss: 0.6939, Val Loss: 0.6936
# [Epoch 10/100] Train Loss: 0.6936, Val Loss: 0.6924
# [Epoch 15/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 20/100] Train Loss: 0.6930, Val Loss: 0.6935
# [Epoch 25/100] Train Loss: 0.6920, Val Loss: 0.6849
# [Epoch 30/100] Train Loss: 0.6905, Val Loss: 0.6886
# [Epoch 35/100] Train Loss: 0.6902, Val Loss: 0.6832
# [Epoch 40/100] Train Loss: 0.6896, Val Loss: 0.6844
# [Epoch 45/100] Train Loss: 0.6879, Val Loss: 0.6813
# [Epoch 50/100] Train Loss: 0.6877, Val Loss: 0.6811
# [Epoch 55/100] Train Loss: 0.6864, Val Loss: 0.6831
# [Epoch 60/100] Train Loss: 0.6869, Val Loss: 0.6833
# [Epoch 65/100] Train Loss: 0.6838, Val Loss: 0.6796
# [Epoch 70/100] Train Loss: 0.6823, Val Loss: 0.6776
# [Epoch 75/100] Train Loss: 0.6804, Val Loss: 0.6783
# [Epoch 80/100] Train Loss: 0.6827, Val Loss: 0.6789
# [Epoch 85/100] Train Loss: 0.6794, Val Loss: 0.6776
# [Epoch 90/100] Train Loss: 0.6781, Val Loss: 0.6795
# [Epoch 95/100] Train Loss: 0.6790, Val Loss: 0.6818
# [Epoch 100/100] Train Loss: 0.6736, Val Loss: 0.6760
# Accuracy on Nonzero Predictions: 0.5344
# 29
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Security type: single_name
# [Epoch 5/100] Train Loss: 0.6939, Val Loss: 0.6933
# [Epoch 10/100] Train Loss: 0.6936, Val Loss: 0.6922
# [Epoch 15/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 20/100] Train Loss: 0.6936, Val Loss: 0.6922
# [Epoch 25/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 30/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 35/100] Train Loss: 0.6936, Val Loss: 0.6922
# [Epoch 40/100] Train Loss: 0.6936, Val Loss: 0.6917
# [Epoch 45/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 50/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 55/100] Train Loss: 0.6936, Val Loss: 0.6922
# [Epoch 60/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 65/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 70/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 75/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 80/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 85/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 90/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 95/100] Train Loss: 0.6989, Val Loss: 0.6866
# [Epoch 100/100] Train Loss: 0.6934, Val Loss: 0.6912
# Accuracy on Nonzero Predictions: 0.5878
# 30
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Security type: single_name
# [Epoch 5/100] Train Loss: 0.6938, Val Loss: 0.6937
# [Epoch 10/100] Train Loss: 0.6936, Val Loss: 0.6924
# [Epoch 15/100] Train Loss: 0.6937, Val Loss: 0.6926
# [Epoch 20/100] Train Loss: 0.6938, Val Loss: 0.6924
# [Epoch 25/100] Train Loss: 0.6931, Val Loss: 0.6924
# [Epoch 30/100] Train Loss: 0.6921, Val Loss: 0.6914
# [Epoch 35/100] Train Loss: 0.6925, Val Loss: 0.6907
# [Epoch 40/100] Train Loss: 0.6918, Val Loss: 0.6861
# [Epoch 45/100] Train Loss: 0.6917, Val Loss: 0.6873
# [Epoch 50/100] Train Loss: 0.6899, Val Loss: 0.6854
# [Epoch 55/100] Train Loss: 0.6862, Val Loss: 0.6869
# [Epoch 60/100] Train Loss: 0.6872, Val Loss: 0.6893
# [Epoch 65/100] Train Loss: 0.6841, Val Loss: 0.6908
# [Epoch 70/100] Train Loss: 0.6834, Val Loss: 0.6915
# [Epoch 75/100] Train Loss: 0.6816, Val Loss: 0.6901
# [Epoch 80/100] Train Loss: 0.6847, Val Loss: 0.6865
# [Epoch 85/100] Train Loss: 0.6807, Val Loss: 0.6839
# [Epoch 90/100] Train Loss: 0.6816, Val Loss: 0.6792
# [Epoch 95/100] Train Loss: 0.6780, Val Loss: 0.6797
# [Epoch 100/100] Train Loss: 0.6800, Val Loss: 0.6870
# Accuracy on Nonzero Predictions: 0.5573
# 31
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Security type: single_name
# [Epoch 5/100] Train Loss: 0.6939, Val Loss: 0.6925
# [Epoch 10/100] Train Loss: 0.6936, Val Loss: 0.6926
# [Epoch 15/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 20/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 25/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 30/100] Train Loss: 0.6936, Val Loss: 0.6921
# [Epoch 35/100] Train Loss: 0.6932, Val Loss: 0.6926
# [Epoch 40/100] Train Loss: 0.6922, Val Loss: 0.6881
# [Epoch 45/100] Train Loss: 0.6911, Val Loss: 0.6889
# [Epoch 50/100] Train Loss: 0.6915, Val Loss: 0.6904
# [Epoch 55/100] Train Loss: 0.6907, Val Loss: 0.6809
# [Epoch 60/100] Train Loss: 0.6888, Val Loss: 0.6889
# [Epoch 65/100] Train Loss: 0.6872, Val Loss: 0.6880
# [Epoch 70/100] Train Loss: 0.6885, Val Loss: 0.6911
# [Epoch 75/100] Train Loss: 0.6882, Val Loss: 0.6877
# [Epoch 80/100] Train Loss: 0.6880, Val Loss: 0.6854
# [Epoch 85/100] Train Loss: 0.6851, Val Loss: 0.6830
# [Epoch 90/100] Train Loss: 0.6838, Val Loss: 0.6835
# [Epoch 95/100] Train Loss: 0.6828, Val Loss: 0.6765
# [Epoch 100/100] Train Loss: 0.6837, Val Loss: 0.6825
# Accuracy on Nonzero Predictions: 0.5878
# 32
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Security type: single_name
# [Epoch 5/100] Train Loss: 0.6938, Val Loss: 0.6937
# [Epoch 10/100] Train Loss: 0.6936, Val Loss: 0.6925
# [Epoch 15/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 20/100] Train Loss: 0.6936, Val Loss: 0.6921
# [Epoch 25/100] Train Loss: 0.6936, Val Loss: 0.6913
# [Epoch 30/100] Train Loss: 0.6932, Val Loss: 0.6924
# [Epoch 35/100] Train Loss: 0.6933, Val Loss: 0.6912
# [Epoch 40/100] Train Loss: 0.6914, Val Loss: 0.6883
# [Epoch 45/100] Train Loss: 0.6921, Val Loss: 0.6871
# [Epoch 50/100] Train Loss: 0.6910, Val Loss: 0.6869
# [Epoch 55/100] Train Loss: 0.6883, Val Loss: 0.6819
# [Epoch 60/100] Train Loss: 0.6877, Val Loss: 0.6822
# [Epoch 65/100] Train Loss: 0.6864, Val Loss: 0.6830
# [Epoch 70/100] Train Loss: 0.6870, Val Loss: 0.6843
# [Epoch 75/100] Train Loss: 0.6853, Val Loss: 0.6847
# [Epoch 80/100] Train Loss: 0.6832, Val Loss: 0.6828
# [Epoch 85/100] Train Loss: 0.6864, Val Loss: 0.6898
# [Epoch 90/100] Train Loss: 0.6846, Val Loss: 0.6855
# [Epoch 95/100] Train Loss: 0.6811, Val Loss: 0.6862
# [Epoch 100/100] Train Loss: 0.6772, Val Loss: 0.6859
# Accuracy on Nonzero Predictions: 0.6107
# 33
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Security type: single_name
# [Epoch 5/100] Train Loss: 0.6939, Val Loss: 0.6935
# [Epoch 10/100] Train Loss: 0.6937, Val Loss: 0.6926
# [Epoch 15/100] Train Loss: 0.6936, Val Loss: 0.6921
# [Epoch 20/100] Train Loss: 0.6936, Val Loss: 0.6925
# [Epoch 25/100] Train Loss: 0.6928, Val Loss: 0.6908
# [Epoch 30/100] Train Loss: 0.6927, Val Loss: 0.6908
# [Epoch 35/100] Train Loss: 0.6910, Val Loss: 0.6867
# [Epoch 40/100] Train Loss: 0.6900, Val Loss: 0.6852
# [Epoch 45/100] Train Loss: 0.6904, Val Loss: 0.6871
# [Epoch 50/100] Train Loss: 0.6897, Val Loss: 0.6874
# [Epoch 55/100] Train Loss: 0.6869, Val Loss: 0.6878
# [Epoch 60/100] Train Loss: 0.6865, Val Loss: 0.6894
# [Epoch 65/100] Train Loss: 0.6855, Val Loss: 0.6895
# [Epoch 70/100] Train Loss: 0.6844, Val Loss: 0.6892
# [Epoch 75/100] Train Loss: 0.6848, Val Loss: 0.6894
# [Epoch 80/100] Train Loss: 0.6841, Val Loss: 0.6900
# [Epoch 85/100] Train Loss: 0.6830, Val Loss: 0.6919
# [Epoch 90/100] Train Loss: 0.6819, Val Loss: 0.6925
# [Epoch 95/100] Train Loss: 0.6789, Val Loss: 0.6927
# [Epoch 100/100] Train Loss: 0.6792, Val Loss: 0.6891
# Accuracy on Nonzero Predictions: 0.5573
# 34
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Security type: single_name
# [Epoch 5/100] Train Loss: 0.6938, Val Loss: 0.6928
# [Epoch 10/100] Train Loss: 0.6936, Val Loss: 0.6925
# [Epoch 15/100] Train Loss: 0.6936, Val Loss: 0.6924
# [Epoch 20/100] Train Loss: 0.6936, Val Loss: 0.6926
# [Epoch 25/100] Train Loss: 0.6936, Val Loss: 0.6927
# [Epoch 30/100] Train Loss: 0.6927, Val Loss: 0.6915
# [Epoch 35/100] Train Loss: 0.6921, Val Loss: 0.6914
# [Epoch 40/100] Train Loss: 0.6920, Val Loss: 0.6900
# [Epoch 45/100] Train Loss: 0.6903, Val Loss: 0.6851
# [Epoch 50/100] Train Loss: 0.6898, Val Loss: 0.6891
# [Epoch 55/100] Train Loss: 0.6889, Val Loss: 0.6876
# [Epoch 60/100] Train Loss: 0.6880, Val Loss: 0.6887
# [Epoch 65/100] Train Loss: 0.6880, Val Loss: 0.6893
# [Epoch 70/100] Train Loss: 0.6872, Val Loss: 0.6896
# [Epoch 75/100] Train Loss: 0.6848, Val Loss: 0.6899
# [Epoch 80/100] Train Loss: 0.6835, Val Loss: 0.6926
# [Epoch 85/100] Train Loss: 0.6835, Val Loss: 0.6885
# [Epoch 90/100] Train Loss: 0.6789, Val Loss: 0.6919
# [Epoch 95/100] Train Loss: 0.6801, Val Loss: 0.6887
# [Epoch 100/100] Train Loss: 0.6824, Val Loss: 0.6885
# Accuracy on Nonzero Predictions: 0.5649
# 35
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Security type: single_name
# [Epoch 5/100] Train Loss: 0.6940, Val Loss: 0.6936
# [Epoch 10/100] Train Loss: 0.6936, Val Loss: 0.6929
# [Epoch 15/100] Train Loss: 0.6936, Val Loss: 0.6924
# [Epoch 20/100] Train Loss: 0.6936, Val Loss: 0.6925
# [Epoch 25/100] Train Loss: 0.6936, Val Loss: 0.6919
# [Epoch 30/100] Train Loss: 0.6928, Val Loss: 0.6923
# [Epoch 35/100] Train Loss: 0.6920, Val Loss: 0.6927
# [Epoch 40/100] Train Loss: 0.6921, Val Loss: 0.6916
# [Epoch 45/100] Train Loss: 0.6897, Val Loss: 0.6849
# [Epoch 50/100] Train Loss: 0.6898, Val Loss: 0.6855
# [Epoch 55/100] Train Loss: 0.6878, Val Loss: 0.6832
# [Epoch 60/100] Train Loss: 0.6855, Val Loss: 0.6839
# [Epoch 65/100] Train Loss: 0.6830, Val Loss: 0.6852
# [Epoch 70/100] Train Loss: 0.6854, Val Loss: 0.6778
# [Epoch 75/100] Train Loss: 0.6839, Val Loss: 0.6826
# [Epoch 80/100] Train Loss: 0.6824, Val Loss: 0.6804
# [Epoch 85/100] Train Loss: 0.6784, Val Loss: 0.6809
# [Epoch 90/100] Train Loss: 0.6774, Val Loss: 0.6756
# [Epoch 95/100] Train Loss: 0.6790, Val Loss: 0.6795
# [Epoch 100/100] Train Loss: 0.6772, Val Loss: 0.6809
# Accuracy on Nonzero Predictions: 0.6031
# 36
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Security type: single_name
# [Epoch 5/100] Train Loss: 0.6939, Val Loss: 0.6935
# [Epoch 10/100] Train Loss: 0.6936, Val Loss: 0.6925
# [Epoch 15/100] Train Loss: 0.6936, Val Loss: 0.6924
# [Epoch 20/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 25/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 30/100] Train Loss: 0.6935, Val Loss: 0.6925
# [Epoch 35/100] Train Loss: 0.6936, Val Loss: 0.6922
# [Epoch 40/100] Train Loss: 0.6936, Val Loss: 0.6922
# [Epoch 45/100] Train Loss: 0.6935, Val Loss: 0.6924
# [Epoch 50/100] Train Loss: 0.6935, Val Loss: 0.6924
# [Epoch 55/100] Train Loss: 0.6926, Val Loss: 0.6920
# [Epoch 60/100] Train Loss: 0.6926, Val Loss: 0.6909
# [Epoch 65/100] Train Loss: 0.6927, Val Loss: 0.6896
# [Epoch 70/100] Train Loss: 0.6911, Val Loss: 0.6908
# [Epoch 75/100] Train Loss: 0.6910, Val Loss: 0.6917
# [Epoch 80/100] Train Loss: 0.6893, Val Loss: 0.6916
# [Epoch 85/100] Train Loss: 0.6880, Val Loss: 0.6917
# [Epoch 90/100] Train Loss: 0.6857, Val Loss: 0.6980
# [Epoch 95/100] Train Loss: 0.6870, Val Loss: 0.6931
# [Epoch 100/100] Train Loss: 0.6853, Val Loss: 0.6908
# Accuracy on Nonzero Predictions: 0.5954
# 37
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Security type: single_name
# [Epoch 5/100] Train Loss: 0.6941, Val Loss: 0.6955
# [Epoch 10/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 15/100] Train Loss: 0.6936, Val Loss: 0.6922
# [Epoch 20/100] Train Loss: 0.6929, Val Loss: 0.6923
# [Epoch 25/100] Train Loss: 0.6926, Val Loss: 0.6914
# [Epoch 30/100] Train Loss: 0.6923, Val Loss: 0.6917
# [Epoch 35/100] Train Loss: 0.6915, Val Loss: 0.6899
# [Epoch 40/100] Train Loss: 0.6909, Val Loss: 0.6910
# [Epoch 45/100] Train Loss: 0.6907, Val Loss: 0.6859
# [Epoch 50/100] Train Loss: 0.6874, Val Loss: 0.6896
# [Epoch 55/100] Train Loss: 0.6883, Val Loss: 0.6875
# [Epoch 60/100] Train Loss: 0.6889, Val Loss: 0.6891
# [Epoch 65/100] Train Loss: 0.6860, Val Loss: 0.6866
# [Epoch 70/100] Train Loss: 0.6854, Val Loss: 0.6834
# [Epoch 75/100] Train Loss: 0.6828, Val Loss: 0.6890
# [Epoch 80/100] Train Loss: 0.6824, Val Loss: 0.6928
# [Epoch 85/100] Train Loss: 0.6807, Val Loss: 0.6988
# [Epoch 90/100] Train Loss: 0.6800, Val Loss: 0.7012
# [Epoch 95/100] Train Loss: 0.6777, Val Loss: 0.7005
# [Epoch 100/100] Train Loss: 0.6786, Val Loss: 0.6957
# Accuracy on Nonzero Predictions: 0.6107
# 38
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Security type: single_name
# [Epoch 5/100] Train Loss: 0.6939, Val Loss: 0.6938
# [Epoch 10/100] Train Loss: 0.6936, Val Loss: 0.6924
# [Epoch 15/100] Train Loss: 0.6936, Val Loss: 0.6922
# [Epoch 20/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 25/100] Train Loss: 0.6936, Val Loss: 0.6921
# [Epoch 30/100] Train Loss: 0.6940, Val Loss: 0.6918
# [Epoch 35/100] Train Loss: 0.6937, Val Loss: 0.6925
# [Epoch 40/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 45/100] Train Loss: 0.6936, Val Loss: 0.6923
# [Epoch 50/100] Train Loss: 0.6936, Val Loss: 0.6926
# [Epoch 55/100] Train Loss: 0.6937, Val Loss: 0.6895
# [Epoch 60/100] Train Loss: 0.6927, Val Loss: 0.6921
# [Epoch 65/100] Train Loss: 0.6921, Val Loss: 0.6910
# [Epoch 70/100] Train Loss: 0.6910, Val Loss: 0.6880
# [Epoch 75/100] Train Loss: 0.6888, Val Loss: 0.6837
# [Epoch 80/100] Train Loss: 0.6904, Val Loss: 0.6835
# [Epoch 85/100] Train Loss: 0.6875, Val Loss: 0.6887
# [Epoch 90/100] Train Loss: 0.6884, Val Loss: 0.6849
# [Epoch 95/100] Train Loss: 0.6870, Val Loss: 0.6849
# [Epoch 100/100] Train Loss: 0.6879, Val Loss: 0.6889
# Accuracy on Nonzero Predictions: 0.4809
# 39
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Security type: single_name
# [Epoch 5/100] Train Loss: 0.6939, Val Loss: 0.6934
# [Epoch 10/100] Train Loss: 0.6936, Val Loss: 0.6924
# [Epoch 15/100] Train Loss: 0.6936, Val Loss: 0.6924
# [Epoch 20/100] Train Loss: 0.6938, Val Loss: 0.6923
# [Epoch 25/100] Train Loss: 0.6933, Val Loss: 0.6914
# [Epoch 30/100] Train Loss: 0.6923, Val Loss: 0.6863
# [Epoch 35/100] Train Loss: 0.6925, Val Loss: 0.6908
# [Epoch 40/100] Train Loss: 0.6907, Val Loss: 0.6879
# [Epoch 45/100] Train Loss: 0.6905, Val Loss: 0.6886
# [Epoch 50/100] Train Loss: 0.6904, Val Loss: 0.6878
# [Epoch 55/100] Train Loss: 0.6893, Val Loss: 0.6868
# [Epoch 60/100] Train Loss: 0.6903, Val Loss: 0.6863
# [Epoch 65/100] Train Loss: 0.6872, Val Loss: 0.6849
# [Epoch 70/100] Train Loss: 0.6855, Val Loss: 0.6882
# [Epoch 75/100] Train Loss: 0.6864, Val Loss: 0.6872
# [Epoch 80/100] Train Loss: 0.6866, Val Loss: 0.6884
# [Epoch 85/100] Train Loss: 0.6838, Val Loss: 0.6930
# [Epoch 90/100] Train Loss: 0.6830, Val Loss: 0.6904
# [Epoch 95/100] Train Loss: 0.6801, Val Loss: 0.6910
# [Epoch 100/100] Train Loss: 0.6811, Val Loss: 0.6945
# Accuracy on Nonzero Predictions: 0.5878
# 40
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Security type: single_name
# [Epoch 5/100] Train Loss: 0.6940, Val Loss: 0.6926
# [Epoch 10/100] Train Loss: 0.6937, Val Loss: 0.6924
# [Epoch 15/100] Train Loss: 0.6936, Val Loss: 0.6921
# [Epoch 20/100] Train Loss: 0.6932, Val Loss: 0.6919
# [Epoch 25/100] Train Loss: 0.6930, Val Loss: 0.6919
# [Epoch 30/100] Train Loss: 0.6918, Val Loss: 0.6925
# [Epoch 35/100] Train Loss: 0.6915, Val Loss: 0.6887
# [Epoch 40/100] Train Loss: 0.6899, Val Loss: 0.6868
# [Epoch 45/100] Train Loss: 0.6902, Val Loss: 0.6891
# [Epoch 50/100] Train Loss: 0.6913, Val Loss: 0.6895
# [Epoch 55/100] Train Loss: 0.6901, Val Loss: 0.6879
# [Epoch 60/100] Train Loss: 0.6879, Val Loss: 0.6879
# [Epoch 65/100] Train Loss: 0.6873, Val Loss: 0.6842
# [Epoch 70/100] Train Loss: 0.6881, Val Loss: 0.6904
# [Epoch 75/100] Train Loss: 0.6850, Val Loss: 0.6840
# [Epoch 80/100] Train Loss: 0.6815, Val Loss: 0.6825
# [Epoch 85/100] Train Loss: 0.6818, Val Loss: 0.6870
# [Epoch 90/100] Train Loss: 0.6827, Val Loss: 0.6833
# [Epoch 95/100] Train Loss: 0.6780, Val Loss: 0.6832
# [Epoch 100/100] Train Loss: 0.6805, Val Loss: 0.6790
# Accuracy on Nonzero Predictions: 0.5191
# 41
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Security type: single_name
# [Epoch 5/100] Train Loss: 0.6939, Val Loss: 0.6940
# [Epoch 10/100] Train Loss: 0.6936, Val Loss: 0.6924
# [Epoch 15/100] Train Loss: 0.6936, Val Loss: 0.6922
# ...
# [Epoch 25/100] Train Loss: 0.6958, Val Loss: 0.6822
# [Epoch 30/100] Train Loss: 0.6971, Val Loss: 0.6829
# [Epoch 35/100] Train Loss: 0.6951, Val Loss: 0.6845
# [Epoch 40/100] Train Loss: 0.6930, Val Loss: 0.6834
# [Epoch 45/100] Train Loss: 0.6943, Val Loss: 0.6758
# [Epoch 50/100] Train Loss: 0.6942, Val Loss: 0.6775
# [Epoch 55/100] Train Loss: 0.6918, Val Loss: 0.6849
# [Epoch 60/100] Train Loss: 0.6930, Val Loss: 0.6784
# [Epoch 65/100] Train Loss: 0.6934, Val Loss: 0.6919
# [Epoch 70/100] Train Loss: 0.6916, Val Loss: 0.6918
# [Epoch 75/100] Train Loss: 0.6926, Val Loss: 0.6702
# [Epoch 80/100] Train Loss: 0.6903, Val Loss: 0.6879
# [Epoch 85/100] Train Loss: 0.6923, Val Loss: 0.6875
# [Epoch 90/100] Train Loss: 0.6889, Val Loss: 0.6936
# [Epoch 95/100] Train Loss: 0.6854, Val Loss: 0.6918
# [Epoch 100/100] Train Loss: 0.6880, Val Loss: 0.6773
# Accuracy on Nonzero Predictions: 0.6270
# 37
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Security type: technical
# [Epoch 5/100] Train Loss: 0.6972, Val Loss: 0.6969
# [Epoch 10/100] Train Loss: 0.6984, Val Loss: 0.6919
# [Epoch 15/100] Train Loss: 0.6954, Val Loss: 0.6893
# [Epoch 20/100] Train Loss: 0.6933, Val Loss: 0.6803
# [Epoch 25/100] Train Loss: 0.6958, Val Loss: 0.6874
# [Epoch 30/100] Train Loss: 0.6960, Val Loss: 0.6823
# [Epoch 35/100] Train Loss: 0.6962, Val Loss: 0.6789
# [Epoch 40/100] Train Loss: 0.6949, Val Loss: 0.6896
# [Epoch 45/100] Train Loss: 0.6937, Val Loss: 0.6949
# [Epoch 50/100] Train Loss: 0.6950, Val Loss: 0.6870
# [Epoch 55/100] Train Loss: 0.6941, Val Loss: 0.6960
# [Epoch 60/100] Train Loss: 0.6956, Val Loss: 0.6905
# [Epoch 65/100] Train Loss: 0.6947, Val Loss: 0.7217
# [Epoch 70/100] Train Loss: 0.6907, Val Loss: 0.7163
# [Epoch 75/100] Train Loss: 0.6951, Val Loss: 0.7317
# [Epoch 80/100] Train Loss: 0.6947, Val Loss: 0.7230
# [Epoch 85/100] Train Loss: 0.6934, Val Loss: 0.7093
# [Epoch 90/100] Train Loss: 0.6886, Val Loss: 0.7222
# [Epoch 95/100] Train Loss: 0.6909, Val Loss: 0.7049
# [Epoch 100/100] Train Loss: 0.6935, Val Loss: 0.7179
# Accuracy on Nonzero Predictions: 0.6032
# 38
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Security type: technical
# [Epoch 5/100] Train Loss: 0.6967, Val Loss: 0.6941
# [Epoch 10/100] Train Loss: 0.7099, Val Loss: 0.6826
# [Epoch 15/100] Train Loss: 0.6978, Val Loss: 0.6738
# [Epoch 20/100] Train Loss: 0.7015, Val Loss: 0.6837
# [Epoch 25/100] Train Loss: 0.6962, Val Loss: 0.6791
# [Epoch 30/100] Train Loss: 0.6997, Val Loss: 0.6808
# [Epoch 35/100] Train Loss: 0.6990, Val Loss: 0.6786
# [Epoch 40/100] Train Loss: 0.6990, Val Loss: 0.6770
# [Epoch 45/100] Train Loss: 0.6995, Val Loss: 0.6786
# [Epoch 50/100] Train Loss: 0.6942, Val Loss: 0.6893
# [Epoch 55/100] Train Loss: 0.6953, Val Loss: 0.6842
# [Epoch 60/100] Train Loss: 0.6956, Val Loss: 0.6969
# [Epoch 65/100] Train Loss: 0.6929, Val Loss: 0.6735
# [Epoch 70/100] Train Loss: 0.6918, Val Loss: 0.6742
# [Epoch 75/100] Train Loss: 0.6939, Val Loss: 0.6834
# [Epoch 80/100] Train Loss: 0.6958, Val Loss: 0.6881
# [Epoch 85/100] Train Loss: 0.6928, Val Loss: 0.6880
# [Epoch 90/100] Train Loss: 0.6866, Val Loss: 0.7322
# [Epoch 95/100] Train Loss: 0.6926, Val Loss: 0.7063
# [Epoch 100/100] Train Loss: 0.6952, Val Loss: 0.6957
# Accuracy on Nonzero Predictions: 0.5794
# 39
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Security type: technical
# [Epoch 5/100] Train Loss: 0.6975, Val Loss: 0.6985
# [Epoch 10/100] Train Loss: 0.7056, Val Loss: 0.7745
# [Epoch 15/100] Train Loss: 0.6959, Val Loss: 0.6891
# [Epoch 20/100] Train Loss: 0.6957, Val Loss: 0.6891
# [Epoch 25/100] Train Loss: 0.6946, Val Loss: 0.6785
# [Epoch 30/100] Train Loss: 0.6946, Val Loss: 0.6840
# [Epoch 35/100] Train Loss: 0.6945, Val Loss: 0.6881
# [Epoch 40/100] Train Loss: 0.6953, Val Loss: 0.6907
# [Epoch 45/100] Train Loss: 0.6942, Val Loss: 0.6901
# [Epoch 50/100] Train Loss: 0.6965, Val Loss: 0.6782
# [Epoch 55/100] Train Loss: 0.6939, Val Loss: 0.6793
# [Epoch 60/100] Train Loss: 0.6925, Val Loss: 0.6844
# [Epoch 65/100] Train Loss: 0.6980, Val Loss: 0.6845
# [Epoch 70/100] Train Loss: 0.6920, Val Loss: 0.7059
# [Epoch 75/100] Train Loss: 0.6927, Val Loss: 0.6757
# [Epoch 80/100] Train Loss: 0.6928, Val Loss: 0.6633
# [Epoch 85/100] Train Loss: 0.6927, Val Loss: 0.6740
# [Epoch 90/100] Train Loss: 0.6963, Val Loss: 0.6687
# [Epoch 95/100] Train Loss: 0.6963, Val Loss: 0.6834
# [Epoch 100/100] Train Loss: 0.6904, Val Loss: 0.6920
# Accuracy on Nonzero Predictions: 0.5000
# 40
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Security type: technical
# [Epoch 5/100] Train Loss: 0.6981, Val Loss: 0.7083
# [Epoch 10/100] Train Loss: 0.6952, Val Loss: 0.6860
# [Epoch 15/100] Train Loss: 0.6957, Val Loss: 0.6850
# [Epoch 20/100] Train Loss: 0.6942, Val Loss: 0.6940
# [Epoch 25/100] Train Loss: 0.6938, Val Loss: 0.6888
# [Epoch 30/100] Train Loss: 0.6959, Val Loss: 0.6888
# [Epoch 35/100] Train Loss: 0.6955, Val Loss: 0.6903
# [Epoch 40/100] Train Loss: 0.6948, Val Loss: 0.6874
# [Epoch 45/100] Train Loss: 0.6974, Val Loss: 0.6640
# [Epoch 50/100] Train Loss: 0.6940, Val Loss: 0.6874
# [Epoch 55/100] Train Loss: 0.6952, Val Loss: 0.6814
# [Epoch 60/100] Train Loss: 0.6962, Val Loss: 0.6812
# [Epoch 65/100] Train Loss: 0.6939, Val Loss: 0.6697
# [Epoch 70/100] Train Loss: 0.6917, Val Loss: 0.6783
# [Epoch 75/100] Train Loss: 0.6942, Val Loss: 0.6705
# [Epoch 80/100] Train Loss: 0.6979, Val Loss: 0.6853
# [Epoch 85/100] Train Loss: 0.6962, Val Loss: 0.6656
# [Epoch 90/100] Train Loss: 0.6959, Val Loss: 0.6897
# [Epoch 95/100] Train Loss: 0.6938, Val Loss: 0.6799
# [Epoch 100/100] Train Loss: 0.6927, Val Loss: 0.6845
# Accuracy on Nonzero Predictions: 0.6429
# 41
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Security type: technical
# [Epoch 5/100] Train Loss: 0.6989, Val Loss: 0.7159
# [Epoch 10/100] Train Loss: 0.6988, Val Loss: 0.7088
# [Epoch 15/100] Train Loss: 0.7066, Val Loss: 0.6817
# [Epoch 20/100] Train Loss: 0.6959, Val Loss: 0.6857
# [Epoch 25/100] Train Loss: 0.6962, Val Loss: 0.6851
# [Epoch 30/100] Train Loss: 0.6963, Val Loss: 0.6806
# [Epoch 35/100] Train Loss: 0.6974, Val Loss: 0.6906
# [Epoch 40/100] Train Loss: 0.6942, Val Loss: 0.6806
# [Epoch 45/100] Train Loss: 0.6929, Val Loss: 0.6822
# [Epoch 50/100] Train Loss: 0.6936, Val Loss: 0.6758
# [Epoch 55/100] Train Loss: 0.6909, Val Loss: 0.6715
# [Epoch 60/100] Train Loss: 0.6989, Val Loss: 0.6774
# [Epoch 65/100] Train Loss: 0.6937, Val Loss: 0.6782
# [Epoch 70/100] Train Loss: 0.6956, Val Loss: 0.6837
# [Epoch 75/100] Train Loss: 0.6916, Val Loss: 0.6683
# [Epoch 80/100] Train Loss: 0.6895, Val Loss: 0.6686
# [Epoch 85/100] Train Loss: 0.6913, Val Loss: 0.6807
# [Epoch 90/100] Train Loss: 0.6929, Val Loss: 0.6893
# [Epoch 95/100] Train Loss: 0.6908, Val Loss: 0.6836
# [Epoch 100/100] Train Loss: 0.6870, Val Loss: 0.6717
# Accuracy on Nonzero Predictions: 0.5952
# 42
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Security type: technical
# [Epoch 5/100] Train Loss: 0.6975, Val Loss: 0.7168
# [Epoch 10/100] Train Loss: 0.7002, Val Loss: 0.6843
# [Epoch 15/100] Train Loss: 0.6972, Val Loss: 0.6875
# [Epoch 20/100] Train Loss: 0.6940, Val Loss: 0.6965
# [Epoch 25/100] Train Loss: 0.6958, Val Loss: 0.6864
# [Epoch 30/100] Train Loss: 0.6944, Val Loss: 0.6924
# [Epoch 35/100] Train Loss: 0.6959, Val Loss: 0.6801
# [Epoch 40/100] Train Loss: 0.6952, Val Loss: 0.6800
# [Epoch 45/100] Train Loss: 0.6965, Val Loss: 0.7166
# [Epoch 50/100] Train Loss: 0.6944, Val Loss: 0.6839
# [Epoch 55/100] Train Loss: 0.6929, Val Loss: 0.6789
# [Epoch 60/100] Train Loss: 0.6940, Val Loss: 0.6777
# [Epoch 65/100] Train Loss: 0.6929, Val Loss: 0.6886
# [Epoch 70/100] Train Loss: 0.6947, Val Loss: 0.6895
# [Epoch 75/100] Train Loss: 0.6906, Val Loss: 0.6792
# [Epoch 80/100] Train Loss: 0.6986, Val Loss: 0.6822
# [Epoch 85/100] Train Loss: 0.6968, Val Loss: 0.6863
# [Epoch 90/100] Train Loss: 0.6967, Val Loss: 0.6952
# [Epoch 95/100] Train Loss: 0.6949, Val Loss: 0.6907
# [Epoch 100/100] Train Loss: 0.6938, Val Loss: 0.6861
# Accuracy on Nonzero Predictions: 0.6190
# 43
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Security type: technical
# [Epoch 5/100] Train Loss: 0.6979, Val Loss: 0.7153
# [Epoch 10/100] Train Loss: 0.7103, Val Loss: 0.7357
# [Epoch 15/100] Train Loss: 0.7004, Val Loss: 0.6744
# [Epoch 20/100] Train Loss: 0.6982, Val Loss: 0.6807
# [Epoch 25/100] Train Loss: 0.6988, Val Loss: 0.6709
# [Epoch 30/100] Train Loss: 0.6980, Val Loss: 0.6761
# [Epoch 35/100] Train Loss: 0.6993, Val Loss: 0.6780
# [Epoch 40/100] Train Loss: 0.6963, Val Loss: 0.6750
# [Epoch 45/100] Train Loss: 0.6969, Val Loss: 0.6928
# [Epoch 50/100] Train Loss: 0.6960, Val Loss: 0.6785
# [Epoch 55/100] Train Loss: 0.6965, Val Loss: 0.6836
# [Epoch 60/100] Train Loss: 0.6956, Val Loss: 0.6829
# [Epoch 65/100] Train Loss: 0.6947, Val Loss: 0.6815
# [Epoch 70/100] Train Loss: 0.6972, Val Loss: 0.6848
# [Epoch 75/100] Train Loss: 0.6949, Val Loss: 0.6714
# [Epoch 80/100] Train Loss: 0.6938, Val Loss: 0.6903
# [Epoch 85/100] Train Loss: 0.6920, Val Loss: 0.6861
# [Epoch 90/100] Train Loss: 0.6940, Val Loss: 0.6924
# [Epoch 95/100] Train Loss: 0.6887, Val Loss: 0.7099
# [Epoch 100/100] Train Loss: 0.6862, Val Loss: 0.6592
# Accuracy on Nonzero Predictions: 0.5952
# 44
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Security type: technical
# [Epoch 5/100] Train Loss: 0.6985, Val Loss: 0.7169
# [Epoch 10/100] Train Loss: 0.6959, Val Loss: 0.6887
# [Epoch 15/100] Train Loss: 0.6962, Val Loss: 0.6832
# [Epoch 20/100] Train Loss: 0.6956, Val Loss: 0.6795
# [Epoch 25/100] Train Loss: 0.6950, Val Loss: 0.6834
# [Epoch 30/100] Train Loss: 0.6947, Val Loss: 0.6725
# [Epoch 35/100] Train Loss: 0.6940, Val Loss: 0.6749
# [Epoch 40/100] Train Loss: 0.6934, Val Loss: 0.6971
# [Epoch 45/100] Train Loss: 0.6954, Val Loss: 0.6872
# [Epoch 50/100] Train Loss: 0.6950, Val Loss: 0.6818
# [Epoch 55/100] Train Loss: 0.6942, Val Loss: 0.6756
# [Epoch 60/100] Train Loss: 0.6960, Val Loss: 0.6886
# [Epoch 65/100] Train Loss: 0.6922, Val Loss: 0.6825
# [Epoch 70/100] Train Loss: 0.6893, Val Loss: 0.6764
# [Epoch 75/100] Train Loss: 0.6896, Val Loss: 0.6908
# [Epoch 80/100] Train Loss: 0.6927, Val Loss: 0.6888
# [Epoch 85/100] Train Loss: 0.6891, Val Loss: 0.6770
# [Epoch 90/100] Train Loss: 0.6919, Val Loss: 0.7013
# [Epoch 95/100] Train Loss: 0.6870, Val Loss: 0.6916
# [Epoch 100/100] Train Loss: 0.6877, Val Loss: 0.6976
# Accuracy on Nonzero Predictions: 0.5317
# 45
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Security type: technical
# [Epoch 5/100] Train Loss: 0.6996, Val Loss: 0.6991
# [Epoch 10/100] Train Loss: 0.6936, Val Loss: 0.6933
# [Epoch 15/100] Train Loss: 0.6932, Val Loss: 0.6885
# [Epoch 20/100] Train Loss: 0.6943, Val Loss: 0.6915
# [Epoch 25/100] Train Loss: 0.6943, Val Loss: 0.6964
# [Epoch 30/100] Train Loss: 0.6953, Val Loss: 0.6849
# [Epoch 35/100] Train Loss: 0.6949, Val Loss: 0.6974
# [Epoch 40/100] Train Loss: 0.6953, Val Loss: 0.6959
# [Epoch 45/100] Train Loss: 0.7020, Val Loss: 0.7023
# [Epoch 50/100] Train Loss: 0.6971, Val Loss: 0.6915
# [Epoch 55/100] Train Loss: 0.6938, Val Loss: 0.6915
# [Epoch 60/100] Train Loss: 0.6916, Val Loss: 0.6936
# [Epoch 65/100] Train Loss: 0.6913, Val Loss: 0.6920
# [Epoch 70/100] Train Loss: 0.6867, Val Loss: 0.6643
# [Epoch 75/100] Train Loss: 0.6910, Val Loss: 0.6904
# [Epoch 80/100] Train Loss: 0.6882, Val Loss: 0.6837
# [Epoch 85/100] Train Loss: 0.6918, Val Loss: 0.6985
# [Epoch 90/100] Train Loss: 0.6859, Val Loss: 0.7171
# [Epoch 95/100] Train Loss: 0.6933, Val Loss: 0.6846
# [Epoch 100/100] Train Loss: 0.6888, Val Loss: 0.6884
# Accuracy on Nonzero Predictions: 0.5952
# 46
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Security type: technical
# [Epoch 5/100] Train Loss: 0.6985, Val Loss: 0.7158
# [Epoch 10/100] Train Loss: 0.7068, Val Loss: 0.6964
# [Epoch 15/100] Train Loss: 0.6984, Val Loss: 0.6810
# [Epoch 20/100] Train Loss: 0.6960, Val Loss: 0.6954
# [Epoch 25/100] Train Loss: 0.6961, Val Loss: 0.6859
# [Epoch 30/100] Train Loss: 0.6988, Val Loss: 0.6821
# [Epoch 35/100] Train Loss: 0.6954, Val Loss: 0.6817
# [Epoch 40/100] Train Loss: 0.6948, Val Loss: 0.7085
# [Epoch 45/100] Train Loss: 0.7000, Val Loss: 0.7087
# [Epoch 50/100] Train Loss: 0.6957, Val Loss: 0.6742
# [Epoch 55/100] Train Loss: 0.7007, Val Loss: 0.6769
# [Epoch 60/100] Train Loss: 0.6980, Val Loss: 0.6732
# [Epoch 65/100] Train Loss: 0.6972, Val Loss: 0.6726
# [Epoch 70/100] Train Loss: 0.6990, Val Loss: 0.7252
# [Epoch 75/100] Train Loss: 0.6921, Val Loss: 0.6872
# [Epoch 80/100] Train Loss: 0.6928, Val Loss: 0.6904
# [Epoch 85/100] Train Loss: 0.6963, Val Loss: 0.6900
# [Epoch 90/100] Train Loss: 0.6903, Val Loss: 0.6734
# [Epoch 95/100] Train Loss: 0.6882, Val Loss: 0.6828
# [Epoch 100/100] Train Loss: 0.6902, Val Loss: 0.6760
# Accuracy on Nonzero Predictions: 0.5635
# 47
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Security type: technical
# [Epoch 5/100] Train Loss: 0.6982, Val Loss: 0.7053
# [Epoch 10/100] Train Loss: 0.7129, Val Loss: 0.7530
# [Epoch 15/100] Train Loss: 0.6977, Val Loss: 0.6856
# [Epoch 20/100] Train Loss: 0.6947, Val Loss: 0.6834
# [Epoch 25/100] Train Loss: 0.6933, Val Loss: 0.7002
# [Epoch 30/100] Train Loss: 0.6962, Val Loss: 0.6858
# [Epoch 35/100] Train Loss: 0.6949, Val Loss: 0.6784
# [Epoch 40/100] Train Loss: 0.6936, Val Loss: 0.6892
# [Epoch 45/100] Train Loss: 0.6919, Val Loss: 0.6859
# [Epoch 50/100] Train Loss: 0.6927, Val Loss: 0.6981
# [Epoch 55/100] Train Loss: 0.6983, Val Loss: 0.6783
# [Epoch 60/100] Train Loss: 0.6948, Val Loss: 0.6882
# [Epoch 65/100] Train Loss: 0.6879, Val Loss: 0.6879
# [Epoch 70/100] Train Loss: 0.6874, Val Loss: 0.6953
# [Epoch 75/100] Train Loss: 0.6908, Val Loss: 0.6791
# [Epoch 80/100] Train Loss: 0.6898, Val Loss: 0.6532
# [Epoch 85/100] Train Loss: 0.6890, Val Loss: 0.6842
# [Epoch 90/100] Train Loss: 0.6908, Val Loss: 0.7012
# [Epoch 95/100] Train Loss: 0.6865, Val Loss: 0.6940
# [Epoch 100/100] Train Loss: 0.6868, Val Loss: 0.7029
# Accuracy on Nonzero Predictions: 0.5714
# 48
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Security type: technical
# [Epoch 5/100] Train Loss: 0.7000, Val Loss: 0.7342
# [Epoch 10/100] Train Loss: 0.6950, Val Loss: 0.6884
# [Epoch 15/100] Train Loss: 0.6941, Val Loss: 0.6866
# [Epoch 20/100] Train Loss: 0.6941, Val Loss: 0.6885
# [Epoch 25/100] Train Loss: 0.6939, Val Loss: 0.6766
# [Epoch 30/100] Train Loss: 0.6944, Val Loss: 0.6872
# [Epoch 35/100] Train Loss: 0.6946, Val Loss: 0.6911
# [Epoch 40/100] Train Loss: 0.6938, Val Loss: 0.7033
# [Epoch 45/100] Train Loss: 0.6980, Val Loss: 0.6746
# [Epoch 50/100] Train Loss: 0.6935, Val Loss: 0.6869
# [Epoch 55/100] Train Loss: 0.6964, Val Loss: 0.6946
# [Epoch 60/100] Train Loss: 0.6904, Val Loss: 0.6902
# [Epoch 65/100] Train Loss: 0.6951, Val Loss: 0.7229
# [Epoch 70/100] Train Loss: 0.6967, Val Loss: 0.6899
# [Epoch 75/100] Train Loss: 0.6952, Val Loss: 0.6972
# [Epoch 80/100] Train Loss: 0.6928, Val Loss: 0.6883
# [Epoch 85/100] Train Loss: 0.6946, Val Loss: 0.6960
# [Epoch 90/100] Train Loss: 0.6923, Val Loss: 0.6892
# [Epoch 95/100] Train Loss: 0.6917, Val Loss: 0.7049
# [Epoch 100/100] Train Loss: 0.6911, Val Loss: 0.7050
# Accuracy on Nonzero Predictions: 0.5714
# 49
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Security type: technical
# [Epoch 5/100] Train Loss: 0.7045, Val Loss: 0.7441
# [Epoch 10/100] Train Loss: 0.6976, Val Loss: 0.7020
# [Epoch 15/100] Train Loss: 0.6964, Val Loss: 0.6864
# [Epoch 20/100] Train Loss: 0.6963, Val Loss: 0.6744
# [Epoch 25/100] Train Loss: 0.6930, Val Loss: 0.6883
# [Epoch 30/100] Train Loss: 0.6960, Val Loss: 0.6850
# [Epoch 35/100] Train Loss: 0.6947, Val Loss: 0.6838
# [Epoch 40/100] Train Loss: 0.6928, Val Loss: 0.6922
# [Epoch 45/100] Train Loss: 0.6966, Val Loss: 0.6764
# [Epoch 50/100] Train Loss: 0.6967, Val Loss: 0.6849
# [Epoch 55/100] Train Loss: 0.6964, Val Loss: 0.6821
# [Epoch 60/100] Train Loss: 0.6958, Val Loss: 0.6945
# [Epoch 65/100] Train Loss: 0.6936, Val Loss: 0.6898
# [Epoch 70/100] Train Loss: 0.6947, Val Loss: 0.6974
# [Epoch 75/100] Train Loss: 0.6943, Val Loss: 0.7139
# [Epoch 80/100] Train Loss: 0.6913, Val Loss: 0.6966
# [Epoch 85/100] Train Loss: 0.6885, Val Loss: 0.6957
# [Epoch 90/100] Train Loss: 0.6910, Val Loss: 0.6900
# [Epoch 95/100] Train Loss: 0.6901, Val Loss: 0.6778
# [Epoch 100/100] Train Loss: 0.6928, Val Loss: 0.7024
# Accuracy on Nonzero Predictions: 0.4127

# %%
df = pd.DataFrame(results_list)
df.to_csv(os.path.join(output_folder, f"gru_accuracy_bydatatype.csv"), index=False)

# %%
summary_stats = df.groupby(["MODEL", "DATA_TYPE"])["ACCURACY"].agg(["mean", "max", "min", "std"]).reset_index()
summary_stats.to_csv(os.path.join(output_folder, f"gru_bydatatype_summarystats.csv"), index=False)

# %%
output_folder = os.path.join(results_dir, 'individual_trials')
output_folder
# Out:
# '/home/jupyter-tfg2425paula/prediction_project_v3/02_results/individual_trials'

# %%
results_csv_path = 

if len(results_list) > 0:
    df = pd.DataFrame(results_list)

    if os.path.exists(results_csv_path):
        # Append without header
        df.to_csv(results_csv_path, mode='a', header=False, index=False)
    else:
        # Write new file with header
        df.to_csv(results_csv_path, index=False)

    # Clear the list before next iteration
    results_list = []
# Out:
#     STOCK    DATA_TYPE MODEL PROCESSING  ACCURACY  TRAIN_PCT_DECREASE  \
# 0    AAPL  single_name   GRU      clean  0.564885           -2.183248
# 1    AAPL  single_name   GRU      clean  0.595420           -2.057334
# 2    AAPL  single_name   GRU      clean  0.587786           -1.778138
# 3    AAPL  single_name   GRU      clean  0.564885           -2.430913
# 4    AAPL  single_name   GRU      clean  0.541985           -2.174941
# ..    ...          ...   ...        ...       ...                 ...
# 295  AAPL    technical   GRU      clean  0.468254          -78.074882
# 296  AAPL    technical   GRU      clean  0.515873          -64.541400
# 297  AAPL    technical   GRU      clean  0.500000          -62.280494
# 298  AAPL    technical   GRU      clean  0.500000          -68.898970
# 299  AAPL    technical   GRU      clean  0.492063          -30.221871
#
#      FINAL_TRAIN_LOSS
# 0            0.680376
# 1            0.681497
# 2            0.683358
# 3            0.678785
# 4            0.680178
# ..                ...
# 295          0.153156
# 296          0.246790
# 297          0.263006
# 298          0.216749
# 299          0.487812
#
# [300 rows x 7 columns]

# %% [markdown]
# ### **Las series univariantes parecen tener mejor resultado**
#
# Nos preguntamos si es por el excesivo ruido de tal número de columnas.
# Introducimos comparación con df's de opciones e indicadores técnicos a los que se le ha aplicado PCA.

# %%
results_list = []
stock = "AAPL"
period = "10y"
possible_train_size = 95
window_size = 5
batch_size = 32
num_epochs = 100

prediction_threshold = 0.5

output_folder = os.path.join(results_dir, f"inidividual_trials") 
os.makedirs(output_folder, exist_ok=True)

results_csv_path = os.path.join(output_folder, f"01_{stock}_proc_model_type.csv")
processing_types = ["pca", "clean"]
types_securities = ["single_name", "technical", "options"]


learning_rates = [0.009, 0.01, 0.011]

results_list = []
for processing in processing_types:
    for model_type in model_types:
        for security_type in types_securities:
            if security_type == "single_name":
                modified_processing = "clean"
            else:
                modified_processing = processing
                
            initial_data_dir = os.path.join(project_dir, f"00_data/{modified_processing}") 
            
            test_accuracy_list = []
            pct_decrease_list = []
            
            # Load original data (info only)
            filename = f"{security_type}/{stock}/{period}_data.csv"
            original_input_filepath = os.path.join(initial_data_dir, filename)
            original_data = pd.read_csv(original_input_filepath)

            # Iterate over window sizes
            print(f"{modified_processing}, {model_type}, {security_type}")

            # Load data using the 'processing' variable in path
            pkl_filename = f"{modified_processing}/{security_type}/{stock}/{period}_{window_size}_data.pkl"
            input_filepath = os.path.join(horizontal_data_dir, pkl_filename)
            print(input_filepath)
            input_df = pd.read_pickle(input_filepath)

            X_resampled, y_resampled = reshape_remove_characters(input_df)

            input_size = X_resampled.shape[2]
            train_size = int(X_resampled.shape[0] * possible_train_size / 100)
            test_size = X_resampled.shape[0] - train_size

            # Generate model
            if model_type == "gru":
                model = GRU3DClassifier(input_size, hidden_size, output_size, num_layers, dropout)
            elif model_type == "lstm":
                model = StockPriceLSTM(input_size, hidden_size, output_size)

            model = model.to(device)
            
            for learning_rate in learning_rates:
                optimizer = optim.Adam(model.parameters(), lr=learning_rate)
                print(f"Training {stock} | LR: {learning_rate} | Epochs: {num_epochs} "
                      f"| Batch: {batch_size} | Prediction Threshold: {prediction_threshold}")

                result = evaluate_rolling_unchanged_model_threshold(
                    model=model,
                    X=X_resampled,
                    y=y_resampled,
                    criterion=criterion,
                    optimizer=optimizer,
                    device=device,
                    train_size=train_size,
                    batch_size=batch_size,
                    num_epochs=num_epochs,
                    lower_threshold=0.5,
                    plots_dir=plots_dir,                # folder where plots are saved
                    plot_filename=f"learning_rates_processing/AAPL_{modified_processing}_{model_type}_lr{learning_rate}_{security_type}.png" # optional custom filename
                )    

                rolling_predictions = result["rolling_predictions"]
                rolling_targets = result["rolling_targets"]
                test_accuracy = result["accuracy_nonzero"]
                loss_decrease_percentage = result["loss_decrease_percentage"]
                nonzero_preds = np.count_nonzero(rolling_predictions)
                
                test_accuracy_list.append(test_accuracy)
                pct_decrease_list.append(loss_decrease_percentage)

            print(test_accuracy_list)
            print(pct_decrease_list)
            # 1) Create a record (dictionary) for this run
            run_record = {"STOCK": stock,
                "DATA_TYPE": security_type,
                "MODEL": model_type.upper(),  # Convert to uppercase for consistency
                "PROCESSING": modified_processing,
                "MEAN_ACCURACY": np.mean(test_accuracy_list),
                "MAX_ACCURACY": np.max(test_accuracy_list),
                "MIN_ACCURACY": np.min(test_accuracy_list),
                "MEAN_TRAIN_PCT_DECREASE": np.mean(test_accuracy_list)}

            # 2) Append to list
            results_list.append(run_record)
# Out:
# clean, lstm, single_name
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/clean/single_name/AAPL/10y_5_data.pkl
# Training AAPL | LR: 0.009 | Epochs: 100 | Batch: 32 | Prediction Threshold: 0.5
# [Epoch 5/100] Train Loss: 0.6930, Val Loss: 0.6921
# [Epoch 10/100] Train Loss: 0.6906, Val Loss: 0.6914
# [Epoch 15/100] Train Loss: 0.6891, Val Loss: 0.6899
# [Epoch 20/100] Train Loss: 0.6877, Val Loss: 0.6884
# [Epoch 25/100] Train Loss: 0.6834, Val Loss: 0.6842
# [Epoch 30/100] Train Loss: 0.6787, Val Loss: 0.6837
# [Epoch 35/100] Train Loss: 0.6741, Val Loss: 0.6843
# [Epoch 40/100] Train Loss: 0.6698, Val Loss: 0.6824
# [Epoch 45/100] Train Loss: 0.6653, Val Loss: 0.6824
# [Epoch 50/100] Train Loss: 0.6610, Val Loss: 0.6849
# [Epoch 55/100] Train Loss: 0.6564, Val Loss: 0.6819
# [Epoch 60/100] Train Loss: 0.6485, Val Loss: 0.6795
# [Epoch 65/100] Train Loss: 0.6427, Val Loss: 0.6814
# [Epoch 70/100] Train Loss: 0.6374, Val Loss: 0.6828
# [Epoch 75/100] Train Loss: 0.6312, Val Loss: 0.6884
# [Epoch 80/100] Train Loss: 0.6261, Val Loss: 0.6923
# [Epoch 85/100] Train Loss: 0.6209, Val Loss: 0.6954
# [Epoch 90/100] Train Loss: 0.6156, Val Loss: 0.6995
# [Epoch 95/100] Train Loss: 0.6105, Val Loss: 0.7045
# [Epoch 100/100] Train Loss: 0.6046, Val Loss: 0.7098
# Accuracy on Nonzero Predictions: 0.5649
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/learning_rates_processing/AAPL_clean_lstm_lr0.009_single_name.png
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Prediction Threshold: 0.5
# [Epoch 5/100] Train Loss: 0.5992, Val Loss: 0.7161
# [Epoch 10/100] Train Loss: 0.5947, Val Loss: 0.7253
# [Epoch 15/100] Train Loss: 0.5898, Val Loss: 0.7406
# [Epoch 20/100] Train Loss: 0.5846, Val Loss: 0.7599
# [Epoch 25/100] Train Loss: 0.5798, Val Loss: 0.7724
# [Epoch 30/100] Train Loss: 0.5749, Val Loss: 0.7818
# [Epoch 35/100] Train Loss: 0.5698, Val Loss: 0.7871
# [Epoch 40/100] Train Loss: 0.5651, Val Loss: 0.7936
# [Epoch 45/100] Train Loss: 0.5600, Val Loss: 0.7952
# [Epoch 50/100] Train Loss: 0.5556, Val Loss: 0.8008
# [Epoch 55/100] Train Loss: 0.5507, Val Loss: 0.8048
# [Epoch 60/100] Train Loss: 0.5468, Val Loss: 0.8146
# [Epoch 65/100] Train Loss: 0.5423, Val Loss: 0.8233
# [Epoch 70/100] Train Loss: 0.5383, Val Loss: 0.8328
# [Epoch 75/100] Train Loss: 0.5335, Val Loss: 0.8377
# [Epoch 80/100] Train Loss: 0.5299, Val Loss: 0.8440
# [Epoch 85/100] Train Loss: 0.5265, Val Loss: 0.8509
# [Epoch 90/100] Train Loss: 0.5231, Val Loss: 0.8578
# [Epoch 95/100] Train Loss: 0.5204, Val Loss: 0.8679
# [Epoch 100/100] Train Loss: 0.5173, Val Loss: 0.8768
# Accuracy on Nonzero Predictions: 0.5649
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/learning_rates_processing/AAPL_clean_lstm_lr0.01_single_name.png
# Training AAPL | LR: 0.011 | Epochs: 100 | Batch: 32 | Prediction Threshold: 0.5
# [Epoch 5/100] Train Loss: 0.5156, Val Loss: 0.8804
# [Epoch 10/100] Train Loss: 0.5123, Val Loss: 0.8940
# [Epoch 15/100] Train Loss: 0.5092, Val Loss: 0.8995
# [Epoch 20/100] Train Loss: 0.5065, Val Loss: 0.9063
# [Epoch 25/100] Train Loss: 0.5035, Val Loss: 0.9152
# [Epoch 30/100] Train Loss: 0.5011, Val Loss: 0.9205
# [Epoch 35/100] Train Loss: 0.5042, Val Loss: 0.9341
# [Epoch 40/100] Train Loss: 0.4954, Val Loss: 0.9414
# [Epoch 45/100] Train Loss: 0.4903, Val Loss: 0.9544
# [Epoch 50/100] Train Loss: 0.4876, Val Loss: 0.9663
# [Epoch 55/100] Train Loss: 0.4843, Val Loss: 0.9768
# [Epoch 60/100] Train Loss: 0.4807, Val Loss: 0.9886
# [Epoch 65/100] Train Loss: 0.4782, Val Loss: 0.9959
# [Epoch 70/100] Train Loss: 0.4716, Val Loss: 1.0230
# [Epoch 75/100] Train Loss: 0.4656, Val Loss: 1.0444
# [Epoch 80/100] Train Loss: 0.4620, Val Loss: 1.0541
# [Epoch 85/100] Train Loss: 0.4587, Val Loss: 1.0688
# [Epoch 90/100] Train Loss: 0.4579, Val Loss: 1.0719
# [Epoch 95/100] Train Loss: 0.4513, Val Loss: 1.0740
# [Epoch 100/100] Train Loss: 0.4416, Val Loss: 1.1003
# Accuracy on Nonzero Predictions: 0.5802
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/learning_rates_processing/AAPL_clean_lstm_lr0.011_single_name.png
# [0.5648854961832062, 0.5648854961832062, 0.5801526717557252]
# [-13.069365985654535, -14.765485336143753, -15.603392415675913]
# pca, lstm, technical
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/AAPL/10y_5_data.pkl
# Training AAPL | LR: 0.009 | Epochs: 100 | Batch: 32 | Prediction Threshold: 0.5
# [Epoch 5/100] Train Loss: 0.6999, Val Loss: 0.6868
# [Epoch 10/100] Train Loss: 0.6962, Val Loss: 0.6857
# [Epoch 15/100] Train Loss: 0.6918, Val Loss: 0.7085
# [Epoch 20/100] Train Loss: 0.6877, Val Loss: 0.7045
# [Epoch 25/100] Train Loss: 0.6823, Val Loss: 0.7367
# [Epoch 30/100] Train Loss: 0.6692, Val Loss: 0.7354
# [Epoch 35/100] Train Loss: 0.6688, Val Loss: 0.7675
# [Epoch 40/100] Train Loss: 0.6391, Val Loss: 0.7243
# [Epoch 45/100] Train Loss: 0.6177, Val Loss: 0.7848
# [Epoch 50/100] Train Loss: 0.5899, Val Loss: 0.7467
# [Epoch 55/100] Train Loss: 0.5407, Val Loss: 0.8779
# [Epoch 60/100] Train Loss: 0.5179, Val Loss: 0.9509
# [Epoch 65/100] Train Loss: 0.4759, Val Loss: 0.9219
# [Epoch 70/100] Train Loss: 0.3978, Val Loss: 1.0941
# [Epoch 75/100] Train Loss: 0.3709, Val Loss: 1.1382
# [Epoch 80/100] Train Loss: 0.3173, Val Loss: 1.2774
# [Epoch 85/100] Train Loss: 0.2839, Val Loss: 1.4042
# [Epoch 90/100] Train Loss: 0.3072, Val Loss: 1.4872
# [Epoch 95/100] Train Loss: 0.2492, Val Loss: 1.5272
# [Epoch 100/100] Train Loss: 0.2199, Val Loss: 1.9120
# Accuracy on Nonzero Predictions: 0.5476
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/learning_rates_processing/AAPL_pca_lstm_lr0.009_technical.png
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Prediction Threshold: 0.5
# [Epoch 5/100] Train Loss: 0.2568, Val Loss: 1.9225
# [Epoch 10/100] Train Loss: 0.2186, Val Loss: 1.8327
# [Epoch 15/100] Train Loss: 0.1990, Val Loss: 2.0801
# [Epoch 20/100] Train Loss: 0.1804, Val Loss: 1.8781
# [Epoch 25/100] Train Loss: 0.1749, Val Loss: 2.0780
# [Epoch 30/100] Train Loss: 0.1371, Val Loss: 1.9629
# [Epoch 35/100] Train Loss: 0.1406, Val Loss: 2.2323
# [Epoch 40/100] Train Loss: 0.1650, Val Loss: 2.3222
# [Epoch 45/100] Train Loss: 0.1535, Val Loss: 2.3666
# [Epoch 50/100] Train Loss: 0.1427, Val Loss: 2.0980
# [Epoch 55/100] Train Loss: 0.1019, Val Loss: 2.0707
# [Epoch 60/100] Train Loss: 0.1481, Val Loss: 2.1499
# [Epoch 65/100] Train Loss: 0.1242, Val Loss: 2.0861
# [Epoch 70/100] Train Loss: 0.1015, Val Loss: 2.4635
# [Epoch 75/100] Train Loss: 0.0979, Val Loss: 2.2812
# [Epoch 80/100] Train Loss: 0.1628, Val Loss: 2.3897
# [Epoch 85/100] Train Loss: 0.1106, Val Loss: 2.2857
# [Epoch 90/100] Train Loss: 0.1177, Val Loss: 2.2392
# [Epoch 95/100] Train Loss: 0.0932, Val Loss: 2.4349
# [Epoch 100/100] Train Loss: 0.1002, Val Loss: 2.6925
# Accuracy on Nonzero Predictions: 0.5079
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/learning_rates_processing/AAPL_pca_lstm_lr0.01_technical.png
# Training AAPL | LR: 0.011 | Epochs: 100 | Batch: 32 | Prediction Threshold: 0.5
# [Epoch 5/100] Train Loss: 0.2108, Val Loss: 2.5511
# [Epoch 10/100] Train Loss: 0.1205, Val Loss: 2.6782
# [Epoch 15/100] Train Loss: 0.1063, Val Loss: 2.4212
# [Epoch 20/100] Train Loss: 0.1486, Val Loss: 2.3381
# [Epoch 25/100] Train Loss: 0.1308, Val Loss: 2.5008
# [Epoch 30/100] Train Loss: 0.2009, Val Loss: 2.4381
# [Epoch 35/100] Train Loss: 0.1652, Val Loss: 2.4034
# [Epoch 40/100] Train Loss: 0.1644, Val Loss: 2.6246
# [Epoch 45/100] Train Loss: 0.1046, Val Loss: 2.5954
# [Epoch 50/100] Train Loss: 0.0970, Val Loss: 2.4391
# [Epoch 55/100] Train Loss: 0.0780, Val Loss: 2.6598
# [Epoch 60/100] Train Loss: 0.0906, Val Loss: 2.6200
# [Epoch 65/100] Train Loss: 0.0673, Val Loss: 2.6574
# [Epoch 70/100] Train Loss: 0.1190, Val Loss: 2.7683
# [Epoch 75/100] Train Loss: 0.1445, Val Loss: 2.1823
# [Epoch 80/100] Train Loss: 0.1356, Val Loss: 2.2268
# [Epoch 85/100] Train Loss: 0.1165, Val Loss: 2.3485
# [Epoch 90/100] Train Loss: 0.1438, Val Loss: 2.6897
# [Epoch 95/100] Train Loss: 0.1059, Val Loss: 2.6577
# [Epoch 100/100] Train Loss: 0.1177, Val Loss: 2.4246
# Accuracy on Nonzero Predictions: 0.5476
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/learning_rates_processing/AAPL_pca_lstm_lr0.011_technical.png
# [0.5476190476190477, 0.5079365079365079, 0.5476190476190477]
# [-68.3226634481063, -58.987081993439304, -10.680032205145197]
# pca, lstm, options
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/options/AAPL/10y_5_data.pkl
# Training AAPL | LR: 0.009 | Epochs: 100 | Batch: 32 | Prediction Threshold: 0.5
# [Epoch 5/100] Train Loss: 0.6936, Val Loss: 0.6901
# [Epoch 10/100] Train Loss: 0.6920, Val Loss: 0.6986
# [Epoch 15/100] Train Loss: 0.6455, Val Loss: 0.7294
# [Epoch 20/100] Train Loss: 0.5396, Val Loss: 0.8689
# [Epoch 25/100] Train Loss: 0.3858, Val Loss: 0.9710
# [Epoch 30/100] Train Loss: 0.2470, Val Loss: 1.3581
# [Epoch 35/100] Train Loss: 0.1622, Val Loss: 1.5220
# [Epoch 40/100] Train Loss: 0.0668, Val Loss: 1.5964
# [Epoch 45/100] Train Loss: 0.0565, Val Loss: 1.9551
# [Epoch 50/100] Train Loss: 0.0213, Val Loss: 2.0190
# [Epoch 55/100] Train Loss: 0.0674, Val Loss: 2.2453
# [Epoch 60/100] Train Loss: 0.0543, Val Loss: 2.0694
# [Epoch 65/100] Train Loss: 0.0200, Val Loss: 1.9258
# [Epoch 70/100] Train Loss: 0.0132, Val Loss: 2.0132
# [Epoch 75/100] Train Loss: 0.0250, Val Loss: 2.4856
# [Epoch 80/100] Train Loss: 0.0616, Val Loss: 2.3172
# [Epoch 85/100] Train Loss: 0.0038, Val Loss: 2.1481
# [Epoch 90/100] Train Loss: 0.0041, Val Loss: 2.1095
# [Epoch 95/100] Train Loss: 0.0010, Val Loss: 2.4409
# [Epoch 100/100] Train Loss: 0.0003, Val Loss: 2.4514
# Accuracy on Nonzero Predictions: 0.5573
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/learning_rates_processing/AAPL_pca_lstm_lr0.009_options.png
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Prediction Threshold: 0.5
# [Epoch 5/100] Train Loss: 0.0480, Val Loss: 2.4426
# [Epoch 10/100] Train Loss: 0.0108, Val Loss: 2.6244
# [Epoch 15/100] Train Loss: 0.0013, Val Loss: 2.7146
# [Epoch 20/100] Train Loss: 0.0002, Val Loss: 2.6467
# [Epoch 25/100] Train Loss: 0.0001, Val Loss: 2.6667
# [Epoch 30/100] Train Loss: 0.0001, Val Loss: 2.6924
# [Epoch 35/100] Train Loss: 0.0001, Val Loss: 2.7194
# [Epoch 40/100] Train Loss: 0.0001, Val Loss: 2.7474
# [Epoch 45/100] Train Loss: 0.0000, Val Loss: 2.7763
# [Epoch 50/100] Train Loss: 0.0000, Val Loss: 2.8064
# [Epoch 55/100] Train Loss: 0.0000, Val Loss: 2.8378
# [Epoch 60/100] Train Loss: 0.0000, Val Loss: 2.8703
# [Epoch 65/100] Train Loss: 0.0000, Val Loss: 2.9041
# [Epoch 70/100] Train Loss: 0.0000, Val Loss: 2.9390
# [Epoch 75/100] Train Loss: 0.0000, Val Loss: 2.9749
# [Epoch 80/100] Train Loss: 0.0000, Val Loss: 3.0118
# [Epoch 85/100] Train Loss: 0.0000, Val Loss: 3.0495
# [Epoch 90/100] Train Loss: 0.0000, Val Loss: 3.0880
# [Epoch 95/100] Train Loss: 0.0000, Val Loss: 3.1272
# [Epoch 100/100] Train Loss: 0.0000, Val Loss: 3.1670
# Accuracy on Nonzero Predictions: 0.5038
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/learning_rates_processing/AAPL_pca_lstm_lr0.01_options.png
# Training AAPL | LR: 0.011 | Epochs: 100 | Batch: 32 | Prediction Threshold: 0.5
# [Epoch 5/100] Train Loss: 0.0619, Val Loss: 2.6138
# [Epoch 10/100] Train Loss: 0.0405, Val Loss: 2.5910
# [Epoch 15/100] Train Loss: 0.0512, Val Loss: 2.8485
# [Epoch 20/100] Train Loss: 0.0166, Val Loss: 3.0525
# [Epoch 25/100] Train Loss: 0.0236, Val Loss: 3.1428
# [Epoch 30/100] Train Loss: 0.0197, Val Loss: 3.7901
# [Epoch 35/100] Train Loss: 0.0357, Val Loss: 3.5215
# [Epoch 40/100] Train Loss: 0.0086, Val Loss: 2.8031
# [Epoch 45/100] Train Loss: 0.1261, Val Loss: 3.4015
# [Epoch 50/100] Train Loss: 0.0407, Val Loss: 3.4930
# [Epoch 55/100] Train Loss: 0.0129, Val Loss: 3.6761
# [Epoch 60/100] Train Loss: 0.0030, Val Loss: 3.6005
# [Epoch 65/100] Train Loss: 0.0039, Val Loss: 3.9924
# [Epoch 70/100] Train Loss: 0.0572, Val Loss: 4.1896
# [Epoch 75/100] Train Loss: 0.0476, Val Loss: 3.7026
# [Epoch 80/100] Train Loss: 0.0166, Val Loss: 3.4966
# [Epoch 85/100] Train Loss: 0.0140, Val Loss: 3.1136
# [Epoch 90/100] Train Loss: 0.0311, Val Loss: 3.3088
# [Epoch 95/100] Train Loss: 0.0184, Val Loss: 3.9959
# [Epoch 100/100] Train Loss: 0.0129, Val Loss: 3.5119
# Accuracy on Nonzero Predictions: 0.4885
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/learning_rates_processing/AAPL_pca_lstm_lr0.011_options.png
# [0.5572519083969466, 0.5038167938931297, 0.48854961832061067]
# [-99.96163502137065, -99.91899498276511, -0.686936369400345]
# clean, gru, single_name
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/clean/single_name/AAPL/10y_5_data.pkl
# Training AAPL | LR: 0.009 | Epochs: 100 | Batch: 32 | Prediction Threshold: 0.5
# [Epoch 5/100] Train Loss: 0.6937, Val Loss: 0.6961
# [Epoch 10/100] Train Loss: 0.6935, Val Loss: 0.6913
# [Epoch 15/100] Train Loss: 0.6924, Val Loss: 0.6950
# [Epoch 20/100] Train Loss: 0.6908, Val Loss: 0.6819
# [Epoch 25/100] Train Loss: 0.6803, Val Loss: 0.7062
# [Epoch 30/100] Train Loss: 0.6758, Val Loss: 0.6934
# [Epoch 35/100] Train Loss: 0.6672, Val Loss: 0.6791
# [Epoch 40/100] Train Loss: 0.6576, Val Loss: 0.6864
# [Epoch 45/100] Train Loss: 0.6467, Val Loss: 0.6687
# [Epoch 50/100] Train Loss: 0.6347, Val Loss: 0.6771
# [Epoch 55/100] Train Loss: 0.6338, Val Loss: 0.6917
# [Epoch 60/100] Train Loss: 0.6131, Val Loss: 0.7041
# [Epoch 65/100] Train Loss: 0.6129, Val Loss: 0.7265
# [Epoch 70/100] Train Loss: 0.5995, Val Loss: 0.7271
# [Epoch 75/100] Train Loss: 0.5997, Val Loss: 0.7490
# [Epoch 80/100] Train Loss: 0.5768, Val Loss: 0.7136
# [Epoch 85/100] Train Loss: 0.5709, Val Loss: 0.7308
# [Epoch 90/100] Train Loss: 0.5662, Val Loss: 0.7487
# [Epoch 95/100] Train Loss: 0.5696, Val Loss: 0.7376
# [Epoch 100/100] Train Loss: 0.5789, Val Loss: 0.7042
# Accuracy on Nonzero Predictions: 0.5191
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/learning_rates_processing/AAPL_clean_gru_lr0.009_single_name.png
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Prediction Threshold: 0.5
# [Epoch 5/100] Train Loss: 0.5643, Val Loss: 0.7955
# [Epoch 10/100] Train Loss: 0.5512, Val Loss: 0.7650
# [Epoch 15/100] Train Loss: 0.5509, Val Loss: 0.8309
# [Epoch 20/100] Train Loss: 0.5472, Val Loss: 0.6985
# [Epoch 25/100] Train Loss: 0.5354, Val Loss: 0.7369
# [Epoch 30/100] Train Loss: 0.5539, Val Loss: 0.7460
# [Epoch 35/100] Train Loss: 0.5273, Val Loss: 0.8830
# [Epoch 40/100] Train Loss: 0.5361, Val Loss: 0.7362
# [Epoch 45/100] Train Loss: 0.5116, Val Loss: 0.8401
# [Epoch 50/100] Train Loss: 0.5150, Val Loss: 0.8453
# [Epoch 55/100] Train Loss: 0.5146, Val Loss: 0.8123
# [Epoch 60/100] Train Loss: 0.5075, Val Loss: 0.9751
# [Epoch 65/100] Train Loss: 0.5032, Val Loss: 0.9100
# [Epoch 70/100] Train Loss: 0.5131, Val Loss: 0.7885
# [Epoch 75/100] Train Loss: 0.4976, Val Loss: 0.7457
# [Epoch 80/100] Train Loss: 0.4992, Val Loss: 0.8433
# [Epoch 85/100] Train Loss: 0.5034, Val Loss: 0.7870
# [Epoch 90/100] Train Loss: 0.4966, Val Loss: 0.8394
# [Epoch 95/100] Train Loss: 0.4916, Val Loss: 0.8629
# [Epoch 100/100] Train Loss: 0.4965, Val Loss: 0.7719
# Accuracy on Nonzero Predictions: 0.5267
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/learning_rates_processing/AAPL_clean_gru_lr0.01_single_name.png
# Training AAPL | LR: 0.011 | Epochs: 100 | Batch: 32 | Prediction Threshold: 0.5
# [Epoch 5/100] Train Loss: 0.4939, Val Loss: 0.8231
# [Epoch 10/100] Train Loss: 0.4780, Val Loss: 0.8863
# [Epoch 15/100] Train Loss: 0.4790, Val Loss: 0.8269
# [Epoch 20/100] Train Loss: 0.4862, Val Loss: 0.8229
# [Epoch 25/100] Train Loss: 0.4866, Val Loss: 0.9622
# [Epoch 30/100] Train Loss: 0.4714, Val Loss: 0.8833
# [Epoch 35/100] Train Loss: 0.4701, Val Loss: 0.8463
# [Epoch 40/100] Train Loss: 0.4691, Val Loss: 0.7831
# [Epoch 45/100] Train Loss: 0.4970, Val Loss: 0.8747
# [Epoch 50/100] Train Loss: 0.4548, Val Loss: 0.9016
# [Epoch 55/100] Train Loss: 0.4632, Val Loss: 0.9030
# [Epoch 60/100] Train Loss: 0.4584, Val Loss: 0.9768
# [Epoch 65/100] Train Loss: 0.4577, Val Loss: 0.9145
# [Epoch 70/100] Train Loss: 0.4406, Val Loss: 0.9419
# [Epoch 75/100] Train Loss: 0.4538, Val Loss: 0.9014
# [Epoch 80/100] Train Loss: 0.4552, Val Loss: 1.0184
# [Epoch 85/100] Train Loss: 0.4544, Val Loss: 0.8794
# [Epoch 90/100] Train Loss: 0.4607, Val Loss: 0.9649
# [Epoch 95/100] Train Loss: 0.4477, Val Loss: 0.9427
# [Epoch 100/100] Train Loss: 0.4547, Val Loss: 0.8918
# Accuracy on Nonzero Predictions: 0.5038
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/learning_rates_processing/AAPL_clean_gru_lr0.011_single_name.png
# [0.5190839694656488, 0.5267175572519084, 0.5038167938931297]
# [-16.792655875728922, -12.41467446432307, -9.154734618234418]
# pca, gru, technical
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/AAPL/10y_5_data.pkl
# Training AAPL | LR: 0.009 | Epochs: 100 | Batch: 32 | Prediction Threshold: 0.5
# [Epoch 5/100] Train Loss: 0.6938, Val Loss: 0.6817
# [Epoch 10/100] Train Loss: 0.6936, Val Loss: 0.6876
# [Epoch 15/100] Train Loss: 0.6912, Val Loss: 0.7136
# [Epoch 20/100] Train Loss: 0.7061, Val Loss: 0.7718
# [Epoch 25/100] Train Loss: 0.7006, Val Loss: 0.6827
# [Epoch 30/100] Train Loss: 0.7001, Val Loss: 0.6819
# [Epoch 35/100] Train Loss: 0.6979, Val Loss: 0.6725
# [Epoch 40/100] Train Loss: 0.6954, Val Loss: 0.6823
# [Epoch 45/100] Train Loss: 0.6952, Val Loss: 0.6777
# [Epoch 50/100] Train Loss: 0.6933, Val Loss: 0.6947
# [Epoch 55/100] Train Loss: 0.6912, Val Loss: 0.6894
# [Epoch 60/100] Train Loss: 0.6929, Val Loss: 0.6753
# [Epoch 65/100] Train Loss: 0.6879, Val Loss: 0.7050
# [Epoch 70/100] Train Loss: 0.6931, Val Loss: 0.6888
# [Epoch 75/100] Train Loss: 0.6968, Val Loss: 0.6964
# [Epoch 80/100] Train Loss: 0.6952, Val Loss: 0.6714
# [Epoch 85/100] Train Loss: 0.6941, Val Loss: 0.6882
# [Epoch 90/100] Train Loss: 0.6919, Val Loss: 0.6948
# [Epoch 95/100] Train Loss: 0.6936, Val Loss: 0.6886
# [Epoch 100/100] Train Loss: 0.6931, Val Loss: 0.6879
# Accuracy on Nonzero Predictions: 0.5317
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/learning_rates_processing/AAPL_pca_gru_lr0.009_technical.png
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Prediction Threshold: 0.5
# [Epoch 5/100] Train Loss: 0.6923, Val Loss: 0.6953
# [Epoch 10/100] Train Loss: 0.6938, Val Loss: 0.6861
# [Epoch 15/100] Train Loss: 0.6926, Val Loss: 0.6855
# [Epoch 20/100] Train Loss: 0.6903, Val Loss: 0.7013
# [Epoch 25/100] Train Loss: 0.6880, Val Loss: 0.7049
# [Epoch 30/100] Train Loss: 0.6900, Val Loss: 0.7137
# [Epoch 35/100] Train Loss: 0.6873, Val Loss: 0.7038
# [Epoch 40/100] Train Loss: 0.6885, Val Loss: 0.7225
# [Epoch 45/100] Train Loss: 0.6859, Val Loss: 0.7240
# [Epoch 50/100] Train Loss: 0.6825, Val Loss: 0.7235
# [Epoch 55/100] Train Loss: 0.6821, Val Loss: 0.7170
# [Epoch 60/100] Train Loss: 0.6813, Val Loss: 0.7160
# [Epoch 65/100] Train Loss: 0.6906, Val Loss: 0.6924
# [Epoch 70/100] Train Loss: 0.6789, Val Loss: 0.7150
# [Epoch 75/100] Train Loss: 0.6838, Val Loss: 0.7039
# [Epoch 80/100] Train Loss: 0.6857, Val Loss: 0.6972
# [Epoch 85/100] Train Loss: 0.6832, Val Loss: 0.6904
# [Epoch 90/100] Train Loss: 0.6844, Val Loss: 0.7186
# [Epoch 95/100] Train Loss: 0.6826, Val Loss: 0.7169
# [Epoch 100/100] Train Loss: 0.6920, Val Loss: 0.7007
# Accuracy on Nonzero Predictions: 0.5794
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/learning_rates_processing/AAPL_pca_gru_lr0.01_technical.png
# Training AAPL | LR: 0.011 | Epochs: 100 | Batch: 32 | Prediction Threshold: 0.5
# [Epoch 5/100] Train Loss: 0.6813, Val Loss: 0.7177
# [Epoch 10/100] Train Loss: 0.6839, Val Loss: 0.7112
# [Epoch 15/100] Train Loss: 0.6836, Val Loss: 0.7044
# [Epoch 20/100] Train Loss: 0.6827, Val Loss: 0.7045
# [Epoch 25/100] Train Loss: 0.6824, Val Loss: 0.6978
# [Epoch 30/100] Train Loss: 0.6858, Val Loss: 0.6869
# [Epoch 35/100] Train Loss: 0.6895, Val Loss: 0.7161
# [Epoch 40/100] Train Loss: 0.6872, Val Loss: 0.6933
# [Epoch 45/100] Train Loss: 0.6871, Val Loss: 0.7032
# [Epoch 50/100] Train Loss: 0.6878, Val Loss: 0.7133
# [Epoch 55/100] Train Loss: 0.6936, Val Loss: 0.7047
# [Epoch 60/100] Train Loss: 0.6908, Val Loss: 0.6951
# [Epoch 65/100] Train Loss: 0.6918, Val Loss: 0.6932
# [Epoch 70/100] Train Loss: 0.6905, Val Loss: 0.7179
# [Epoch 75/100] Train Loss: 0.6926, Val Loss: 0.7217
# [Epoch 80/100] Train Loss: 0.6917, Val Loss: 0.7077
# [Epoch 85/100] Train Loss: 0.6924, Val Loss: 0.6952
# [Epoch 90/100] Train Loss: 0.6899, Val Loss: 0.6859
# [Epoch 95/100] Train Loss: 0.6891, Val Loss: 0.7014
# [Epoch 100/100] Train Loss: 0.6805, Val Loss: 0.7031
# Accuracy on Nonzero Predictions: 0.4286
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/learning_rates_processing/AAPL_pca_gru_lr0.011_technical.png
# [0.5317460317460317, 0.5793650793650794, 0.42857142857142855]
# [-0.4192388856678447, -0.31321320314540524, -1.065557371583325]
# pca, gru, options
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/options/AAPL/10y_5_data.pkl
# Training AAPL | LR: 0.009 | Epochs: 100 | Batch: 32 | Prediction Threshold: 0.5
# [Epoch 5/100] Train Loss: 0.6908, Val Loss: 0.6938
# [Epoch 10/100] Train Loss: 0.6919, Val Loss: 0.6821
# [Epoch 15/100] Train Loss: 0.6818, Val Loss: 0.7279
# [Epoch 20/100] Train Loss: 0.6829, Val Loss: 0.6762
# [Epoch 25/100] Train Loss: 0.6817, Val Loss: 0.6730
# [Epoch 30/100] Train Loss: 0.6830, Val Loss: 0.6793
# [Epoch 35/100] Train Loss: 0.6770, Val Loss: 0.6710
# [Epoch 40/100] Train Loss: 0.6701, Val Loss: 0.6670
# [Epoch 45/100] Train Loss: 0.6715, Val Loss: 0.6700
# [Epoch 50/100] Train Loss: 0.6636, Val Loss: 0.6776
# [Epoch 55/100] Train Loss: 0.6578, Val Loss: 0.6826
# [Epoch 60/100] Train Loss: 0.6541, Val Loss: 0.7180
# [Epoch 65/100] Train Loss: 0.6424, Val Loss: 0.7314
# [Epoch 70/100] Train Loss: 0.6207, Val Loss: 0.7897
# [Epoch 75/100] Train Loss: 0.6379, Val Loss: 0.8810
# [Epoch 80/100] Train Loss: 0.6115, Val Loss: 0.9711
# [Epoch 85/100] Train Loss: 0.5805, Val Loss: 1.1921
# [Epoch 90/100] Train Loss: 0.5728, Val Loss: 1.1175
# [Epoch 95/100] Train Loss: 0.5565, Val Loss: 1.0781
# [Epoch 100/100] Train Loss: 0.5375, Val Loss: 0.9918
# Accuracy on Nonzero Predictions: 0.5954
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/learning_rates_processing/AAPL_pca_gru_lr0.009_options.png
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Prediction Threshold: 0.5
# [Epoch 5/100] Train Loss: 0.5085, Val Loss: 1.2982
# [Epoch 10/100] Train Loss: 0.4835, Val Loss: 1.3433
# [Epoch 15/100] Train Loss: 0.4544, Val Loss: 1.5462
# [Epoch 20/100] Train Loss: 0.4648, Val Loss: 1.6853
# [Epoch 25/100] Train Loss: 0.4310, Val Loss: 1.6521
# [Epoch 30/100] Train Loss: 0.4157, Val Loss: 1.8291
# [Epoch 35/100] Train Loss: 0.4263, Val Loss: 1.6292
# [Epoch 40/100] Train Loss: 0.4040, Val Loss: 1.6613
# [Epoch 45/100] Train Loss: 0.3960, Val Loss: 1.6771
# [Epoch 50/100] Train Loss: 0.3950, Val Loss: 1.6372
# [Epoch 55/100] Train Loss: 0.3871, Val Loss: 1.8126
# [Epoch 60/100] Train Loss: 0.3780, Val Loss: 2.1709
# [Epoch 65/100] Train Loss: 0.3422, Val Loss: 2.3114
# [Epoch 70/100] Train Loss: 0.3474, Val Loss: 2.3281
# [Epoch 75/100] Train Loss: 0.3147, Val Loss: 2.0703
# [Epoch 80/100] Train Loss: 0.3161, Val Loss: 2.1075
# [Epoch 85/100] Train Loss: 0.2870, Val Loss: 2.5818
# [Epoch 90/100] Train Loss: 0.3332, Val Loss: 2.1390
# [Epoch 95/100] Train Loss: 0.3005, Val Loss: 2.1322
# [Epoch 100/100] Train Loss: 0.2798, Val Loss: 2.2076
# Accuracy on Nonzero Predictions: 0.5496
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/learning_rates_processing/AAPL_pca_gru_lr0.01_options.png
# Training AAPL | LR: 0.011 | Epochs: 100 | Batch: 32 | Prediction Threshold: 0.5
# [Epoch 5/100] Train Loss: 0.3261, Val Loss: 2.4806
# [Epoch 10/100] Train Loss: 0.3030, Val Loss: 2.0734
# [Epoch 15/100] Train Loss: 0.2648, Val Loss: 1.7170
# [Epoch 20/100] Train Loss: 0.3016, Val Loss: 2.0795
# [Epoch 25/100] Train Loss: 0.2684, Val Loss: 2.2461
# [Epoch 30/100] Train Loss: 0.2868, Val Loss: 2.2955
# [Epoch 35/100] Train Loss: 0.2952, Val Loss: 2.5744
# [Epoch 40/100] Train Loss: 0.2739, Val Loss: 2.5355
# [Epoch 45/100] Train Loss: 0.3040, Val Loss: 2.1355
# [Epoch 50/100] Train Loss: 0.2687, Val Loss: 2.2955
# [Epoch 55/100] Train Loss: 0.2593, Val Loss: 2.1996
# [Epoch 60/100] Train Loss: 0.2481, Val Loss: 2.4593
# [Epoch 65/100] Train Loss: 0.2129, Val Loss: 2.4244
# [Epoch 70/100] Train Loss: 0.2406, Val Loss: 2.3859
# [Epoch 75/100] Train Loss: 0.3110, Val Loss: 1.9257
# [Epoch 80/100] Train Loss: 0.2413, Val Loss: 2.1429
# [Epoch 85/100] Train Loss: 0.2481, Val Loss: 2.1850
# [Epoch 90/100] Train Loss: 0.2607, Val Loss: 2.0083
# [Epoch 95/100] Train Loss: 0.2680, Val Loss: 1.8549
# [Epoch 100/100] Train Loss: 0.2374, Val Loss: 2.1079
# Accuracy on Nonzero Predictions: 0.5878
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/learning_rates_processing/AAPL_pca_gru_lr0.011_options.png
# [0.5954198473282443, 0.549618320610687, 0.5877862595419847]
# [-22.8951912405555, -47.6925169823348, -16.939510121364027]
# clean, lstm, single_name
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/clean/single_name/AAPL/10y_5_data.pkl
# Training AAPL | LR: 0.009 | Epochs: 100 | Batch: 32 | Prediction Threshold: 0.5
# [Epoch 5/100] Train Loss: 0.6934, Val Loss: 0.6915
# [Epoch 10/100] Train Loss: 0.6917, Val Loss: 0.6926
# [Epoch 15/100] Train Loss: 0.6895, Val Loss: 0.6910
# [Epoch 20/100] Train Loss: 0.6879, Val Loss: 0.6874
# [Epoch 25/100] Train Loss: 0.6845, Val Loss: 0.6832
# [Epoch 30/100] Train Loss: 0.6797, Val Loss: 0.6802
# [Epoch 35/100] Train Loss: 0.6758, Val Loss: 0.6787
# [Epoch 40/100] Train Loss: 0.6723, Val Loss: 0.6762
# [Epoch 45/100] Train Loss: 0.6695, Val Loss: 0.6724
# [Epoch 50/100] Train Loss: 0.6669, Val Loss: 0.6682
# [Epoch 55/100] Train Loss: 0.6633, Val Loss: 0.6659
# [Epoch 60/100] Train Loss: 0.6591, Val Loss: 0.6680
# [Epoch 65/100] Train Loss: 0.6548, Val Loss: 0.6716
# [Epoch 70/100] Train Loss: 0.6508, Val Loss: 0.6765
# [Epoch 75/100] Train Loss: 0.6471, Val Loss: 0.6819
# [Epoch 80/100] Train Loss: 0.6420, Val Loss: 0.6977
# [Epoch 85/100] Train Loss: 0.6348, Val Loss: 0.7160
# [Epoch 90/100] Train Loss: 0.6285, Val Loss: 0.7243
# [Epoch 95/100] Train Loss: 0.6217, Val Loss: 0.7328
# [Epoch 100/100] Train Loss: 0.6152, Val Loss: 0.7449
# Accuracy on Nonzero Predictions: 0.5115
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/learning_rates_processing/AAPL_clean_lstm_lr0.009_single_name.png
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Prediction Threshold: 0.5
# [Epoch 5/100] Train Loss: 0.6080, Val Loss: 0.7525
# [Epoch 10/100] Train Loss: 0.6032, Val Loss: 0.7616
# [Epoch 15/100] Train Loss: 0.5986, Val Loss: 0.7703
# [Epoch 20/100] Train Loss: 0.5939, Val Loss: 0.7819
# [Epoch 25/100] Train Loss: 0.5892, Val Loss: 0.7952
# [Epoch 30/100] Train Loss: 0.5847, Val Loss: 0.8075
# [Epoch 35/100] Train Loss: 0.5807, Val Loss: 0.8185
# [Epoch 40/100] Train Loss: 0.5770, Val Loss: 0.8284
# [Epoch 45/100] Train Loss: 0.5733, Val Loss: 0.8369
# [Epoch 50/100] Train Loss: 0.5700, Val Loss: 0.8463
# [Epoch 55/100] Train Loss: 0.5658, Val Loss: 0.8549
# [Epoch 60/100] Train Loss: 0.5617, Val Loss: 0.8652
# [Epoch 65/100] Train Loss: 0.5574, Val Loss: 0.8782
# [Epoch 70/100] Train Loss: 0.5528, Val Loss: 0.8945
# [Epoch 75/100] Train Loss: 0.5477, Val Loss: 0.9122
# [Epoch 80/100] Train Loss: 0.5428, Val Loss: 0.9313
# [Epoch 85/100] Train Loss: 0.5384, Val Loss: 0.9473
# [Epoch 90/100] Train Loss: 0.5344, Val Loss: 0.9560
# [Epoch 95/100] Train Loss: 0.5307, Val Loss: 0.9605
# [Epoch 100/100] Train Loss: 0.5271, Val Loss: 0.9625
# Accuracy on Nonzero Predictions: 0.3893
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/learning_rates_processing/AAPL_clean_lstm_lr0.01_single_name.png
# Training AAPL | LR: 0.011 | Epochs: 100 | Batch: 32 | Prediction Threshold: 0.5
# [Epoch 5/100] Train Loss: 0.5253, Val Loss: 0.9648
# [Epoch 10/100] Train Loss: 0.5226, Val Loss: 0.9674
# [Epoch 15/100] Train Loss: 0.5199, Val Loss: 0.9716
# [Epoch 20/100] Train Loss: 0.5173, Val Loss: 0.9763
# [Epoch 25/100] Train Loss: 0.5147, Val Loss: 0.9813
# [Epoch 30/100] Train Loss: 0.5121, Val Loss: 0.9858
# [Epoch 35/100] Train Loss: 0.5097, Val Loss: 0.9883
# [Epoch 40/100] Train Loss: 0.5073, Val Loss: 0.9886
# [Epoch 45/100] Train Loss: 0.5048, Val Loss: 0.9919
# [Epoch 50/100] Train Loss: 0.5024, Val Loss: 0.9977
# [Epoch 55/100] Train Loss: 0.5046, Val Loss: 1.0030
# [Epoch 60/100] Train Loss: 0.4996, Val Loss: 1.0092
# [Epoch 65/100] Train Loss: 0.5012, Val Loss: 1.0087
# [Epoch 70/100] Train Loss: 0.4930, Val Loss: 1.0147
# [Epoch 75/100] Train Loss: 0.4901, Val Loss: 1.0188
# [Epoch 80/100] Train Loss: 0.4875, Val Loss: 1.0230
# [Epoch 85/100] Train Loss: 0.4852, Val Loss: 1.0271
# [Epoch 90/100] Train Loss: 0.4828, Val Loss: 1.0304
# [Epoch 95/100] Train Loss: 0.4816, Val Loss: 1.0354
# [Epoch 100/100] Train Loss: 0.4779, Val Loss: 1.0443
# Accuracy on Nonzero Predictions: 0.4885
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/learning_rates_processing/AAPL_clean_lstm_lr0.011_single_name.png
# [0.5114503816793893, 0.3893129770992366, 0.48854961832061067]
# [-11.550413912684116, -14.545753596412458, -10.600531244732844]
# clean, lstm, technical
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/clean/technical/AAPL/10y_5_data.pkl
# Training AAPL | LR: 0.009 | Epochs: 100 | Batch: 32 | Prediction Threshold: 0.5
# [Epoch 5/100] Train Loss: 0.6930, Val Loss: 0.6927
# [Epoch 10/100] Train Loss: 0.6847, Val Loss: 0.7121
# [Epoch 15/100] Train Loss: 0.6521, Val Loss: 0.7416
# [Epoch 20/100] Train Loss: 0.5528, Val Loss: 0.7981
# [Epoch 25/100] Train Loss: 0.4558, Val Loss: 1.1176
# [Epoch 30/100] Train Loss: 0.3720, Val Loss: 1.1487
# [Epoch 35/100] Train Loss: 0.2858, Val Loss: 1.4474
# [Epoch 40/100] Train Loss: 0.2074, Val Loss: 1.7580
# [Epoch 45/100] Train Loss: 0.1700, Val Loss: 2.1497
# [Epoch 50/100] Train Loss: 0.1320, Val Loss: 2.2471
# [Epoch 55/100] Train Loss: 0.0809, Val Loss: 2.5417
# [Epoch 60/100] Train Loss: 0.0959, Val Loss: 2.8123
# [Epoch 65/100] Train Loss: 0.0725, Val Loss: 2.3319
# [Epoch 70/100] Train Loss: 0.0445, Val Loss: 2.5149
# [Epoch 75/100] Train Loss: 0.0674, Val Loss: 2.6787
# [Epoch 80/100] Train Loss: 0.1270, Val Loss: 2.8613
# [Epoch 85/100] Train Loss: 0.0652, Val Loss: 3.2304
# [Epoch 90/100] Train Loss: 0.0344, Val Loss: 3.3497
# [Epoch 95/100] Train Loss: 0.0525, Val Loss: 3.4957
# [Epoch 100/100] Train Loss: 0.0623, Val Loss: 3.2482
# Accuracy on Nonzero Predictions: 0.5238
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/learning_rates_processing/AAPL_clean_lstm_lr0.009_technical.png
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Prediction Threshold: 0.5
# [Epoch 5/100] Train Loss: 0.0552, Val Loss: 3.8846
# [Epoch 10/100] Train Loss: 0.0990, Val Loss: 3.4486
# [Epoch 15/100] Train Loss: 0.0547, Val Loss: 3.2830
# [Epoch 20/100] Train Loss: 0.0350, Val Loss: 3.9525
# [Epoch 25/100] Train Loss: 0.0496, Val Loss: 3.7888
# [Epoch 30/100] Train Loss: 0.1241, Val Loss: 4.3597
# [Epoch 35/100] Train Loss: 0.0551, Val Loss: 3.8259
# [Epoch 40/100] Train Loss: 0.0706, Val Loss: 3.5573
# [Epoch 45/100] Train Loss: 0.0550, Val Loss: 4.0413
# [Epoch 50/100] Train Loss: 0.0569, Val Loss: 4.2690
# [Epoch 55/100] Train Loss: 0.0582, Val Loss: 4.1031
# [Epoch 60/100] Train Loss: 0.0576, Val Loss: 4.5606
# [Epoch 65/100] Train Loss: 0.0514, Val Loss: 4.1947
# [Epoch 70/100] Train Loss: 0.0583, Val Loss: 4.7340
# [Epoch 75/100] Train Loss: 0.0865, Val Loss: 4.3517
# [Epoch 80/100] Train Loss: 0.0629, Val Loss: 3.8690
# [Epoch 85/100] Train Loss: 0.0371, Val Loss: 4.0685
# [Epoch 90/100] Train Loss: 0.0747, Val Loss: 4.3114
# [Epoch 95/100] Train Loss: 0.1037, Val Loss: 4.0680
# [Epoch 100/100] Train Loss: 0.0542, Val Loss: 3.4117
# Accuracy on Nonzero Predictions: 0.5317
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/learning_rates_processing/AAPL_clean_lstm_lr0.01_technical.png
# Training AAPL | LR: 0.011 | Epochs: 100 | Batch: 32 | Prediction Threshold: 0.5
# [Epoch 5/100] Train Loss: 0.1017, Val Loss: 3.2805
# [Epoch 10/100] Train Loss: 0.0755, Val Loss: 3.5774
# [Epoch 15/100] Train Loss: 0.0484, Val Loss: 3.2637
# [Epoch 20/100] Train Loss: 0.0786, Val Loss: 3.6122
# [Epoch 25/100] Train Loss: 0.0378, Val Loss: 4.1683
# [Epoch 30/100] Train Loss: 0.1051, Val Loss: 3.5546
# [Epoch 35/100] Train Loss: 0.0510, Val Loss: 3.7499
# [Epoch 40/100] Train Loss: 0.1126, Val Loss: 4.0203
# [Epoch 45/100] Train Loss: 0.0551, Val Loss: 3.7710
# [Epoch 50/100] Train Loss: 0.0545, Val Loss: 3.3123
# [Epoch 55/100] Train Loss: 0.0711, Val Loss: 3.8161
# [Epoch 60/100] Train Loss: 0.0430, Val Loss: 3.8660
# [Epoch 65/100] Train Loss: 0.0199, Val Loss: 3.2461
# [Epoch 70/100] Train Loss: 0.0659, Val Loss: 3.5051
# [Epoch 75/100] Train Loss: 0.0902, Val Loss: 3.4973
# [Epoch 80/100] Train Loss: 0.0621, Val Loss: 3.9207
# [Epoch 85/100] Train Loss: 0.0731, Val Loss: 3.5291
# [Epoch 90/100] Train Loss: 0.0654, Val Loss: 3.7533
# [Epoch 95/100] Train Loss: 0.0277, Val Loss: 3.9345
# [Epoch 100/100] Train Loss: 0.0402, Val Loss: 4.0210
# Accuracy on Nonzero Predictions: 0.5873
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/learning_rates_processing/AAPL_clean_lstm_lr0.011_technical.png
# [0.5238095238095238, 0.5317460317460317, 0.5873015873015873]
# [-91.03890838083457, 1.3335545716834325, -52.62435661804824]
# clean, lstm, options
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/clean/options/AAPL/10y_5_data.pkl
# Training AAPL | LR: 0.009 | Epochs: 100 | Batch: 32 | Prediction Threshold: 0.5
# [Epoch 5/100] Train Loss: 0.6892, Val Loss: 0.6829
# [Epoch 10/100] Train Loss: 0.6818, Val Loss: 0.6882
# [Epoch 15/100] Train Loss: 0.6521, Val Loss: 0.6810
# [Epoch 20/100] Train Loss: 0.5449, Val Loss: 0.7579
# [Epoch 25/100] Train Loss: 0.4099, Val Loss: 0.8192
# [Epoch 30/100] Train Loss: 0.3106, Val Loss: 1.0505
# [Epoch 35/100] Train Loss: 0.2360, Val Loss: 1.1664
# [Epoch 40/100] Train Loss: 0.1615, Val Loss: 1.4256
# [Epoch 45/100] Train Loss: 0.1069, Val Loss: 1.5860
# [Epoch 50/100] Train Loss: 0.0720, Val Loss: 1.8157
# [Epoch 55/100] Train Loss: 0.0657, Val Loss: 1.8589
# [Epoch 60/100] Train Loss: 0.0777, Val Loss: 1.9371
# [Epoch 65/100] Train Loss: 0.0276, Val Loss: 2.1768
# [Epoch 70/100] Train Loss: 0.0385, Val Loss: 2.1017
# [Epoch 75/100] Train Loss: 0.0387, Val Loss: 2.1581
# [Epoch 80/100] Train Loss: 0.0842, Val Loss: 2.3816
# [Epoch 85/100] Train Loss: 0.0843, Val Loss: 2.2093
# [Epoch 90/100] Train Loss: 0.0231, Val Loss: 2.4853
# [Epoch 95/100] Train Loss: 0.0285, Val Loss: 2.6213
# [Epoch 100/100] Train Loss: 0.0240, Val Loss: 2.3774
# Accuracy on Nonzero Predictions: 0.5344
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/learning_rates_processing/AAPL_clean_lstm_lr0.009_options.png
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Prediction Threshold: 0.5
# [Epoch 5/100] Train Loss: 0.0443, Val Loss: 2.2305
# [Epoch 10/100] Train Loss: 0.0421, Val Loss: 3.0306
# [Epoch 15/100] Train Loss: 0.0299, Val Loss: 2.5434
# [Epoch 20/100] Train Loss: 0.0631, Val Loss: 2.7516
# [Epoch 25/100] Train Loss: 0.0746, Val Loss: 2.8890
# [Epoch 30/100] Train Loss: 0.0365, Val Loss: 3.1856
# [Epoch 35/100] Train Loss: 0.0321, Val Loss: 3.4125
# [Epoch 40/100] Train Loss: 0.0453, Val Loss: 2.8044
# [Epoch 45/100] Train Loss: 0.0697, Val Loss: 2.6146
# [Epoch 50/100] Train Loss: 0.0616, Val Loss: 2.6263
# [Epoch 55/100] Train Loss: 0.0212, Val Loss: 3.2392
# [Epoch 60/100] Train Loss: 0.0008, Val Loss: 3.4392
# [Epoch 65/100] Train Loss: 0.0005, Val Loss: 3.5281
# [Epoch 70/100] Train Loss: 0.0004, Val Loss: 3.5935
# [Epoch 75/100] Train Loss: 0.0003, Val Loss: 3.6540
# [Epoch 80/100] Train Loss: 0.0002, Val Loss: 3.7130
# [Epoch 85/100] Train Loss: 0.0002, Val Loss: 3.7736
# [Epoch 90/100] Train Loss: 0.0001, Val Loss: 3.8367
# [Epoch 95/100] Train Loss: 0.0001, Val Loss: 3.8975
# [Epoch 100/100] Train Loss: 0.0001, Val Loss: 3.9497
# Accuracy on Nonzero Predictions: 0.4275
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/learning_rates_processing/AAPL_clean_lstm_lr0.01_options.png
# Training AAPL | LR: 0.011 | Epochs: 100 | Batch: 32 | Prediction Threshold: 0.5
# [Epoch 5/100] Train Loss: 0.0547, Val Loss: 3.3801
# [Epoch 10/100] Train Loss: 0.0883, Val Loss: 3.2185
# [Epoch 15/100] Train Loss: 0.0893, Val Loss: 2.6368
# [Epoch 20/100] Train Loss: 0.0418, Val Loss: 2.9290
# [Epoch 25/100] Train Loss: 0.0583, Val Loss: 2.5934
# [Epoch 30/100] Train Loss: 0.0379, Val Loss: 3.1018
# [Epoch 35/100] Train Loss: 0.0264, Val Loss: 2.7749
# [Epoch 40/100] Train Loss: 0.0738, Val Loss: 3.3016
# [Epoch 45/100] Train Loss: 0.0476, Val Loss: 2.7750
# [Epoch 50/100] Train Loss: 0.0479, Val Loss: 3.1924
# [Epoch 55/100] Train Loss: 0.0091, Val Loss: 3.6581
# [Epoch 60/100] Train Loss: 0.0830, Val Loss: 2.6948
# [Epoch 65/100] Train Loss: 0.0570, Val Loss: 3.3683
# [Epoch 70/100] Train Loss: 0.0375, Val Loss: 3.0912
# [Epoch 75/100] Train Loss: 0.0114, Val Loss: 2.6987
# [Epoch 80/100] Train Loss: 0.0802, Val Loss: 2.7091
# [Epoch 85/100] Train Loss: 0.0550, Val Loss: 2.6749
# [Epoch 90/100] Train Loss: 0.0311, Val Loss: 2.8491
# [Epoch 95/100] Train Loss: 0.0183, Val Loss: 3.2593
# [Epoch 100/100] Train Loss: 0.0330, Val Loss: 3.5737
# Accuracy on Nonzero Predictions: 0.5115
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/learning_rates_processing/AAPL_clean_lstm_lr0.011_options.png
# [0.5343511450381679, 0.42748091603053434, 0.5114503816793893]
# [-96.54213977337199, -99.78680791459159, 23.926010035884303]
# clean, gru, single_name
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/clean/single_name/AAPL/10y_5_data.pkl
# Training AAPL | LR: 0.009 | Epochs: 100 | Batch: 32 | Prediction Threshold: 0.5
# [Epoch 5/100] Train Loss: 0.6935, Val Loss: 0.6939
# [Epoch 10/100] Train Loss: 0.6931, Val Loss: 0.6949
# [Epoch 15/100] Train Loss: 0.6893, Val Loss: 0.6965
# [Epoch 20/100] Train Loss: 0.6866, Val Loss: 0.6891
# [Epoch 25/100] Train Loss: 0.6795, Val Loss: 0.7114
# [Epoch 30/100] Train Loss: 0.6761, Val Loss: 0.6954
# [Epoch 35/100] Train Loss: 0.6686, Val Loss: 0.6963
# [Epoch 40/100] Train Loss: 0.6581, Val Loss: 0.6984
# [Epoch 45/100] Train Loss: 0.6514, Val Loss: 0.6965
# [Epoch 50/100] Train Loss: 0.6459, Val Loss: 0.6966
# [Epoch 55/100] Train Loss: 0.6358, Val Loss: 0.6929
# [Epoch 60/100] Train Loss: 0.6300, Val Loss: 0.7089
# [Epoch 65/100] Train Loss: 0.6231, Val Loss: 0.7075
# [Epoch 70/100] Train Loss: 0.6235, Val Loss: 0.7037
# [Epoch 75/100] Train Loss: 0.6109, Val Loss: 0.6893
# [Epoch 80/100] Train Loss: 0.6079, Val Loss: 0.7270
# [Epoch 85/100] Train Loss: 0.5997, Val Loss: 0.7221
# [Epoch 90/100] Train Loss: 0.5908, Val Loss: 0.7153
# [Epoch 95/100] Train Loss: 0.5844, Val Loss: 0.7225
# [Epoch 100/100] Train Loss: 0.5800, Val Loss: 0.7157
# Accuracy on Nonzero Predictions: 0.4885
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/learning_rates_processing/AAPL_clean_gru_lr0.009_single_name.png
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Prediction Threshold: 0.5
# [Epoch 5/100] Train Loss: 0.5654, Val Loss: 0.7383
# [Epoch 10/100] Train Loss: 0.5800, Val Loss: 0.7248
# [Epoch 15/100] Train Loss: 0.5613, Val Loss: 0.7087
# [Epoch 20/100] Train Loss: 0.5629, Val Loss: 0.7220
# [Epoch 25/100] Train Loss: 0.5514, Val Loss: 0.7495
# [Epoch 30/100] Train Loss: 0.5482, Val Loss: 0.7790
# [Epoch 35/100] Train Loss: 0.5502, Val Loss: 0.7379
# [Epoch 40/100] Train Loss: 0.5455, Val Loss: 0.7238
# [Epoch 45/100] Train Loss: 0.5447, Val Loss: 0.7255
# [Epoch 50/100] Train Loss: 0.5400, Val Loss: 0.7266
# [Epoch 55/100] Train Loss: 0.5263, Val Loss: 0.7422
# [Epoch 60/100] Train Loss: 0.5096, Val Loss: 0.7165
# [Epoch 65/100] Train Loss: 0.5265, Val Loss: 0.7704
# [Epoch 70/100] Train Loss: 0.5136, Val Loss: 0.7148
# [Epoch 75/100] Train Loss: 0.5098, Val Loss: 0.7202
# [Epoch 80/100] Train Loss: 0.5028, Val Loss: 0.7343
# [Epoch 85/100] Train Loss: 0.5176, Val Loss: 0.7230
# [Epoch 90/100] Train Loss: 0.5005, Val Loss: 0.7308
# [Epoch 95/100] Train Loss: 0.5182, Val Loss: 0.7318
# [Epoch 100/100] Train Loss: 0.5062, Val Loss: 0.7165
# Accuracy on Nonzero Predictions: 0.4962
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/learning_rates_processing/AAPL_clean_gru_lr0.01_single_name.png
# Training AAPL | LR: 0.011 | Epochs: 100 | Batch: 32 | Prediction Threshold: 0.5
# [Epoch 5/100] Train Loss: 0.4993, Val Loss: 0.7471
# [Epoch 10/100] Train Loss: 0.4888, Val Loss: 0.7316
# [Epoch 15/100] Train Loss: 0.4993, Val Loss: 0.7737
# [Epoch 20/100] Train Loss: 0.4921, Val Loss: 0.7191
# [Epoch 25/100] Train Loss: 0.4720, Val Loss: 0.7311
# [Epoch 30/100] Train Loss: 0.4878, Val Loss: 0.6631
# [Epoch 35/100] Train Loss: 0.4842, Val Loss: 0.7468
# [Epoch 40/100] Train Loss: 0.4811, Val Loss: 0.7178
# [Epoch 45/100] Train Loss: 0.4961, Val Loss: 0.7339
# [Epoch 50/100] Train Loss: 0.4868, Val Loss: 0.7093
# [Epoch 55/100] Train Loss: 0.4623, Val Loss: 0.7791
# [Epoch 60/100] Train Loss: 0.4830, Val Loss: 0.6995
# [Epoch 65/100] Train Loss: 0.4614, Val Loss: 0.7680
# [Epoch 70/100] Train Loss: 0.4654, Val Loss: 0.8270
# [Epoch 75/100] Train Loss: 0.4506, Val Loss: 0.8079
# [Epoch 80/100] Train Loss: 0.4607, Val Loss: 0.8237
# [Epoch 85/100] Train Loss: 0.4580, Val Loss: 0.7457
# [Epoch 90/100] Train Loss: 0.4645, Val Loss: 0.8258
# [Epoch 95/100] Train Loss: 0.4461, Val Loss: 0.7804
# [Epoch 100/100] Train Loss: 0.4488, Val Loss: 0.7785
# Accuracy on Nonzero Predictions: 0.5496
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/learning_rates_processing/AAPL_clean_gru_lr0.011_single_name.png
# [0.48854961832061067, 0.4961832061068702, 0.549618320610687]
# [-16.637848470971882, -12.994511055876051, -12.723667924155496]
# clean, gru, technical
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/clean/technical/AAPL/10y_5_data.pkl
# Training AAPL | LR: 0.009 | Epochs: 100 | Batch: 32 | Prediction Threshold: 0.5
# [Epoch 5/100] Train Loss: 0.7075, Val Loss: 0.7982
# [Epoch 10/100] Train Loss: 0.7029, Val Loss: 0.6776
# [Epoch 15/100] Train Loss: 0.7042, Val Loss: 0.6895
# [Epoch 20/100] Train Loss: 0.7099, Val Loss: 0.6720
# [Epoch 25/100] Train Loss: 0.6990, Val Loss: 0.6856
# [Epoch 30/100] Train Loss: 0.6979, Val Loss: 0.6915
# [Epoch 35/100] Train Loss: 0.6974, Val Loss: 0.6916
# [Epoch 40/100] Train Loss: 0.7008, Val Loss: 0.6869
# [Epoch 45/100] Train Loss: 0.6972, Val Loss: 0.6854
# [Epoch 50/100] Train Loss: 0.6979, Val Loss: 0.6847
# [Epoch 55/100] Train Loss: 0.6985, Val Loss: 0.6818
# [Epoch 60/100] Train Loss: 0.6975, Val Loss: 0.6782
# [Epoch 65/100] Train Loss: 0.6971, Val Loss: 0.6808
# [Epoch 70/100] Train Loss: 0.6948, Val Loss: 0.6854
# [Epoch 75/100] Train Loss: 0.6943, Val Loss: 0.6870
# [Epoch 80/100] Train Loss: 0.6944, Val Loss: 0.6855
# [Epoch 85/100] Train Loss: 0.7042, Val Loss: 0.8122
# [Epoch 90/100] Train Loss: 0.6976, Val Loss: 0.6818
# [Epoch 95/100] Train Loss: 0.6968, Val Loss: 0.7216
# [Epoch 100/100] Train Loss: 0.7000, Val Loss: 0.6877
# Accuracy on Nonzero Predictions: 0.5952
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/learning_rates_processing/AAPL_clean_gru_lr0.009_technical.png
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Prediction Threshold: 0.5
# [Epoch 5/100] Train Loss: 0.7010, Val Loss: 0.6822
# [Epoch 10/100] Train Loss: 0.6962, Val Loss: 0.7358
# [Epoch 15/100] Train Loss: 0.6939, Val Loss: 0.6902
# [Epoch 20/100] Train Loss: 0.6972, Val Loss: 0.7011
# [Epoch 25/100] Train Loss: 0.6967, Val Loss: 0.6809
# [Epoch 30/100] Train Loss: 0.6957, Val Loss: 0.6819
# [Epoch 35/100] Train Loss: 0.6927, Val Loss: 0.6822
# [Epoch 40/100] Train Loss: 0.6908, Val Loss: 0.6798
# [Epoch 45/100] Train Loss: 0.6869, Val Loss: 0.6958
# [Epoch 50/100] Train Loss: 0.6900, Val Loss: 0.7060
# [Epoch 55/100] Train Loss: 0.6899, Val Loss: 0.7106
# [Epoch 60/100] Train Loss: 0.6929, Val Loss: 0.6863
# [Epoch 65/100] Train Loss: 0.6866, Val Loss: 0.7349
# [Epoch 70/100] Train Loss: 0.6851, Val Loss: 0.7831
# [Epoch 75/100] Train Loss: 0.6836, Val Loss: 0.7545
# [Epoch 80/100] Train Loss: 0.6798, Val Loss: 0.6972
# [Epoch 85/100] Train Loss: 0.6860, Val Loss: 0.7474
# [Epoch 90/100] Train Loss: 0.6838, Val Loss: 0.6989
# [Epoch 95/100] Train Loss: 0.6782, Val Loss: 0.7903
# [Epoch 100/100] Train Loss: 0.6779, Val Loss: 0.7912
# Accuracy on Nonzero Predictions: 0.3810
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/learning_rates_processing/AAPL_clean_gru_lr0.01_technical.png
# Training AAPL | LR: 0.011 | Epochs: 100 | Batch: 32 | Prediction Threshold: 0.5
# [Epoch 5/100] Train Loss: 0.6798, Val Loss: 0.8328
# [Epoch 10/100] Train Loss: 0.6837, Val Loss: 0.7953
# [Epoch 15/100] Train Loss: 0.6767, Val Loss: 0.9537
# [Epoch 20/100] Train Loss: 0.6822, Val Loss: 0.7985
# [Epoch 25/100] Train Loss: 0.6800, Val Loss: 0.7597
# [Epoch 30/100] Train Loss: 0.6779, Val Loss: 0.8072
# [Epoch 35/100] Train Loss: 0.6766, Val Loss: 0.7819
# [Epoch 40/100] Train Loss: 0.6867, Val Loss: 0.6928
# [Epoch 45/100] Train Loss: 0.6765, Val Loss: 0.7113
# [Epoch 50/100] Train Loss: 0.6744, Val Loss: 0.6992
# [Epoch 55/100] Train Loss: 0.6855, Val Loss: 0.7106
# [Epoch 60/100] Train Loss: 0.6818, Val Loss: 0.7620
# [Epoch 65/100] Train Loss: 0.6807, Val Loss: 0.7406
# [Epoch 70/100] Train Loss: 0.6823, Val Loss: 0.7030
# [Epoch 75/100] Train Loss: 0.6875, Val Loss: 0.7150
# [Epoch 80/100] Train Loss: 0.6890, Val Loss: 0.7207
# [Epoch 85/100] Train Loss: 0.6828, Val Loss: 0.7884
# [Epoch 90/100] Train Loss: 0.6845, Val Loss: 0.7425
# [Epoch 95/100] Train Loss: 0.6830, Val Loss: 0.7243
# [Epoch 100/100] Train Loss: 0.6877, Val Loss: 0.6885
# Accuracy on Nonzero Predictions: 0.6111
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/learning_rates_processing/AAPL_clean_gru_lr0.011_technical.png
# [0.5952380952380952, 0.38095238095238093, 0.6111111111111112]
# [0.444777378611543, -2.496953515240042, 0.850185730436737]
# clean, gru, options
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/clean/options/AAPL/10y_5_data.pkl
# Training AAPL | LR: 0.009 | Epochs: 100 | Batch: 32 | Prediction Threshold: 0.5
# [Epoch 5/100] Train Loss: 0.6893, Val Loss: 0.6800
# [Epoch 10/100] Train Loss: 0.6887, Val Loss: 0.6738
# [Epoch 15/100] Train Loss: 0.6888, Val Loss: 0.6657
# [Epoch 20/100] Train Loss: 0.6790, Val Loss: 0.6652
# [Epoch 25/100] Train Loss: 0.6711, Val Loss: 0.6721
# [Epoch 30/100] Train Loss: 0.6216, Val Loss: 0.6732
# [Epoch 35/100] Train Loss: 0.6087, Val Loss: 0.7733
# [Epoch 40/100] Train Loss: 0.5390, Val Loss: 0.8460
# [Epoch 45/100] Train Loss: 0.5597, Val Loss: 0.8223
# [Epoch 50/100] Train Loss: 0.5003, Val Loss: 0.8910
# [Epoch 55/100] Train Loss: 0.4971, Val Loss: 0.9612
# [Epoch 60/100] Train Loss: 0.4353, Val Loss: 1.1287
# [Epoch 65/100] Train Loss: 0.4211, Val Loss: 1.1246
# [Epoch 70/100] Train Loss: 0.3936, Val Loss: 1.1993
# [Epoch 75/100] Train Loss: 0.3643, Val Loss: 1.4147
# [Epoch 80/100] Train Loss: 0.3912, Val Loss: 1.3051
# [Epoch 85/100] Train Loss: 0.3673, Val Loss: 1.3972
# [Epoch 90/100] Train Loss: 0.3366, Val Loss: 1.4257
# [Epoch 95/100] Train Loss: 0.3072, Val Loss: 1.4889
# [Epoch 100/100] Train Loss: 0.3144, Val Loss: 1.3209
# Accuracy on Nonzero Predictions: 0.5725
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/learning_rates_processing/AAPL_clean_gru_lr0.009_options.png
# Training AAPL | LR: 0.01 | Epochs: 100 | Batch: 32 | Prediction Threshold: 0.5
# [Epoch 5/100] Train Loss: 0.3571, Val Loss: 1.5588
# [Epoch 10/100] Train Loss: 0.3326, Val Loss: 1.4469
# [Epoch 15/100] Train Loss: 0.3186, Val Loss: 1.3992
# [Epoch 20/100] Train Loss: 0.2958, Val Loss: 1.5419
# [Epoch 25/100] Train Loss: 0.3248, Val Loss: 1.6507
# [Epoch 30/100] Train Loss: 0.3389, Val Loss: 1.4447
# [Epoch 35/100] Train Loss: 0.3367, Val Loss: 1.4528
# [Epoch 40/100] Train Loss: 0.3428, Val Loss: 1.4476
# [Epoch 45/100] Train Loss: 0.3173, Val Loss: 1.4482
# [Epoch 50/100] Train Loss: 0.3711, Val Loss: 1.1746
# [Epoch 55/100] Train Loss: 0.3381, Val Loss: 1.3270
# [Epoch 60/100] Train Loss: 0.3333, Val Loss: 1.7563
# [Epoch 65/100] Train Loss: 0.3421, Val Loss: 1.4816
# [Epoch 70/100] Train Loss: 0.3514, Val Loss: 1.2257
# [Epoch 75/100] Train Loss: 0.3501, Val Loss: 1.4711
# [Epoch 80/100] Train Loss: 0.3955, Val Loss: 1.2901
# [Epoch 85/100] Train Loss: 0.3449, Val Loss: 1.5490
# [Epoch 90/100] Train Loss: 0.3422, Val Loss: 1.5665
# [Epoch 95/100] Train Loss: 0.3468, Val Loss: 2.1621
# [Epoch 100/100] Train Loss: 0.3444, Val Loss: 1.6557
# Accuracy on Nonzero Predictions: 0.4504
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/learning_rates_processing/AAPL_clean_gru_lr0.01_options.png
# Training AAPL | LR: 0.011 | Epochs: 100 | Batch: 32 | Prediction Threshold: 0.5
# [Epoch 5/100] Train Loss: 0.3962, Val Loss: 1.6294
# [Epoch 10/100] Train Loss: 0.3736, Val Loss: 1.1147
# [Epoch 15/100] Train Loss: 0.3653, Val Loss: 1.1330
# [Epoch 20/100] Train Loss: 0.4051, Val Loss: 1.1555
# [Epoch 25/100] Train Loss: 0.4007, Val Loss: 0.8875
# [Epoch 30/100] Train Loss: 0.3871, Val Loss: 1.0765
# [Epoch 35/100] Train Loss: 0.3941, Val Loss: 1.2205
# [Epoch 40/100] Train Loss: 0.3869, Val Loss: 1.3602
# [Epoch 45/100] Train Loss: 0.4087, Val Loss: 0.9676
# [Epoch 50/100] Train Loss: 0.4267, Val Loss: 1.1603
# [Epoch 55/100] Train Loss: 0.4521, Val Loss: 1.1648
# [Epoch 60/100] Train Loss: 0.4332, Val Loss: 1.0896
# [Epoch 65/100] Train Loss: 0.4482, Val Loss: 1.3514
# [Epoch 70/100] Train Loss: 0.4619, Val Loss: 1.0140
# [Epoch 75/100] Train Loss: 0.4036, Val Loss: 1.2300
# [Epoch 80/100] Train Loss: 0.4445, Val Loss: 1.1720
# [Epoch 85/100] Train Loss: 0.4043, Val Loss: 1.1308
# [Epoch 90/100] Train Loss: 0.4871, Val Loss: 1.2647
# [Epoch 95/100] Train Loss: 0.4724, Val Loss: 0.9108
# [Epoch 100/100] Train Loss: 0.4216, Val Loss: 1.2584
# Accuracy on Nonzero Predictions: 0.4962
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/learning_rates_processing/AAPL_clean_gru_lr0.011_options.png
# [0.5725190839694656, 0.45038167938931295, 0.4961832061068702]
# [-54.91203526580593, -10.968435516218165, 16.774954151876162]

# %%
df = pd.DataFrame(results_list)
df
# Out:
#    STOCK    DATA_TYPE MODEL PROCESSING  MEAN_ACCURACY  MAX_ACCURACY  \
# 0   AAPL  single_name  LSTM      clean       0.569975      0.580153
# 1   AAPL    technical  LSTM        pca       0.534392      0.547619
# 2   AAPL      options  LSTM        pca       0.516539      0.557252
# 3   AAPL  single_name   GRU      clean       0.516539      0.526718
# 4   AAPL    technical   GRU        pca       0.513228      0.579365
# 5   AAPL      options   GRU        pca       0.577608      0.595420
# 6   AAPL  single_name  LSTM      clean       0.463104      0.511450
# 7   AAPL    technical  LSTM      clean       0.547619      0.587302
# 8   AAPL      options  LSTM      clean       0.491094      0.534351
# 9   AAPL  single_name   GRU      clean       0.511450      0.549618
# 10  AAPL    technical   GRU      clean       0.529101      0.611111
# 11  AAPL      options   GRU      clean       0.506361      0.572519
#
#     MIN_ACCURACY  MEAN_TRAIN_PCT_DECREASE
# 0       0.564885                 0.569975
# 1       0.507937                 0.534392
# 2       0.488550                 0.516539
# 3       0.503817                 0.516539
# 4       0.428571                 0.513228
# 5       0.549618                 0.577608
# 6       0.389313                 0.463104
# 7       0.523810                 0.547619
# 8       0.427481                 0.491094
# 9       0.488550                 0.511450
# 10      0.380952                 0.529101
# 11      0.450382                 0.506361
