# %% [markdown]
# ## **This notebook aims to combine multiple assets databases**

# %%
import pandas as pd
import numpy as np
import os
import time
from imblearn.over_sampling import SMOTE
from sklearn.metrics import accuracy_score
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

# %%
project_dir = "/home/jupyter-tfg2425paula/prediction_project_v3"
os.chdir(project_dir)

clean_data_dir = os.path.join(project_dir, "00_data/clean")
horizontal_data_dir = os.path.join(project_dir, "00_data/horizontal_structure")
results_dir = os.path.join(project_dir, "02_results")
plots_dir = os.path.join(project_dir, "03_plots")
pca_data_dir = os.path.join(project_dir, "00_data/pca")

# %% [markdown]
# ### **GRU Model**

# %%
class GRU3DClassifier(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers, dropout):
        super(GRU3DClassifier, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.gru = nn.GRU(input_size, hidden_size, num_layers, batch_first=True, dropout=dropout)
        self.fc = nn.Linear(hidden_size, output_size)
        self.sigmoid = nn.Sigmoid()
    
    def forward(self, x):

        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)

        out, _ = self.gru(x, h0)
        out = self.fc(out[:, -1, :]) 
        # return self.sigmoid(out)
        return out

# %% [markdown]
# ### **LSTM Model**

# %%
class StockPriceLSTM(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, num_layers=1, dropout=0.0):
        super(StockPriceLSTM, self).__init__()
        self.hidden_dim = hidden_dim
        self.num_layers = num_layers
        self.lstm = nn.LSTM(input_dim, hidden_dim, num_layers=num_layers, 
                            batch_first=True, dropout=dropout)
    
        self.fc = nn.Linear(hidden_dim, output_dim)
        self.sigmoid = nn.Sigmoid()
    
    def forward(self, x):
        batch_size = x.size(0)  # Get the batch size dynamically

        h0 = torch.zeros(self.num_layers, batch_size, self.hidden_dim).to(x.device)  # (num_layers, batch_size, hidden_dim)
        c0 = torch.zeros(self.num_layers, batch_size, self.hidden_dim).to(x.device)  # (num_layers, batch_size, hidden_dim)
        
        out, _ = self.lstm(x, (h0, c0))

        out = self.fc(out[:, -1, :]) 
        # out = self.sigmoid(out)
        return out

# %% [markdown]
# ### **Set folders**

# %%
thresholds = [0.3, 0.35, 0.4, 0.45, 0.5]
thresholds = [0.5]
learning_rates = [0.005, 0.008, 0.009, 0.01]
learning_rates = [0.01]
num_epochs_list = [100, 200]
num_epochs_list = [100]
batch_sizes = [16, 32]
batch_sizes = [32]

# %% [markdown]
# #### **Model and Hyperparameters**

# %% [markdown]
# #### **Last data modifications**

# %%
def reshape_remove_characters(df):

    X = np.array([np.stack(row) for row in df.drop(columns=['Target']).values])
    y = df['Target'].values

    smote = SMOTE(random_state=42)
    n_samples, timesteps, n_features = X.shape
    X_flat = X.reshape((n_samples, timesteps * n_features))
    X_flat = np.where(X_flat == 'ç', 0, X_flat)

    X_resampled = X_flat.reshape((-1, timesteps, n_features))
    
    return X_resampled, y

# %% [markdown]
# ### **Evaluation function**

# %%
import os
import numpy as np
import torch
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import accuracy_score

def evaluate_model_plot(
    model, 
    X, 
    y, 
    criterion, 
    optimizer, 
    device, 
    train_size, 
    batch_size, 
    num_epochs, 
    lower_threshold,
    plots_dir=None,
    plot_filename=None
):

    # -------------------------------
    # 0) Prepare Tensors & Splits
    # -------------------------------
    X = torch.tensor(X, dtype=torch.float32)
    y = torch.tensor(y, dtype=torch.long)

    total_size = len(X)
    # Determine actual train_size index
    if train_size < 1.0:
        lower_bound = int(train_size * total_size)
    else:
        lower_bound = train_size

    # Training portion
    X_train = X[:lower_bound].to(device)
    y_train = y[:lower_bound].to(device)

    train_dataset = TensorDataset(X_train, y_train)
    trainloader = DataLoader(
        train_dataset,
        batch_size=batch_size,
        shuffle=False,   # Set True if you prefer shuffling
        drop_last=False
    )

    if lower_bound < total_size:
        X_val = X[lower_bound:].to(device)
        y_val = y[lower_bound:].to(device)
        val_dataset = TensorDataset(X_val, y_val)
        valloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
    else:
        # If there's no leftover data for "test", handle gracefully
        X_val = None
        y_val = None
        valloader = None

    # ---------------------------------------------
    # 1) SINGLE TRAINING PHASE + Track Loss Curves
    # ---------------------------------------------
    model.to(device)
    model.train()

    epoch_train_losses = []
    epoch_test_losses = []

    for epoch in range(num_epochs):
        # TRAINING PASS
        epoch_loss = 0.0
        for X_batch, y_batch in trainloader:
            optimizer.zero_grad()

            # Forward
            pred_y = model(X_batch)
            loss = criterion(pred_y, y_batch)

            # Backprop & update
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)  # optional
            optimizer.step()

            epoch_loss += loss.item()

        avg_train_loss = epoch_loss / len(trainloader)
        epoch_train_losses.append(avg_train_loss)

        
        # VALIDATION PASS (Optional but needed to get test_loss_curve)
        if valloader is not None:
            model.eval()
            val_loss = 0.0
            with torch.no_grad():
                for Xb, yb in valloader:
                    pred_yb = model(Xb)
                    loss_b = criterion(pred_yb, yb)
                    val_loss += loss_b.item()
            avg_val_loss = val_loss / len(valloader)
            epoch_test_losses.append(avg_val_loss)

            model.train()  # Switch back to train mode

        else:
            # If no validation set, just store None or 0
            epoch_test_losses.append(None)

        # Print progress every 5 epochs or last epoch
        if (epoch + 1) % 5 == 0 or (epoch == num_epochs - 1):
            if epoch_test_losses[-1] is not None:
                print(f"[Epoch {epoch+1}/{num_epochs}] ",
                      f"Train Loss: {avg_train_loss:.4f}")
            else:
                print(f"[Epoch {epoch+1}/{num_epochs}] "
                      f"Train Loss: {avg_train_loss:.4f}")

    # % decrease from first to last train loss
    if len(epoch_train_losses) > 1:
        loss_decrease_percentage = ((epoch_train_losses[-1] - epoch_train_losses[0])
                                    / epoch_train_losses[0]) * 100
    else:
        loss_decrease_percentage = 0.0

    final_train_loss = epoch_train_losses[-1]

    # -------------------------------
    # 2) ROLLING PREDICTIONS, NO UPDATE
    # -------------------------------
    model.eval()
    rolling_predictions = []
    rolling_targets = []

    for i in range(lower_bound, total_size):
        X_test = X[i:i+1].to(device)
        y_test = y[i:i+1].to(device)

        with torch.no_grad():
            pred_y = model(X_test)
            probabilities = torch.softmax(pred_y, dim=1).cpu().numpy()
            prob_class_1 = probabilities[:, 1]  # shape: (1,)

            # Threshold-based logic
            pred_classes = np.zeros_like(prob_class_1)
            # Predict -1 if prob < lower_threshold
            pred_classes[prob_class_1 < lower_threshold] = -1
            # Predict +1 if prob > (1 - lower_threshold)
            pred_classes[prob_class_1 > (1 - lower_threshold)] = 1

        rolling_predictions.append(pred_classes[0])
        rolling_targets.append(y_test.item())

    rolling_predictions = np.array(rolling_predictions)
    rolling_targets = np.array(rolling_targets).astype(int)

    # If original labels might be {0,1}, adapt as needed
    rolling_targets[rolling_targets == 0] = -1

    # Filter out zero predictions
    nonzero_mask = (rolling_predictions != 0)
    filtered_preds = rolling_predictions[nonzero_mask]
    filtered_targets = rolling_targets[nonzero_mask]

    if len(filtered_preds) == 0:
        accuracy_nonzero = None
        print("No nonzero predictions, cannot compute thresholded accuracy.")
    else:
        accuracy_nonzero = accuracy_score(filtered_targets, filtered_preds)
        print(f"Accuracy on Nonzero Predictions: {accuracy_nonzero:.4f}")

    # -------------------------------------------------
    # 3) PLOT (if plots_dir is set and there's test data)
    # -------------------------------------------------
    if plots_dir is not None:
        os.makedirs(plots_dir, exist_ok=True)

        # If user didn't provide a filename, create a default
        if plot_filename is None:
            plot_filename = "train_test_loss_curve.png"
        plot_path = os.path.join(plots_dir, plot_filename)

        # Plot the training and validation (test) loss curves
        plt.figure(figsize=(8, 5))
        plt.plot(epoch_train_losses, label="Train Loss")
        # Only plot test loss if it isn't None
        if any(x is not None for x in epoch_test_losses):
            plt.plot(epoch_test_losses, label="Test Loss")
        plt.xlabel("Epoch")
        plt.ylabel("Loss")
        plt.title("Train vs. Test Loss per Epoch")
        plt.legend()
        plt.tight_layout()

        # plt.savefig(plot_path)
        plt.show()
        print(f"Loss curves saved to: {plot_path}")

    # ----------------
    # 4) Return results
    # ----------------
    return {
        "rolling_predictions": rolling_predictions,
        "rolling_targets": rolling_targets,
        "filtered_predictions": filtered_preds,
        "filtered_targets": filtered_targets,
        "accuracy_nonzero": accuracy_nonzero,
        "loss_decrease_percentage": loss_decrease_percentage,
        "final_train_loss": final_train_loss,
        "train_loss_curve": epoch_train_losses,
        "test_loss_curve": epoch_test_losses
    }

# %% [markdown]
# ### **Execute evaluation funcion**

# %%
def combine_stocks_pkl_df(processing, security_type, period, window_size, project_dir, stocks):

    X_list = []
    y_list = []

    for stock in stocks:
        initial_data_dir = os.path.join(project_dir, f"00_data/{processing}") 

        # 1) Load original data (info only)
        filename = f"{security_type}/{stock}/{period}_data.csv"
        original_input_filepath = os.path.join(initial_data_dir, filename)
        original_data = pd.read_csv(original_input_filepath)

        print(f"----- Appending stock: {stock}, period: {period}, data_type: {security_type} -----")

        # 2) Load the preprocessed data
        pkl_filename = f"{processing}/{security_type}/{stock}/{period}_{window_size}_data.pkl"
        input_filepath = os.path.join(horizontal_data_dir, pkl_filename)
        input_df = pd.read_pickle(input_filepath)

        # 3) Reshape
        X_resampled, y_resampled = reshape_remove_characters(input_df)

        # Store in lists
        X_list.append(X_resampled)
        y_list.append(y_resampled)

    # Concatenate all stocks along the sample dimension
    X_combined = np.concatenate(X_list, axis=0)  # Shape: (total_samples, num_features, window_size)
    y_combined = np.concatenate(y_list, axis=0)  # Shape: (total_samples,)

    # Print shapes to verify
    print("Final X shape:", X_combined.shape)
    print("Final y shape:", y_combined.shape)
    
    return X_combined, y_combined

# %%
def combine_stocks_pkl_new_df(processing, security_type, period, window_size, project_dir, stocks, test_size):

    X_list = []
    y_list = []
    last_stock = stocks[-1]

    for stock in stocks:
        initial_data_dir = os.path.join(project_dir, f"00_data/{processing}") 

        # 1) Load original data (info only)
        filename = f"{security_type}/{stock}/{period}_data.csv"
        original_input_filepath = os.path.join(initial_data_dir, filename)
        original_data = pd.read_csv(original_input_filepath)

        print(f"----- Appending stock: {stock}, period: {period}, data_type: {security_type} -----")

        # 2) Load the preprocessed data
        pkl_filename = f"{processing}/{security_type}/{stock}/{period}_{window_size}_data.pkl"
        input_filepath = os.path.join(horizontal_data_dir, pkl_filename)
        input_df = pd.read_pickle(input_filepath)

        # 3) Reshape
        X_resampled, y_resampled = reshape_remove_characters(input_df)
        
        # 4) Remove last rows only if not last stock
        if stock!= last_stock:
            X_resampled = X_resampled[:-test_size]
            y_resampled = y_resampled[:-test_size]

        # Store in lists
        X_list.append(X_resampled)
        y_list.append(y_resampled)

    # Concatenate all stocks along the sample dimension
    X_combined = np.concatenate(X_list, axis=0)  # Shape: (total_samples, num_features, window_size)
    y_combined = np.concatenate(y_list, axis=0)  # Shape: (total_samples,)

    # Print shapes to verify
    print("Final X shape:", X_combined.shape)
    print("Final y shape:", y_combined.shape)
    
    return X_combined, y_combined

# %% [markdown]
# ## **Apply concatenation to specified datasets**

# %%
processing = "clean"
security_type = "options"
period = "10y"
stocks = ['AAPL', 'MSFT', 'AMZN', 'NVDA', 'SPX']
# window_size = 50

# X_combined, y_combined = combine_stocks_pkl_df(processing, security_type, period, window_size, project_dir, stocks)

# %% [markdown]
# ## **Run LSTM and GRU Models**

# %%
possible_train_size = 95

num_epochs = 100
learning_rate = 0.01
prediction_threshold = 0.5

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

batch_size = 64
hidden_size = 64  
output_size = 2  
num_layers = 2
dropout = 0.2

criterion = nn.CrossEntropyLoss()

# %%
model_types = ["lstm", "gru"]   
sample_size = 5
window_sizes = [5, 10, 50, 100]
test_size = 300

results_list = []

for window_size in window_sizes:
    
    X_combined, y_combined = combine_stocks_pkl_new_df(processing, security_type, period, window_size, project_dir, stocks, test_size)
    input_size = X_combined.shape[2]
    # train_size = int(X_combined.shape[0] * possible_train_size / 100)
    train_size = X_combined.shape[0] - test_size
    # test_size = X_combined.shape[0] - train_size

    for model_type in model_types:
        for i in range(sample_size):
            if model_type == "gru":
                model = GRU3DClassifier(input_size, hidden_size, output_size, num_layers, dropout)
            elif model_type == "lstm":
                model = StockPriceLSTM(input_size, hidden_size, output_size)

            model = model.to(device)

            optimizer = optim.Adam(model.parameters(), lr=learning_rate)
            print(f"Training {stocks[-1]} | LR: {learning_rate} | Epochs: {num_epochs} "
                  f"| Batch: {batch_size} | Security type: {security_type}")


            result = evaluate_model_plot(
                model, 
                X_combined, 
                y_combined, 
                criterion, 
                optimizer, 
                device, 
                train_size, 
                batch_size, 
                num_epochs, 
                lower_threshold = 0.5,
                plots_dir=plots_dir,
                plot_filename=None
            )

            # Store results in a list
            results_list.append({
                "security_type": security_type,
                "window_size": window_size,
                "model_type": model_type,
                "iteration": i + 1,
                "accuracy_nonzero": result["accuracy_nonzero"],
                "loss_decrease_percentage": result["loss_decrease_percentage"],
                "final_train_loss": result["final_train_loss"]
            })

results_df = pd.DataFrame(results_list)
# Out:
# ----- Appending stock: AAPL, period: 10y, data_type: options -----
# ----- Appending stock: MSFT, period: 10y, data_type: options -----
# ----- Appending stock: AMZN, period: 10y, data_type: options -----
# ----- Appending stock: NVDA, period: 10y, data_type: options -----
# ----- Appending stock: SPX, period: 10y, data_type: options -----
# Final X shape: (11830, 11, 5)
# Final y shape: (11830,)
# Training SPX | LR: 0.01 | Epochs: 100 | Batch: 64 | Security type: options
# [Epoch 5/100]  Train Loss: 0.6899
# [Epoch 10/100]  Train Loss: 0.6787
# [Epoch 15/100]  Train Loss: 0.6621
# [Epoch 20/100]  Train Loss: 0.6242
# [Epoch 25/100]  Train Loss: 0.5927
# [Epoch 30/100]  Train Loss: 0.5412
# [Epoch 35/100]  Train Loss: 0.4991
# [Epoch 40/100]  Train Loss: 0.4502
# [Epoch 45/100]  Train Loss: 0.4447
# [Epoch 50/100]  Train Loss: 0.4057
# [Epoch 55/100]  Train Loss: 0.3778
# [Epoch 60/100]  Train Loss: 0.3777
# [Epoch 65/100]  Train Loss: 0.3353
# [Epoch 70/100]  Train Loss: 0.3312
# [Epoch 75/100]  Train Loss: 0.3364
# [Epoch 80/100]  Train Loss: 0.3317
# [Epoch 85/100]  Train Loss: 0.3208
# [Epoch 90/100]  Train Loss: 0.3196
# [Epoch 95/100]  Train Loss: 0.2930
# [Epoch 100/100]  Train Loss: 0.2831
# Accuracy on Nonzero Predictions: 0.5467
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/train_test_loss_curve.png
# Training SPX | LR: 0.01 | Epochs: 100 | Batch: 64 | Security type: options
# [Epoch 5/100]  Train Loss: 0.6891
# [Epoch 10/100]  Train Loss: 0.6784
# [Epoch 15/100]  Train Loss: 0.6543
# [Epoch 20/100]  Train Loss: 0.6262
# [Epoch 25/100]  Train Loss: 0.5935
# [Epoch 30/100]  Train Loss: 0.5503
# [Epoch 35/100]  Train Loss: 0.5057
# [Epoch 40/100]  Train Loss: 0.4764
# [Epoch 45/100]  Train Loss: 0.4348
# [Epoch 50/100]  Train Loss: 0.4109
# [Epoch 55/100]  Train Loss: 0.3943
# [Epoch 60/100]  Train Loss: 0.3667
# [Epoch 65/100]  Train Loss: 0.3467
# [Epoch 70/100]  Train Loss: 0.3207
# [Epoch 75/100]  Train Loss: 0.3217
# [Epoch 80/100]  Train Loss: 0.3029
# [Epoch 85/100]  Train Loss: 0.3027
# [Epoch 90/100]  Train Loss: 0.2771
# [Epoch 95/100]  Train Loss: 0.2586
# [Epoch 100/100]  Train Loss: 0.2435
# Accuracy on Nonzero Predictions: 0.5300
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/train_test_loss_curve.png
# Training SPX | LR: 0.01 | Epochs: 100 | Batch: 64 | Security type: options
# [Epoch 5/100]  Train Loss: 0.6903
# [Epoch 10/100]  Train Loss: 0.6804
# [Epoch 15/100]  Train Loss: 0.6649
# [Epoch 20/100]  Train Loss: 0.6319
# [Epoch 25/100]  Train Loss: 0.5862
# [Epoch 30/100]  Train Loss: 0.5429
# [Epoch 35/100]  Train Loss: 0.5098
# [Epoch 40/100]  Train Loss: 0.4614
# [Epoch 45/100]  Train Loss: 0.4224
# [Epoch 50/100]  Train Loss: 0.4147
# [Epoch 55/100]  Train Loss: 0.3814
# [Epoch 60/100]  Train Loss: 0.3650
# [Epoch 65/100]  Train Loss: 0.3428
# [Epoch 70/100]  Train Loss: 0.3378
# [Epoch 75/100]  Train Loss: 0.3197
# [Epoch 80/100]  Train Loss: 0.3145
# [Epoch 85/100]  Train Loss: 0.3028
# [Epoch 90/100]  Train Loss: 0.2921
# [Epoch 95/100]  Train Loss: 0.2942
# [Epoch 100/100]  Train Loss: 0.2903
# Accuracy on Nonzero Predictions: 0.5233
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/train_test_loss_curve.png
# Training SPX | LR: 0.01 | Epochs: 100 | Batch: 64 | Security type: options
# [Epoch 5/100]  Train Loss: 0.6917
# [Epoch 10/100]  Train Loss: 0.6784
# [Epoch 15/100]  Train Loss: 0.6560
# [Epoch 20/100]  Train Loss: 0.6215
# [Epoch 25/100]  Train Loss: 0.5774
# [Epoch 30/100]  Train Loss: 0.5376
# [Epoch 35/100]  Train Loss: 0.4971
# [Epoch 40/100]  Train Loss: 0.4915
# [Epoch 45/100]  Train Loss: 0.4362
# [Epoch 50/100]  Train Loss: 0.4128
# [Epoch 55/100]  Train Loss: 0.3730
# [Epoch 60/100]  Train Loss: 0.3703
# [Epoch 65/100]  Train Loss: 0.3633
# [Epoch 70/100]  Train Loss: 0.3305
# [Epoch 75/100]  Train Loss: 0.3162
# [Epoch 80/100]  Train Loss: 0.3102
# [Epoch 85/100]  Train Loss: 0.2850
# [Epoch 90/100]  Train Loss: 0.2905
# [Epoch 95/100]  Train Loss: 0.2661
# [Epoch 100/100]  Train Loss: 0.2620
# Accuracy on Nonzero Predictions: 0.5233
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/train_test_loss_curve.png
# Training SPX | LR: 0.01 | Epochs: 100 | Batch: 64 | Security type: options
# [Epoch 5/100]  Train Loss: 0.6901
# [Epoch 10/100]  Train Loss: 0.6800
# [Epoch 15/100]  Train Loss: 0.6602
# [Epoch 20/100]  Train Loss: 0.6278
# [Epoch 25/100]  Train Loss: 0.5853
# [Epoch 30/100]  Train Loss: 0.5492
# [Epoch 35/100]  Train Loss: 0.5005
# [Epoch 40/100]  Train Loss: 0.4637
# [Epoch 45/100]  Train Loss: 0.4444
# [Epoch 50/100]  Train Loss: 0.4180
# [Epoch 55/100]  Train Loss: 0.4020
# [Epoch 60/100]  Train Loss: 0.3744
# [Epoch 65/100]  Train Loss: 0.3643
# [Epoch 70/100]  Train Loss: 0.3527
# [Epoch 75/100]  Train Loss: 0.3127
# [Epoch 80/100]  Train Loss: 0.3328
# [Epoch 85/100]  Train Loss: 0.3153
# [Epoch 90/100]  Train Loss: 0.3108
# [Epoch 95/100]  Train Loss: 0.3163
# [Epoch 100/100]  Train Loss: 0.3078
# Accuracy on Nonzero Predictions: 0.5433
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/train_test_loss_curve.png
# Training SPX | LR: 0.01 | Epochs: 100 | Batch: 64 | Security type: options
# [Epoch 5/100]  Train Loss: 0.6936
# [Epoch 10/100]  Train Loss: 0.6936
# [Epoch 15/100]  Train Loss: 0.6921
# [Epoch 20/100]  Train Loss: 0.6874
# [Epoch 25/100]  Train Loss: 0.6877
# [Epoch 30/100]  Train Loss: 0.6876
# [Epoch 35/100]  Train Loss: 0.6851
# [Epoch 40/100]  Train Loss: 0.6846
# [Epoch 45/100]  Train Loss: 0.6849
# [Epoch 50/100]  Train Loss: 0.6820
# [Epoch 55/100]  Train Loss: 0.6821
# [Epoch 60/100]  Train Loss: 0.6844
# [Epoch 65/100]  Train Loss: 0.6866
# [Epoch 70/100]  Train Loss: 0.6851
# [Epoch 75/100]  Train Loss: 0.6834
# [Epoch 80/100]  Train Loss: 0.6854
# [Epoch 85/100]  Train Loss: 0.6820
# [Epoch 90/100]  Train Loss: 0.6877
# [Epoch 95/100]  Train Loss: 0.6879
# [Epoch 100/100]  Train Loss: 0.6851
# Accuracy on Nonzero Predictions: 0.5800
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/train_test_loss_curve.png
# Training SPX | LR: 0.01 | Epochs: 100 | Batch: 64 | Security type: options
# [Epoch 5/100]  Train Loss: 0.6955
# [Epoch 10/100]  Train Loss: 0.6931
# [Epoch 15/100]  Train Loss: 0.6898
# [Epoch 20/100]  Train Loss: 0.6886
# [Epoch 25/100]  Train Loss: 0.6883
# [Epoch 30/100]  Train Loss: 0.6885
# [Epoch 35/100]  Train Loss: 0.6892
# [Epoch 40/100]  Train Loss: 0.6892
# [Epoch 45/100]  Train Loss: 0.6870
# [Epoch 50/100]  Train Loss: 0.6880
# [Epoch 55/100]  Train Loss: 0.6898
# [Epoch 60/100]  Train Loss: 0.6889
# [Epoch 65/100]  Train Loss: 0.6878
# [Epoch 70/100]  Train Loss: 0.6857
# [Epoch 75/100]  Train Loss: 0.6886
# [Epoch 80/100]  Train Loss: 0.6858
# [Epoch 85/100]  Train Loss: 0.6859
# [Epoch 90/100]  Train Loss: 0.6838
# [Epoch 95/100]  Train Loss: 0.6837
# [Epoch 100/100]  Train Loss: 0.6837
# Accuracy on Nonzero Predictions: 0.6000
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/train_test_loss_curve.png
# Training SPX | LR: 0.01 | Epochs: 100 | Batch: 64 | Security type: options
# [Epoch 5/100]  Train Loss: 0.6953
# [Epoch 10/100]  Train Loss: 0.6929
# [Epoch 15/100]  Train Loss: 0.6919
# [Epoch 20/100]  Train Loss: 0.6911
# [Epoch 25/100]  Train Loss: 0.6894
# [Epoch 30/100]  Train Loss: 0.6892
# [Epoch 35/100]  Train Loss: 0.6892
# [Epoch 40/100]  Train Loss: 0.6899
# [Epoch 45/100]  Train Loss: 0.6871
# [Epoch 50/100]  Train Loss: 0.6868
# [Epoch 55/100]  Train Loss: 0.6872
# [Epoch 60/100]  Train Loss: 0.6877
# [Epoch 65/100]  Train Loss: 0.6863
# [Epoch 70/100]  Train Loss: 0.6865
# [Epoch 75/100]  Train Loss: 0.6862
# [Epoch 80/100]  Train Loss: 0.6867
# [Epoch 85/100]  Train Loss: 0.6882
# [Epoch 90/100]  Train Loss: 0.6859
# [Epoch 95/100]  Train Loss: 0.6855
# [Epoch 100/100]  Train Loss: 0.6869
# Accuracy on Nonzero Predictions: 0.6067
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/train_test_loss_curve.png
# Training SPX | LR: 0.01 | Epochs: 100 | Batch: 64 | Security type: options
# [Epoch 5/100]  Train Loss: 0.6934
# [Epoch 10/100]  Train Loss: 0.6912
# [Epoch 15/100]  Train Loss: 0.6902
# [Epoch 20/100]  Train Loss: 0.6897
# [Epoch 25/100]  Train Loss: 0.6938
# [Epoch 30/100]  Train Loss: 0.6882
# [Epoch 35/100]  Train Loss: 0.6878
# [Epoch 40/100]  Train Loss: 0.6864
# [Epoch 45/100]  Train Loss: 0.6853
# [Epoch 50/100]  Train Loss: 0.6863
# [Epoch 55/100]  Train Loss: 0.6845
# [Epoch 60/100]  Train Loss: 0.6797
# [Epoch 65/100]  Train Loss: 0.6868
# [Epoch 70/100]  Train Loss: 0.6812
# [Epoch 75/100]  Train Loss: 0.6837
# [Epoch 80/100]  Train Loss: 0.6819
# [Epoch 85/100]  Train Loss: 0.6816
# [Epoch 90/100]  Train Loss: 0.6814
# [Epoch 95/100]  Train Loss: 0.6781
# [Epoch 100/100]  Train Loss: 0.6806
# Accuracy on Nonzero Predictions: 0.6200
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/train_test_loss_curve.png
# Training SPX | LR: 0.01 | Epochs: 100 | Batch: 64 | Security type: options
# [Epoch 5/100]  Train Loss: 0.6933
# [Epoch 10/100]  Train Loss: 0.6947
# [Epoch 15/100]  Train Loss: 0.6944
# [Epoch 20/100]  Train Loss: 0.6918
# [Epoch 25/100]  Train Loss: 0.6903
# [Epoch 30/100]  Train Loss: 0.6894
# [Epoch 35/100]  Train Loss: 0.6902
# [Epoch 40/100]  Train Loss: 0.6884
# [Epoch 45/100]  Train Loss: 0.6887
# [Epoch 50/100]  Train Loss: 0.6885
# [Epoch 55/100]  Train Loss: 0.6861
# [Epoch 60/100]  Train Loss: 0.6867
# [Epoch 65/100]  Train Loss: 0.6864
# [Epoch 70/100]  Train Loss: 0.6846
# [Epoch 75/100]  Train Loss: 0.6841
# [Epoch 80/100]  Train Loss: 0.6844
# [Epoch 85/100]  Train Loss: 0.6840
# [Epoch 90/100]  Train Loss: 0.6829
# [Epoch 95/100]  Train Loss: 0.6872
# [Epoch 100/100]  Train Loss: 0.6875
# Accuracy on Nonzero Predictions: 0.5400
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/train_test_loss_curve.png
# ----- Appending stock: AAPL, period: 10y, data_type: options -----
# ----- Appending stock: MSFT, period: 10y, data_type: options -----
# ----- Appending stock: AMZN, period: 10y, data_type: options -----
# ----- Appending stock: NVDA, period: 10y, data_type: options -----
# ----- Appending stock: SPX, period: 10y, data_type: options -----
# Final X shape: (11805, 11, 10)
# Final y shape: (11805,)
# Training SPX | LR: 0.01 | Epochs: 100 | Batch: 64 | Security type: options
# [Epoch 5/100]  Train Loss: 0.6831
# [Epoch 10/100]  Train Loss: 0.6222
# [Epoch 15/100]  Train Loss: 0.5156
# [Epoch 20/100]  Train Loss: 0.4280
# [Epoch 25/100]  Train Loss: 0.3687
# [Epoch 30/100]  Train Loss: 0.3202
# [Epoch 35/100]  Train Loss: 0.2861
# [Epoch 40/100]  Train Loss: 0.2659
# [Epoch 45/100]  Train Loss: 0.2324
# [Epoch 50/100]  Train Loss: 0.2096
# [Epoch 55/100]  Train Loss: 0.1971
# [Epoch 60/100]  Train Loss: 0.2049
# [Epoch 65/100]  Train Loss: 0.1846
# [Epoch 70/100]  Train Loss: 0.1877
# [Epoch 75/100]  Train Loss: 0.1581
# [Epoch 80/100]  Train Loss: 0.1586
# [Epoch 85/100]  Train Loss: 0.1400
# [Epoch 90/100]  Train Loss: 0.1469
# [Epoch 95/100]  Train Loss: 0.1593
# [Epoch 100/100]  Train Loss: 0.1388
# Accuracy on Nonzero Predictions: 0.5500
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/train_test_loss_curve.png
# Training SPX | LR: 0.01 | Epochs: 100 | Batch: 64 | Security type: options
# [Epoch 5/100]  Train Loss: 0.6852
# [Epoch 10/100]  Train Loss: 0.6396
# [Epoch 15/100]  Train Loss: 0.5561
# [Epoch 20/100]  Train Loss: 0.4581
# [Epoch 25/100]  Train Loss: 0.3925
# [Epoch 30/100]  Train Loss: 0.3440
# [Epoch 35/100]  Train Loss: 0.3039
# [Epoch 40/100]  Train Loss: 0.2734
# [Epoch 45/100]  Train Loss: 0.2500
# [Epoch 50/100]  Train Loss: 0.2206
# [Epoch 55/100]  Train Loss: 0.2293
# [Epoch 60/100]  Train Loss: 0.2085
# [Epoch 65/100]  Train Loss: 0.1929
# [Epoch 70/100]  Train Loss: 0.2103
# [Epoch 75/100]  Train Loss: 0.1728
# [Epoch 80/100]  Train Loss: 0.2190
# [Epoch 85/100]  Train Loss: 0.1803
# [Epoch 90/100]  Train Loss: 0.1528
# [Epoch 95/100]  Train Loss: 0.1911
# [Epoch 100/100]  Train Loss: 0.1444
# Accuracy on Nonzero Predictions: 0.5067
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/train_test_loss_curve.png
# Training SPX | LR: 0.01 | Epochs: 100 | Batch: 64 | Security type: options
# [Epoch 5/100]  Train Loss: 0.6841
# [Epoch 10/100]  Train Loss: 0.6257
# [Epoch 15/100]  Train Loss: 0.5261
# [Epoch 20/100]  Train Loss: 0.4445
# [Epoch 25/100]  Train Loss: 0.3899
# [Epoch 30/100]  Train Loss: 0.3187
# [Epoch 35/100]  Train Loss: 0.2846
# [Epoch 40/100]  Train Loss: 0.2508
# [Epoch 45/100]  Train Loss: 0.2383
# [Epoch 50/100]  Train Loss: 0.2345
# [Epoch 55/100]  Train Loss: 0.2294
# [Epoch 60/100]  Train Loss: 0.2181
# [Epoch 65/100]  Train Loss: 0.1872
# [Epoch 70/100]  Train Loss: 0.1775
# [Epoch 75/100]  Train Loss: 0.1721
# [Epoch 80/100]  Train Loss: 0.1772
# [Epoch 85/100]  Train Loss: 0.1647
# [Epoch 90/100]  Train Loss: 0.1722
# [Epoch 95/100]  Train Loss: 0.1554
# [Epoch 100/100]  Train Loss: 0.1538
# Accuracy on Nonzero Predictions: 0.5467
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/train_test_loss_curve.png
# Training SPX | LR: 0.01 | Epochs: 100 | Batch: 64 | Security type: options
# [Epoch 5/100]  Train Loss: 0.6800
# [Epoch 10/100]  Train Loss: 0.6267
# [Epoch 15/100]  Train Loss: 0.5423
# [Epoch 20/100]  Train Loss: 0.4336
# [Epoch 25/100]  Train Loss: 0.3800
# [Epoch 30/100]  Train Loss: 0.3397
# [Epoch 35/100]  Train Loss: 0.2988
# [Epoch 40/100]  Train Loss: 0.2662
# [Epoch 45/100]  Train Loss: 0.2529
# [Epoch 50/100]  Train Loss: 0.2301
# [Epoch 55/100]  Train Loss: 0.2209
# [Epoch 60/100]  Train Loss: 0.2237
# [Epoch 65/100]  Train Loss: 0.1980
# [Epoch 70/100]  Train Loss: 0.1786
# [Epoch 75/100]  Train Loss: 0.1886
# [Epoch 80/100]  Train Loss: 0.1632
# [Epoch 85/100]  Train Loss: 0.1562
# [Epoch 90/100]  Train Loss: 0.1609
# [Epoch 95/100]  Train Loss: 0.1598
# [Epoch 100/100]  Train Loss: 0.1779
# Accuracy on Nonzero Predictions: 0.5433
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/train_test_loss_curve.png
# Training SPX | LR: 0.01 | Epochs: 100 | Batch: 64 | Security type: options
# [Epoch 5/100]  Train Loss: 0.6844
# [Epoch 10/100]  Train Loss: 0.6363
# [Epoch 15/100]  Train Loss: 0.5546
# [Epoch 20/100]  Train Loss: 0.4620
# [Epoch 25/100]  Train Loss: 0.4046
# [Epoch 30/100]  Train Loss: 0.3447
# [Epoch 35/100]  Train Loss: 0.2980
# [Epoch 40/100]  Train Loss: 0.2853
# [Epoch 45/100]  Train Loss: 0.2871
# [Epoch 50/100]  Train Loss: 0.2453
# [Epoch 55/100]  Train Loss: 0.2381
# [Epoch 60/100]  Train Loss: 0.2231
# [Epoch 65/100]  Train Loss: 0.2307
# [Epoch 70/100]  Train Loss: 0.2241
# [Epoch 75/100]  Train Loss: 0.2050
# [Epoch 80/100]  Train Loss: 0.2119
# [Epoch 85/100]  Train Loss: 0.1879
# [Epoch 90/100]  Train Loss: 0.1740
# [Epoch 95/100]  Train Loss: 0.1790
# [Epoch 100/100]  Train Loss: 0.1795
# Accuracy on Nonzero Predictions: 0.5200
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/train_test_loss_curve.png
# Training SPX | LR: 0.01 | Epochs: 100 | Batch: 64 | Security type: options
# [Epoch 5/100]  Train Loss: 0.6971
# [Epoch 10/100]  Train Loss: 0.6920
# [Epoch 15/100]  Train Loss: 0.6882
# [Epoch 20/100]  Train Loss: 0.6846
# [Epoch 25/100]  Train Loss: 0.6802
# [Epoch 30/100]  Train Loss: 0.6678
# [Epoch 35/100]  Train Loss: 0.6646
# [Epoch 40/100]  Train Loss: 0.6628
# [Epoch 45/100]  Train Loss: 0.6623
# [Epoch 50/100]  Train Loss: 0.6563
# [Epoch 55/100]  Train Loss: 0.6535
# [Epoch 60/100]  Train Loss: 0.6433
# [Epoch 65/100]  Train Loss: 0.6412
# [Epoch 70/100]  Train Loss: 0.6368
# [Epoch 75/100]  Train Loss: 0.6350
# [Epoch 80/100]  Train Loss: 0.6339
# [Epoch 85/100]  Train Loss: 0.6298
# [Epoch 90/100]  Train Loss: 0.6255
# [Epoch 95/100]  Train Loss: 0.6322
# [Epoch 100/100]  Train Loss: 0.6148
# Accuracy on Nonzero Predictions: 0.4767
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/train_test_loss_curve.png
# Training SPX | LR: 0.01 | Epochs: 100 | Batch: 64 | Security type: options
# [Epoch 5/100]  Train Loss: 0.6992
# [Epoch 10/100]  Train Loss: 0.6945
# [Epoch 15/100]  Train Loss: 0.6912
# [Epoch 20/100]  Train Loss: 0.6899
# [Epoch 25/100]  Train Loss: 0.6831
# [Epoch 30/100]  Train Loss: 0.6840
# [Epoch 35/100]  Train Loss: 0.6801
# [Epoch 40/100]  Train Loss: 0.6792
# [Epoch 45/100]  Train Loss: 0.6768
# [Epoch 50/100]  Train Loss: 0.6790
# [Epoch 55/100]  Train Loss: 0.6825
# [Epoch 60/100]  Train Loss: 0.6780
# [Epoch 65/100]  Train Loss: 0.6754
# [Epoch 70/100]  Train Loss: 0.6736
# [Epoch 75/100]  Train Loss: 0.6775
# [Epoch 80/100]  Train Loss: 0.6790
# [Epoch 85/100]  Train Loss: 0.6773
# [Epoch 90/100]  Train Loss: 0.6765
# [Epoch 95/100]  Train Loss: 0.6817
# [Epoch 100/100]  Train Loss: 0.6778
# Accuracy on Nonzero Predictions: 0.5067
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/train_test_loss_curve.png
# Training SPX | LR: 0.01 | Epochs: 100 | Batch: 64 | Security type: options
# [Epoch 5/100]  Train Loss: 0.6964
# [Epoch 10/100]  Train Loss: 0.6905
# [Epoch 15/100]  Train Loss: 0.6867
# [Epoch 20/100]  Train Loss: 0.6849
# [Epoch 25/100]  Train Loss: 0.6819
# [Epoch 30/100]  Train Loss: 0.6800
# [Epoch 35/100]  Train Loss: 0.6808
# [Epoch 40/100]  Train Loss: 0.6828
# [Epoch 45/100]  Train Loss: 0.6742
# [Epoch 50/100]  Train Loss: 0.6757
# [Epoch 55/100]  Train Loss: 0.6767
# [Epoch 60/100]  Train Loss: 0.6768
# [Epoch 65/100]  Train Loss: 0.6782
# [Epoch 70/100]  Train Loss: 0.6799
# [Epoch 75/100]  Train Loss: 0.6714
# [Epoch 80/100]  Train Loss: 0.6760
# [Epoch 85/100]  Train Loss: 0.6710
# [Epoch 90/100]  Train Loss: 0.6695
# [Epoch 95/100]  Train Loss: 0.6706
# [Epoch 100/100]  Train Loss: 0.6686
# Accuracy on Nonzero Predictions: 0.5667
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/train_test_loss_curve.png
# Training SPX | LR: 0.01 | Epochs: 100 | Batch: 64 | Security type: options
# [Epoch 5/100]  Train Loss: 0.6957
# [Epoch 10/100]  Train Loss: 0.6956
# [Epoch 15/100]  Train Loss: 0.6943
# [Epoch 20/100]  Train Loss: 0.6926
# [Epoch 25/100]  Train Loss: 0.6929
# [Epoch 30/100]  Train Loss: 0.6926
# [Epoch 35/100]  Train Loss: 0.6870
# [Epoch 40/100]  Train Loss: 0.6893
# [Epoch 45/100]  Train Loss: 0.6881
# [Epoch 50/100]  Train Loss: 0.6864
# [Epoch 55/100]  Train Loss: 0.6877
# [Epoch 60/100]  Train Loss: 0.6842
# [Epoch 65/100]  Train Loss: 0.6843
# [Epoch 70/100]  Train Loss: 0.6819
# [Epoch 75/100]  Train Loss: 0.6842
# [Epoch 80/100]  Train Loss: 0.6810
# [Epoch 85/100]  Train Loss: 0.6795
# [Epoch 90/100]  Train Loss: 0.6792
# [Epoch 95/100]  Train Loss: 0.6805
# [Epoch 100/100]  Train Loss: 0.6833
# Accuracy on Nonzero Predictions: 0.5867
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/train_test_loss_curve.png
# Training SPX | LR: 0.01 | Epochs: 100 | Batch: 64 | Security type: options
# [Epoch 5/100]  Train Loss: 0.6983
# [Epoch 10/100]  Train Loss: 0.6962
# [Epoch 15/100]  Train Loss: 0.6925
# [Epoch 20/100]  Train Loss: 0.6894
# [Epoch 25/100]  Train Loss: 0.6857
# [Epoch 30/100]  Train Loss: 0.6860
# [Epoch 35/100]  Train Loss: 0.6855
# [Epoch 40/100]  Train Loss: 0.6842
# [Epoch 45/100]  Train Loss: 0.6865
# [Epoch 50/100]  Train Loss: 0.6822
# [Epoch 55/100]  Train Loss: 0.6849
# [Epoch 60/100]  Train Loss: 0.6816
# [Epoch 65/100]  Train Loss: 0.6782
# [Epoch 70/100]  Train Loss: 0.6808
# [Epoch 75/100]  Train Loss: 0.6827
# [Epoch 80/100]  Train Loss: 0.6826
# [Epoch 85/100]  Train Loss: 0.6870
# [Epoch 90/100]  Train Loss: 0.6880
# [Epoch 95/100]  Train Loss: 0.6837
# [Epoch 100/100]  Train Loss: 0.6811
# Accuracy on Nonzero Predictions: 0.5767
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/train_test_loss_curve.png
# ----- Appending stock: AAPL, period: 10y, data_type: options -----
# ----- Appending stock: MSFT, period: 10y, data_type: options -----
# ----- Appending stock: AMZN, period: 10y, data_type: options -----
# ----- Appending stock: NVDA, period: 10y, data_type: options -----
# ----- Appending stock: SPX, period: 10y, data_type: options -----
# Final X shape: (11605, 11, 50)
# Final y shape: (11605,)
# Training SPX | LR: 0.01 | Epochs: 100 | Batch: 64 | Security type: options
# [Epoch 5/100]  Train Loss: 0.4874
# [Epoch 10/100]  Train Loss: 0.1696
# [Epoch 15/100]  Train Loss: 0.1121
# [Epoch 20/100]  Train Loss: 0.0355
# [Epoch 25/100]  Train Loss: 0.0558
# [Epoch 30/100]  Train Loss: 0.0025
# [Epoch 35/100]  Train Loss: 0.0011
# [Epoch 40/100]  Train Loss: 0.0006
# [Epoch 45/100]  Train Loss: 0.0003
# [Epoch 50/100]  Train Loss: 0.0002
# [Epoch 55/100]  Train Loss: 0.0001
# [Epoch 60/100]  Train Loss: 0.0001
# [Epoch 65/100]  Train Loss: 0.0000
# [Epoch 70/100]  Train Loss: 0.0000
# [Epoch 75/100]  Train Loss: 0.0000
# [Epoch 80/100]  Train Loss: 0.0000
# [Epoch 85/100]  Train Loss: 0.0000
# [Epoch 90/100]  Train Loss: 0.0000
# [Epoch 95/100]  Train Loss: 0.0000
# [Epoch 100/100]  Train Loss: 0.0000
# Accuracy on Nonzero Predictions: 0.5200
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/train_test_loss_curve.png
# Training SPX | LR: 0.01 | Epochs: 100 | Batch: 64 | Security type: options
# [Epoch 5/100]  Train Loss: 0.4781
# [Epoch 10/100]  Train Loss: 0.1821
# [Epoch 15/100]  Train Loss: 0.0922
# [Epoch 20/100]  Train Loss: 0.0859
# [Epoch 25/100]  Train Loss: 0.0133
# [Epoch 30/100]  Train Loss: 0.0017
# [Epoch 35/100]  Train Loss: 0.0009
# [Epoch 40/100]  Train Loss: 0.0005
# [Epoch 45/100]  Train Loss: 0.0003
# [Epoch 50/100]  Train Loss: 0.0002
# [Epoch 55/100]  Train Loss: 0.0001
# [Epoch 60/100]  Train Loss: 0.0001
# [Epoch 65/100]  Train Loss: 0.0000
# [Epoch 70/100]  Train Loss: 0.0000
# [Epoch 75/100]  Train Loss: 0.0000
# [Epoch 80/100]  Train Loss: 0.0000
# [Epoch 85/100]  Train Loss: 0.0000
# [Epoch 90/100]  Train Loss: 0.0000
# [Epoch 95/100]  Train Loss: 0.0000
# [Epoch 100/100]  Train Loss: 0.0000
# Accuracy on Nonzero Predictions: 0.5033
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/train_test_loss_curve.png
# Training SPX | LR: 0.01 | Epochs: 100 | Batch: 64 | Security type: options
# [Epoch 5/100]  Train Loss: 0.4882
# [Epoch 10/100]  Train Loss: 0.1638
# [Epoch 15/100]  Train Loss: 0.0803
# [Epoch 20/100]  Train Loss: 0.0664
# [Epoch 25/100]  Train Loss: 0.0042
# [Epoch 30/100]  Train Loss: 0.0012
# [Epoch 35/100]  Train Loss: 0.0006
# [Epoch 40/100]  Train Loss: 0.0004
# [Epoch 45/100]  Train Loss: 0.0002
# [Epoch 50/100]  Train Loss: 0.0001
# [Epoch 55/100]  Train Loss: 0.0001
# [Epoch 60/100]  Train Loss: 0.0000
# [Epoch 65/100]  Train Loss: 0.0000
# [Epoch 70/100]  Train Loss: 0.0000
# [Epoch 75/100]  Train Loss: 0.0000
# [Epoch 80/100]  Train Loss: 0.0000
# [Epoch 85/100]  Train Loss: 0.0000
# [Epoch 90/100]  Train Loss: 0.0000
# [Epoch 95/100]  Train Loss: 0.0000
# [Epoch 100/100]  Train Loss: 0.0000
# Accuracy on Nonzero Predictions: 0.5133
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/train_test_loss_curve.png
# Training SPX | LR: 0.01 | Epochs: 100 | Batch: 64 | Security type: options
# [Epoch 5/100]  Train Loss: 0.4844
# [Epoch 10/100]  Train Loss: 0.1912
# [Epoch 15/100]  Train Loss: 0.0851
# [Epoch 20/100]  Train Loss: 0.0954
# [Epoch 25/100]  Train Loss: 0.0081
# [Epoch 30/100]  Train Loss: 0.0015
# [Epoch 35/100]  Train Loss: 0.0008
# [Epoch 40/100]  Train Loss: 0.0004
# [Epoch 45/100]  Train Loss: 0.0002
# [Epoch 50/100]  Train Loss: 0.0001
# [Epoch 55/100]  Train Loss: 0.0001
# [Epoch 60/100]  Train Loss: 0.0001
# [Epoch 65/100]  Train Loss: 0.0000
# [Epoch 70/100]  Train Loss: 0.0000
# [Epoch 75/100]  Train Loss: 0.0000
# [Epoch 80/100]  Train Loss: 0.0000
# [Epoch 85/100]  Train Loss: 0.0000
# [Epoch 90/100]  Train Loss: 0.0000
# [Epoch 95/100]  Train Loss: 0.0000
# [Epoch 100/100]  Train Loss: 0.0000
# Accuracy on Nonzero Predictions: 0.5533
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/train_test_loss_curve.png
# Training SPX | LR: 0.01 | Epochs: 100 | Batch: 64 | Security type: options
# [Epoch 5/100]  Train Loss: 0.4918
# [Epoch 10/100]  Train Loss: 0.2041
# [Epoch 15/100]  Train Loss: 0.1404
# [Epoch 20/100]  Train Loss: 0.0370
# [Epoch 25/100]  Train Loss: 0.0038
# [Epoch 30/100]  Train Loss: 0.0011
# [Epoch 35/100]  Train Loss: 0.0006
# [Epoch 40/100]  Train Loss: 0.0003
# [Epoch 45/100]  Train Loss: 0.0002
# [Epoch 50/100]  Train Loss: 0.0001
# [Epoch 55/100]  Train Loss: 0.0001
# [Epoch 60/100]  Train Loss: 0.0000
# [Epoch 65/100]  Train Loss: 0.0000
# [Epoch 70/100]  Train Loss: 0.0000
# [Epoch 75/100]  Train Loss: 0.0000
# [Epoch 80/100]  Train Loss: 0.0000
# [Epoch 85/100]  Train Loss: 0.0000
# [Epoch 90/100]  Train Loss: 0.0000
# [Epoch 95/100]  Train Loss: 0.0000
# [Epoch 100/100]  Train Loss: 0.0000
# Accuracy on Nonzero Predictions: 0.5000
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/train_test_loss_curve.png
# Training SPX | LR: 0.01 | Epochs: 100 | Batch: 64 | Security type: options
# [Epoch 5/100]  Train Loss: 0.6927
# [Epoch 10/100]  Train Loss: 0.6732
# [Epoch 15/100]  Train Loss: 0.6547
# [Epoch 20/100]  Train Loss: 0.6441
# [Epoch 25/100]  Train Loss: 0.6336
# [Epoch 30/100]  Train Loss: 0.6275
# [Epoch 35/100]  Train Loss: 0.6284
# [Epoch 40/100]  Train Loss: 0.6157
# [Epoch 45/100]  Train Loss: 0.6173
# [Epoch 50/100]  Train Loss: 0.6153
# [Epoch 55/100]  Train Loss: 0.6172
# [Epoch 60/100]  Train Loss: 0.6157
# [Epoch 65/100]  Train Loss: 0.6067
# [Epoch 70/100]  Train Loss: 0.6143
# [Epoch 75/100]  Train Loss: 0.6241
# [Epoch 80/100]  Train Loss: 0.6221
# [Epoch 85/100]  Train Loss: 0.6294
# [Epoch 90/100]  Train Loss: 0.6304
# [Epoch 95/100]  Train Loss: 0.6387
# [Epoch 100/100]  Train Loss: 0.6354
# Accuracy on Nonzero Predictions: 0.4867
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/train_test_loss_curve.png
# Training SPX | LR: 0.01 | Epochs: 100 | Batch: 64 | Security type: options
# [Epoch 5/100]  Train Loss: 0.6909
# [Epoch 10/100]  Train Loss: 0.6725
# [Epoch 15/100]  Train Loss: 0.6666
# [Epoch 20/100]  Train Loss: 0.6432
# [Epoch 25/100]  Train Loss: 0.6368
# [Epoch 30/100]  Train Loss: 0.6251
# [Epoch 35/100]  Train Loss: 0.6154
# [Epoch 40/100]  Train Loss: 0.6153
# [Epoch 45/100]  Train Loss: 0.6156
# [Epoch 50/100]  Train Loss: 0.6341
# [Epoch 55/100]  Train Loss: 0.6264
# [Epoch 60/100]  Train Loss: 0.6235
# [Epoch 65/100]  Train Loss: 0.6122
# [Epoch 70/100]  Train Loss: 0.6154
# [Epoch 75/100]  Train Loss: 0.6233
# [Epoch 80/100]  Train Loss: 0.6175
# [Epoch 85/100]  Train Loss: 0.6210
# [Epoch 90/100]  Train Loss: 0.6210
# [Epoch 95/100]  Train Loss: 0.6229
# [Epoch 100/100]  Train Loss: 0.6228
# Accuracy on Nonzero Predictions: 0.4633
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/train_test_loss_curve.png
# Training SPX | LR: 0.01 | Epochs: 100 | Batch: 64 | Security type: options
# [Epoch 5/100]  Train Loss: 0.6928
# [Epoch 10/100]  Train Loss: 0.6735
# [Epoch 15/100]  Train Loss: 0.6551
# [Epoch 20/100]  Train Loss: 0.6385
# [Epoch 25/100]  Train Loss: 0.6263
# [Epoch 30/100]  Train Loss: 0.6119
# [Epoch 35/100]  Train Loss: 0.6091
# [Epoch 40/100]  Train Loss: 0.5991
# [Epoch 45/100]  Train Loss: 0.5941
# [Epoch 50/100]  Train Loss: 0.5989
# [Epoch 55/100]  Train Loss: 0.5908
# [Epoch 60/100]  Train Loss: 0.5854
# [Epoch 65/100]  Train Loss: 0.5773
# [Epoch 70/100]  Train Loss: 0.5684
# [Epoch 75/100]  Train Loss: 0.5747
# [Epoch 80/100]  Train Loss: 0.5672
# [Epoch 85/100]  Train Loss: 0.5663
# [Epoch 90/100]  Train Loss: 0.5673
# [Epoch 95/100]  Train Loss: 0.5713
# [Epoch 100/100]  Train Loss: 0.5659
# Accuracy on Nonzero Predictions: 0.5567
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/train_test_loss_curve.png
# Training SPX | LR: 0.01 | Epochs: 100 | Batch: 64 | Security type: options
# [Epoch 5/100]  Train Loss: 0.6954
# [Epoch 10/100]  Train Loss: 0.6756
# [Epoch 15/100]  Train Loss: 0.6564
# [Epoch 20/100]  Train Loss: 0.6467
# [Epoch 25/100]  Train Loss: 0.6320
# [Epoch 30/100]  Train Loss: 0.6161
# [Epoch 35/100]  Train Loss: 0.6137
# [Epoch 40/100]  Train Loss: 0.6118
# [Epoch 45/100]  Train Loss: 0.6071
# [Epoch 50/100]  Train Loss: 0.6083
# [Epoch 55/100]  Train Loss: 0.6025
# [Epoch 60/100]  Train Loss: 0.6139
# [Epoch 65/100]  Train Loss: 0.6106
# [Epoch 70/100]  Train Loss: 0.5999
# [Epoch 75/100]  Train Loss: 0.6067
# [Epoch 80/100]  Train Loss: 0.6104
# [Epoch 85/100]  Train Loss: 0.6027
# [Epoch 90/100]  Train Loss: 0.5965
# [Epoch 95/100]  Train Loss: 0.6048
# [Epoch 100/100]  Train Loss: 0.6117
# Accuracy on Nonzero Predictions: 0.4933
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/train_test_loss_curve.png
# Training SPX | LR: 0.01 | Epochs: 100 | Batch: 64 | Security type: options
# [Epoch 5/100]  Train Loss: 0.6884
# [Epoch 10/100]  Train Loss: 0.6598
# [Epoch 15/100]  Train Loss: 0.6330
# [Epoch 20/100]  Train Loss: 0.6134
# [Epoch 25/100]  Train Loss: 0.6027
# [Epoch 30/100]  Train Loss: 0.5897
# [Epoch 35/100]  Train Loss: 0.5801
# [Epoch 40/100]  Train Loss: 0.5761
# [Epoch 45/100]  Train Loss: 0.5812
# [Epoch 50/100]  Train Loss: 0.5806
# [Epoch 55/100]  Train Loss: 0.5766
# [Epoch 60/100]  Train Loss: 0.5924
# [Epoch 65/100]  Train Loss: 0.5839
# [Epoch 70/100]  Train Loss: 0.5805
# [Epoch 75/100]  Train Loss: 0.5886
# [Epoch 80/100]  Train Loss: 0.5828
# [Epoch 85/100]  Train Loss: 0.5952
# [Epoch 90/100]  Train Loss: 0.5915
# [Epoch 95/100]  Train Loss: 0.5750
# [Epoch 100/100]  Train Loss: 0.5903
# Accuracy on Nonzero Predictions: 0.4500
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/train_test_loss_curve.png
# ----- Appending stock: AAPL, period: 10y, data_type: options -----
# ----- Appending stock: MSFT, period: 10y, data_type: options -----
# ----- Appending stock: AMZN, period: 10y, data_type: options -----
# ----- Appending stock: NVDA, period: 10y, data_type: options -----
# ----- Appending stock: SPX, period: 10y, data_type: options -----
# Final X shape: (11355, 11, 100)
# Final y shape: (11355,)
# Training SPX | LR: 0.01 | Epochs: 100 | Batch: 64 | Security type: options
# [Epoch 5/100]  Train Loss: 0.2909
# [Epoch 10/100]  Train Loss: 0.0693
# [Epoch 15/100]  Train Loss: 0.0177
# [Epoch 20/100]  Train Loss: 0.0012
# [Epoch 25/100]  Train Loss: 0.0006
# [Epoch 30/100]  Train Loss: 0.0003
# [Epoch 35/100]  Train Loss: 0.0002
# [Epoch 40/100]  Train Loss: 0.0001
# [Epoch 45/100]  Train Loss: 0.0001
# [Epoch 50/100]  Train Loss: 0.0000
# [Epoch 55/100]  Train Loss: 0.0000
# [Epoch 60/100]  Train Loss: 0.0000
# [Epoch 65/100]  Train Loss: 0.0000
# [Epoch 70/100]  Train Loss: 0.0000
# [Epoch 75/100]  Train Loss: 0.0000
# [Epoch 80/100]  Train Loss: 0.0000
# [Epoch 85/100]  Train Loss: 0.0000
# [Epoch 90/100]  Train Loss: 0.0000
# [Epoch 95/100]  Train Loss: 0.0000
# [Epoch 100/100]  Train Loss: 0.0000
# Accuracy on Nonzero Predictions: 0.4667
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/train_test_loss_curve.png
# Training SPX | LR: 0.01 | Epochs: 100 | Batch: 64 | Security type: options
# [Epoch 5/100]  Train Loss: 0.2962
# [Epoch 10/100]  Train Loss: 0.0683
# [Epoch 15/100]  Train Loss: 0.0463
# [Epoch 20/100]  Train Loss: 0.0015
# [Epoch 25/100]  Train Loss: 0.0006
# [Epoch 30/100]  Train Loss: 0.0003
# [Epoch 35/100]  Train Loss: 0.0002
# [Epoch 40/100]  Train Loss: 0.0001
# [Epoch 45/100]  Train Loss: 0.0001
# [Epoch 50/100]  Train Loss: 0.0000
# [Epoch 55/100]  Train Loss: 0.0000
# [Epoch 60/100]  Train Loss: 0.0000
# [Epoch 65/100]  Train Loss: 0.0000
# [Epoch 70/100]  Train Loss: 0.0000
# [Epoch 75/100]  Train Loss: 0.0000
# [Epoch 80/100]  Train Loss: 0.0000
# [Epoch 85/100]  Train Loss: 0.0000
# [Epoch 90/100]  Train Loss: 0.0000
# [Epoch 95/100]  Train Loss: 0.0000
# [Epoch 100/100]  Train Loss: 0.0000
# Accuracy on Nonzero Predictions: 0.4933
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/train_test_loss_curve.png
# Training SPX | LR: 0.01 | Epochs: 100 | Batch: 64 | Security type: options
# [Epoch 5/100]  Train Loss: 0.2805
# [Epoch 10/100]  Train Loss: 0.0567
# [Epoch 15/100]  Train Loss: 0.0611
# [Epoch 20/100]  Train Loss: 0.0057
# [Epoch 25/100]  Train Loss: 0.0006
# [Epoch 30/100]  Train Loss: 0.0003
# [Epoch 35/100]  Train Loss: 0.0002
# [Epoch 40/100]  Train Loss: 0.0001
# [Epoch 45/100]  Train Loss: 0.0001
# [Epoch 50/100]  Train Loss: 0.0000
# [Epoch 55/100]  Train Loss: 0.0000
# [Epoch 60/100]  Train Loss: 0.0000
# [Epoch 65/100]  Train Loss: 0.0000
# [Epoch 70/100]  Train Loss: 0.0000
# [Epoch 75/100]  Train Loss: 0.0000
# [Epoch 80/100]  Train Loss: 0.0000
# [Epoch 85/100]  Train Loss: 0.0000
# [Epoch 90/100]  Train Loss: 0.0000
# [Epoch 95/100]  Train Loss: 0.0000
# [Epoch 100/100]  Train Loss: 0.0000
# Accuracy on Nonzero Predictions: 0.5333
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/train_test_loss_curve.png
# Training SPX | LR: 0.01 | Epochs: 100 | Batch: 64 | Security type: options
# [Epoch 5/100]  Train Loss: 0.2651
# [Epoch 10/100]  Train Loss: 0.0156
# [Epoch 15/100]  Train Loss: 0.0013
# [Epoch 20/100]  Train Loss: 0.0006
# [Epoch 25/100]  Train Loss: 0.0003
# [Epoch 30/100]  Train Loss: 0.0002
# [Epoch 35/100]  Train Loss: 0.0001
# [Epoch 40/100]  Train Loss: 0.0001
# [Epoch 45/100]  Train Loss: 0.0000
# [Epoch 50/100]  Train Loss: 0.0000
# [Epoch 55/100]  Train Loss: 0.0000
# [Epoch 60/100]  Train Loss: 0.0000
# [Epoch 65/100]  Train Loss: 0.0000
# [Epoch 70/100]  Train Loss: 0.0000
# [Epoch 75/100]  Train Loss: 0.0000
# [Epoch 80/100]  Train Loss: 0.0000
# [Epoch 85/100]  Train Loss: 0.0000
# [Epoch 90/100]  Train Loss: 0.0000
# [Epoch 95/100]  Train Loss: 0.0000
# [Epoch 100/100]  Train Loss: 0.0000
# Accuracy on Nonzero Predictions: 0.4933
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/train_test_loss_curve.png
# Training SPX | LR: 0.01 | Epochs: 100 | Batch: 64 | Security type: options
# [Epoch 5/100]  Train Loss: 0.2890
# [Epoch 10/100]  Train Loss: 0.0664
# [Epoch 15/100]  Train Loss: 0.0649
# [Epoch 20/100]  Train Loss: 0.0198
# [Epoch 25/100]  Train Loss: 0.0011
# [Epoch 30/100]  Train Loss: 0.0005
# [Epoch 35/100]  Train Loss: 0.0003
# [Epoch 40/100]  Train Loss: 0.0002
# [Epoch 45/100]  Train Loss: 0.0001
# [Epoch 50/100]  Train Loss: 0.0001
# [Epoch 55/100]  Train Loss: 0.0000
# [Epoch 60/100]  Train Loss: 0.0000
# [Epoch 65/100]  Train Loss: 0.0000
# [Epoch 70/100]  Train Loss: 0.0000
# [Epoch 75/100]  Train Loss: 0.0000
# [Epoch 80/100]  Train Loss: 0.0000
# [Epoch 85/100]  Train Loss: 0.0000
# [Epoch 90/100]  Train Loss: 0.0000
# [Epoch 95/100]  Train Loss: 0.0000
# [Epoch 100/100]  Train Loss: 0.0000
# Accuracy on Nonzero Predictions: 0.4800
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/train_test_loss_curve.png
# Training SPX | LR: 0.01 | Epochs: 100 | Batch: 64 | Security type: options
# [Epoch 5/100]  Train Loss: 0.6616
# [Epoch 10/100]  Train Loss: 0.5753
# [Epoch 15/100]  Train Loss: 0.5118
# [Epoch 20/100]  Train Loss: 0.4801
# [Epoch 25/100]  Train Loss: 0.4447
# [Epoch 30/100]  Train Loss: 0.4242
# [Epoch 35/100]  Train Loss: 0.4158
# [Epoch 40/100]  Train Loss: 0.3953
# [Epoch 45/100]  Train Loss: 0.4133
# [Epoch 50/100]  Train Loss: 0.3722
# [Epoch 55/100]  Train Loss: 0.3685
# [Epoch 60/100]  Train Loss: 0.3805
# [Epoch 65/100]  Train Loss: 0.3688
# [Epoch 70/100]  Train Loss: 0.3772
# [Epoch 75/100]  Train Loss: 0.3788
# [Epoch 80/100]  Train Loss: 0.3653
# [Epoch 85/100]  Train Loss: 0.3669
# [Epoch 90/100]  Train Loss: 0.3768
# [Epoch 95/100]  Train Loss: 0.3757
# [Epoch 100/100]  Train Loss: 0.3989
# Accuracy on Nonzero Predictions: 0.4600
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/train_test_loss_curve.png
# Training SPX | LR: 0.01 | Epochs: 100 | Batch: 64 | Security type: options
# [Epoch 5/100]  Train Loss: 0.6689
# [Epoch 10/100]  Train Loss: 0.5994
# [Epoch 15/100]  Train Loss: 0.5301
# [Epoch 20/100]  Train Loss: 0.4865
# [Epoch 25/100]  Train Loss: 0.4663
# [Epoch 30/100]  Train Loss: 0.4353
# [Epoch 35/100]  Train Loss: 0.4312
# [Epoch 40/100]  Train Loss: 0.4160
# [Epoch 45/100]  Train Loss: 0.4193
# [Epoch 50/100]  Train Loss: 0.4374
# [Epoch 55/100]  Train Loss: 0.4382
# [Epoch 60/100]  Train Loss: 0.4180
# [Epoch 65/100]  Train Loss: 0.4281
# [Epoch 70/100]  Train Loss: 0.4283
# [Epoch 75/100]  Train Loss: 0.4216
# [Epoch 80/100]  Train Loss: 0.4298
# [Epoch 85/100]  Train Loss: 0.4058
# [Epoch 90/100]  Train Loss: 0.4022
# [Epoch 95/100]  Train Loss: 0.3938
# [Epoch 100/100]  Train Loss: 0.4133
# Accuracy on Nonzero Predictions: 0.4167
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/train_test_loss_curve.png
# Training SPX | LR: 0.01 | Epochs: 100 | Batch: 64 | Security type: options
# [Epoch 5/100]  Train Loss: 0.6581
# [Epoch 10/100]  Train Loss: 0.6025
# [Epoch 15/100]  Train Loss: 0.5618
# [Epoch 20/100]  Train Loss: 0.5104
# [Epoch 25/100]  Train Loss: 0.4743
# [Epoch 30/100]  Train Loss: 0.4552
# [Epoch 35/100]  Train Loss: 0.4508
# [Epoch 40/100]  Train Loss: 0.4318
# [Epoch 45/100]  Train Loss: 0.4234
# [Epoch 50/100]  Train Loss: 0.4196
# [Epoch 55/100]  Train Loss: 0.4392
# [Epoch 60/100]  Train Loss: 0.4266
# [Epoch 65/100]  Train Loss: 0.4266
# [Epoch 70/100]  Train Loss: 0.4119
# [Epoch 75/100]  Train Loss: 0.3975
# [Epoch 80/100]  Train Loss: 0.4027
# [Epoch 85/100]  Train Loss: 0.3930
# [Epoch 90/100]  Train Loss: 0.3858
# [Epoch 95/100]  Train Loss: 0.3986
# [Epoch 100/100]  Train Loss: 0.4031
# Accuracy on Nonzero Predictions: 0.5067
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/train_test_loss_curve.png
# Training SPX | LR: 0.01 | Epochs: 100 | Batch: 64 | Security type: options
# [Epoch 5/100]  Train Loss: 0.6741
# [Epoch 10/100]  Train Loss: 0.5972
# [Epoch 15/100]  Train Loss: 0.5462
# [Epoch 20/100]  Train Loss: 0.5039
# [Epoch 25/100]  Train Loss: 0.4686
# [Epoch 30/100]  Train Loss: 0.4500
# [Epoch 35/100]  Train Loss: 0.4266
# [Epoch 40/100]  Train Loss: 0.4148
# [Epoch 45/100]  Train Loss: 0.4156
# [Epoch 50/100]  Train Loss: 0.3867
# [Epoch 55/100]  Train Loss: 0.3909
# [Epoch 60/100]  Train Loss: 0.3715
# [Epoch 65/100]  Train Loss: 0.3684
# [Epoch 70/100]  Train Loss: 0.3590
# [Epoch 75/100]  Train Loss: 0.3561
# [Epoch 80/100]  Train Loss: 0.3647
# [Epoch 85/100]  Train Loss: 0.3563
# [Epoch 90/100]  Train Loss: 0.3610
# [Epoch 95/100]  Train Loss: 0.3523
# [Epoch 100/100]  Train Loss: 0.3616
# Accuracy on Nonzero Predictions: 0.4933
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/train_test_loss_curve.png
# Training SPX | LR: 0.01 | Epochs: 100 | Batch: 64 | Security type: options
# [Epoch 5/100]  Train Loss: 0.6760
# [Epoch 10/100]  Train Loss: 0.6116
# [Epoch 15/100]  Train Loss: 0.5253
# [Epoch 20/100]  Train Loss: 0.5007
# [Epoch 25/100]  Train Loss: 0.4672
# [Epoch 30/100]  Train Loss: 0.4505
# [Epoch 35/100]  Train Loss: 0.4386
# [Epoch 40/100]  Train Loss: 0.4291
# [Epoch 45/100]  Train Loss: 0.4290
# [Epoch 50/100]  Train Loss: 0.4171
# [Epoch 55/100]  Train Loss: 0.3993
# [Epoch 60/100]  Train Loss: 0.3958
# [Epoch 65/100]  Train Loss: 0.3843
# [Epoch 70/100]  Train Loss: 0.3946
# [Epoch 75/100]  Train Loss: 0.4051
# [Epoch 80/100]  Train Loss: 0.3984
# [Epoch 85/100]  Train Loss: 0.3950
# [Epoch 90/100]  Train Loss: 0.3943
# [Epoch 95/100]  Train Loss: 0.3920
# [Epoch 100/100]  Train Loss: 0.3706
# Accuracy on Nonzero Predictions: 0.4400
# Loss curves saved to: /home/jupyter-tfg2425paula/prediction_project_v3/03_plots/train_test_loss_curve.png

# %%
output_folder = os.path.join(results_dir, 'combined_vs_individual_v1')

results_df.to_csv(os.path.join(output_folder, f'combined_options.csv'), index=False)
