# %% [markdown]
# ## **This code aims to generate horizontal dataframes**

# %%
import pandas as pd
import numpy as np
import os
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# %%
project_dir = "/home/jupyter-tfg2425paula/prediction_project_v3"
os.chdir(project_dir)

clean_data_dir = os.path.join(project_dir, "00_data/clean")
horizontal_structure_data_dir = os.path.join(project_dir, "00_data/horizontal_structure")
pca_data_dir = os.path.join(project_dir, "00_data/pca")

# %%
def scale_data(df, selected_scale_cols, scaling_method):
    """
    Scales specified columns in a DataFrame using the specified scaling method.
    
    Args:
        df (pd.DataFrame): The input DataFrame.
        selected_cols (list): A list of column names to scale.
        scaling_method (str): The scaling method to use ("standard" or "minmax"). Default is "standard".
    
    Returns:
        pd.DataFrame: The DataFrame with specified columns scaled.
    """
    
    if scaling_method is not None:
        if scaling_method == "standard":
            scaler = StandardScaler()
        elif scaling_method == "minmax":
            scaler = MinMaxScaler()
        else:
            raise ValueError("Invalid scaling method. Choose 'standard' or 'minmax'.")

        df[selected_scale_cols] = df[selected_scale_cols].apply(pd.to_numeric, errors="coerce")
        
        # Scale only the selected columns
        df_scaled = df.copy()
        # Replace infinite values with NaN
        df[selected_scale_cols].replace([np.inf, -np.inf], np.nan, inplace=True)

        # Optionally fill NaN with column mean or median
        df[selected_scale_cols].fillna(df[selected_scale_cols].mean(), inplace=True)

        df_scaled[selected_scale_cols] = scaler.fit_transform(df[selected_scale_cols])
    
    else:
        df_scaled = df
        
    return df_scaled

# %%
def split_dataframe(df, target_column, window_size):
    """
    Splits the DataFrame into sequential portions of size `window_size`.

    Parameters:
    df (pd.DataFrame): The input DataFrame to be split.
    target_column (str): Name of the target column that indicates future changes.
    window_size (int): The size of each sequential portion.

    Returns:
    list: A list of DataFrames, each of size `window_size`.
    list: Corresponding targets for each sequential portion.
    """
    sequential_data = []
    targets = []

    for i in range(len(df) - window_size + 1):
        window = df.iloc[i:i + window_size].copy()  # Selects a window of size `window_size`
        target = df.iloc[i + window_size - 1][target_column]  # Target is the last value in the window
        sequential_data.append(window)
        targets.append(target)

    return sequential_data, targets

# %%
def create_sequential_dataframe(sequential_data, targets):
    """
    Creates a reshaped DataFrame where each row contains sequential data for each feature
    and a corresponding target value.

    Parameters:
    sequential_data (list): List of DataFrames representing sequential data portions.
    targets (list): List of target values corresponding to each sequence.

    Returns:
    pd.DataFrame: Reshaped DataFrame with each row containing sequential data for each feature
                  and the corresponding target value.
    """
    reshaped_rows = []

    for i, window_df in enumerate(sequential_data):
        row_data = {}
        # Iterate over columns (features) in the window
        for col in window_df.columns:
            # Create a new column for each feature across the window size
            row_data[col] = pd.Series(window_df[col].values)

        # Add the corresponding target for the sequence
        row_data['Target'] = targets[i]

        reshaped_rows.append(row_data)

    # Convert to DataFrame
    reshaped_df = pd.DataFrame(reshaped_rows)
    return reshaped_df

# %%
types_securities = ["options"]
# stocks = ['AAPL', 'MSFT', 'AMZN', 'NVDA', 'SPX']
stocks = ['AAPL']
years = ["2y", "5y", "10y"]

# %%
window_sizes = [5, 10, 50, 100]
for security_type in types_securities:
    for stock in stocks:
        for period in years:
            input_df = pd.read_csv(os.path.join(pca_data_dir, f"{security_type}/{stock}/{period}_data.csv"))
            # input_df = input_df.drop(columns = ["Date"])
            
            # SCALE DATA FIRST
            # scaling_method = "standard"
            # selected_scale_cols = list(input_df.drop(columns=["Target"]).columns)
            # scaled_df = scale_data(input_df, selected_scale_cols, scaling_method)
            
            for window_size in window_sizes:
                print(f"{security_type}, {stock}, {period}, {window_size}")
                sequential_data, targets = split_dataframe(input_df, target_column='Target', window_size=window_size)
                reshaped_df = create_sequential_dataframe(sequential_data, targets)
                
                pkl_filename = f"pca/{security_type}/{stock}/{period}_{window_size}_data.pkl"
                
                output_filepath = os.path.join(horizontal_structure_data_dir, pkl_filename)
                os.makedirs(os.path.dirname(output_filepath), exist_ok=True)
                
                print(output_filepath)
                reshaped_df.to_pickle(output_filepath)
# Out:
# technical, AAPL, 2y, 5
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/AAPL/2y_5_data.pkl
# technical, AAPL, 2y, 10
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/AAPL/2y_10_data.pkl
# technical, AAPL, 2y, 50
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/AAPL/2y_50_data.pkl
# technical, AAPL, 2y, 100
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/AAPL/2y_100_data.pkl
# technical, AAPL, 5y, 5
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/AAPL/5y_5_data.pkl
# technical, AAPL, 5y, 10
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/AAPL/5y_10_data.pkl
# technical, AAPL, 5y, 50
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/AAPL/5y_50_data.pkl
# technical, AAPL, 5y, 100
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/AAPL/5y_100_data.pkl
# technical, AAPL, 10y, 5
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/AAPL/10y_5_data.pkl
# technical, AAPL, 10y, 10
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/AAPL/10y_10_data.pkl
# technical, AAPL, 10y, 50
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/AAPL/10y_50_data.pkl
# technical, AAPL, 10y, 100
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/AAPL/10y_100_data.pkl
# technical, AAPL, 15y, 5
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/AAPL/15y_5_data.pkl
# technical, AAPL, 15y, 10
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/AAPL/15y_10_data.pkl
# technical, AAPL, 15y, 50
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/AAPL/15y_50_data.pkl
# technical, AAPL, 15y, 100
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/AAPL/15y_100_data.pkl
# technical, MSFT, 2y, 5
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/MSFT/2y_5_data.pkl
# technical, MSFT, 2y, 10
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/MSFT/2y_10_data.pkl
# technical, MSFT, 2y, 50
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/MSFT/2y_50_data.pkl
# technical, MSFT, 2y, 100
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/MSFT/2y_100_data.pkl
# technical, MSFT, 5y, 5
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/MSFT/5y_5_data.pkl
# technical, MSFT, 5y, 10
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/MSFT/5y_10_data.pkl
# technical, MSFT, 5y, 50
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/MSFT/5y_50_data.pkl
# technical, MSFT, 5y, 100
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/MSFT/5y_100_data.pkl
# technical, MSFT, 10y, 5
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/MSFT/10y_5_data.pkl
# technical, MSFT, 10y, 10
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/MSFT/10y_10_data.pkl
# technical, MSFT, 10y, 50
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/MSFT/10y_50_data.pkl
# technical, MSFT, 10y, 100
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/MSFT/10y_100_data.pkl
# technical, MSFT, 15y, 5
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/MSFT/15y_5_data.pkl
# technical, MSFT, 15y, 10
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/MSFT/15y_10_data.pkl
# technical, MSFT, 15y, 50
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/MSFT/15y_50_data.pkl
# technical, MSFT, 15y, 100
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/MSFT/15y_100_data.pkl
# technical, AMZN, 2y, 5
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/AMZN/2y_5_data.pkl
# technical, AMZN, 2y, 10
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/AMZN/2y_10_data.pkl
# technical, AMZN, 2y, 50
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/AMZN/2y_50_data.pkl
# technical, AMZN, 2y, 100
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/AMZN/2y_100_data.pkl
# technical, AMZN, 5y, 5
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/AMZN/5y_5_data.pkl
# technical, AMZN, 5y, 10
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/AMZN/5y_10_data.pkl
# technical, AMZN, 5y, 50
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/AMZN/5y_50_data.pkl
# technical, AMZN, 5y, 100
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/AMZN/5y_100_data.pkl
# technical, AMZN, 10y, 5
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/AMZN/10y_5_data.pkl
# technical, AMZN, 10y, 10
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/AMZN/10y_10_data.pkl
# technical, AMZN, 10y, 50
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/AMZN/10y_50_data.pkl
# technical, AMZN, 10y, 100
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/AMZN/10y_100_data.pkl
# technical, AMZN, 15y, 5
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/AMZN/15y_5_data.pkl
# technical, AMZN, 15y, 10
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/AMZN/15y_10_data.pkl
# technical, AMZN, 15y, 50
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/AMZN/15y_50_data.pkl
# technical, AMZN, 15y, 100
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/AMZN/15y_100_data.pkl
# technical, NVDA, 2y, 5
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/NVDA/2y_5_data.pkl
# technical, NVDA, 2y, 10
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/NVDA/2y_10_data.pkl
# technical, NVDA, 2y, 50
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/NVDA/2y_50_data.pkl
# technical, NVDA, 2y, 100
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/NVDA/2y_100_data.pkl
# technical, NVDA, 5y, 5
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/NVDA/5y_5_data.pkl
# technical, NVDA, 5y, 10
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/NVDA/5y_10_data.pkl
# technical, NVDA, 5y, 50
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/NVDA/5y_50_data.pkl
# technical, NVDA, 5y, 100
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/NVDA/5y_100_data.pkl
# technical, NVDA, 10y, 5
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/NVDA/10y_5_data.pkl
# technical, NVDA, 10y, 10
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/NVDA/10y_10_data.pkl
# technical, NVDA, 10y, 50
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/NVDA/10y_50_data.pkl
# technical, NVDA, 10y, 100
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/NVDA/10y_100_data.pkl
# technical, NVDA, 15y, 5
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/NVDA/15y_5_data.pkl
# technical, NVDA, 15y, 10
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/NVDA/15y_10_data.pkl
# technical, NVDA, 15y, 50
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/NVDA/15y_50_data.pkl
# technical, NVDA, 15y, 100
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/NVDA/15y_100_data.pkl
# technical, SPX, 2y, 5
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/SPX/2y_5_data.pkl
# technical, SPX, 2y, 10
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/SPX/2y_10_data.pkl
# technical, SPX, 2y, 50
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/SPX/2y_50_data.pkl
# technical, SPX, 2y, 100
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/SPX/2y_100_data.pkl
# technical, SPX, 5y, 5
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/SPX/5y_5_data.pkl
# technical, SPX, 5y, 10
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/SPX/5y_10_data.pkl
# technical, SPX, 5y, 50
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/SPX/5y_50_data.pkl
# technical, SPX, 5y, 100
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/SPX/5y_100_data.pkl
# technical, SPX, 10y, 5
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/SPX/10y_5_data.pkl
# technical, SPX, 10y, 10
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/SPX/10y_10_data.pkl
# technical, SPX, 10y, 50
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/SPX/10y_50_data.pkl
# technical, SPX, 10y, 100
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/SPX/10y_100_data.pkl
# technical, SPX, 15y, 5
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/SPX/15y_5_data.pkl
# technical, SPX, 15y, 10
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/SPX/15y_10_data.pkl
# technical, SPX, 15y, 50
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/SPX/15y_50_data.pkl
# technical, SPX, 15y, 100
# /home/jupyter-tfg2425paula/prediction_project_v3/00_data/horizontal_structure/pca/technical/SPX/15y_100_data.pkl

# %%
np.linspace(0.009, 0.012, 100)
# Out:
# array([0.009     , 0.0090303 , 0.00906061, 0.00909091, 0.00912121,
#        0.00915152, 0.00918182, 0.00921212, 0.00924242, 0.00927273,
#        0.00930303, 0.00933333, 0.00936364, 0.00939394, 0.00942424,
#        0.00945455, 0.00948485, 0.00951515, 0.00954545, 0.00957576,
#        0.00960606, 0.00963636, 0.00966667, 0.00969697, 0.00972727,
#        0.00975758, 0.00978788, 0.00981818, 0.00984848, 0.00987879,
#        0.00990909, 0.00993939, 0.0099697 , 0.01      , 0.0100303 ,
#        0.01006061, 0.01009091, 0.01012121, 0.01015152, 0.01018182,
#        0.01021212, 0.01024242, 0.01027273, 0.01030303, 0.01033333,
#        0.01036364, 0.01039394, 0.01042424, 0.01045455, 0.01048485,
#        0.01051515, 0.01054545, 0.01057576, 0.01060606, 0.01063636,
#        0.01066667, 0.01069697, 0.01072727, 0.01075758, 0.01078788,
#        0.01081818, 0.01084848, 0.01087879, 0.01090909, 0.01093939,
#        0.0109697 , 0.011     , 0.0110303 , 0.01106061, 0.01109091,
#        0.01112121, 0.01115152, 0.01118182, 0.01121212, 0.01124242,
#        0.01127273, 0.01130303, 0.01133333, 0.01136364, 0.01139394,
#        0.01142424, 0.01145455, 0.01148485, 0.01151515, 0.01154545,
#        0.01157576, 0.01160606, 0.01163636, 0.01166667, 0.01169697,
#        0.01172727, 0.01175758, 0.01178788, 0.01181818, 0.01184848,
#        0.01187879, 0.01190909, 0.01193939, 0.0119697 , 0.012     ])
